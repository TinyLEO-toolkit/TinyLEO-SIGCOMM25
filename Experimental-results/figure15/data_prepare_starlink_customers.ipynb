# %%
import numpy as np
import math
from fractions import Fraction
from tqdm import tqdm
import multiprocessing as mp
from haversine import haversine, Unit
import matplotlib.pyplot as plt
import os
import random
import matplotlib
from scipy.sparse import lil_matrix, csr_matrix
import gc
import time
from multiprocessing import shared_memory

# %%
# Astronomy-related constants

TE = 24 * 3600  # One Earth sidereal day in seconds

RE = 6371e3  # Mean radius of Earth in meters

u = 3.986e14  # Standard gravitational parameter (μ = GM) in m^3/s^2

K = RE / pow(u, 1/3) * pow(2 * np.pi, 2/3)  

eps = 25 * np.pi / 180  # Maximum elevation angle for ground access, in radians (25°)

# %%
# Get all files (excluding Jupyter checkpoints)
def get_allfile(path):
    return [os.path.join(path, f) for f in os.listdir(path) if "ipynb_checkpoints" not in f]

# Compute satellite orbital period (h in meters)
def satellite_period(h):
    a = RE + h
    T = float(2 * np.pi * pow(a**3 / u, 0.5))
    return T

# Compute coverage angle eta (in radians)
def coverage_eta(T):
    eta = math.acos(K * math.cos(eps) / pow(T, 2/3)) - eps
    return eta

# Approximate an integer ratio of a and b
def approximate_ratio(a, b, precision=1e-3):
    if b == 0:
        raise ValueError("Denominator cannot be zero")
    ratio = Fraction(a, b).limit_denominator(int(1 / precision))
    return ratio.numerator, ratio.denominator

# Convert orbital parameters to longitude/latitude
def alpha_gamma_to_lambda_phi(alpha, gamma, inc):
    phi = math.asin(math.sin(inc) * math.sin(gamma))
    temp = math.atan2(math.cos(inc) * math.sin(gamma), math.cos(gamma))
    lamb = (temp + alpha) % (2 * math.pi)
    if lamb > math.pi:
        lamb -= 2 * math.pi
    return lamb, phi

# Check whether satellite covers a ground cell
def is_cover(l_sat, p_sat, l_cell, p_cell, eta):
    # If latitude/longitude range overflows, fallback to haversine distance
    if (p_sat - 2*eta) < -np.pi/2 or (p_sat + 2*eta) > np.pi/2 or (l_sat - 2*eta) < -np.pi or (l_sat + 2*eta) > np.pi:
        d = haversine(
            (np.degrees(p_sat), np.degrees(l_sat)),
            (np.degrees(p_cell), np.degrees(l_cell)),
            unit=Unit.METERS
        )
        return d <= eta * RE
    else:
        # Fast bounding-box filter + haversine check
        if (p_sat - 2*eta) <= p_cell <= (p_sat + 2*eta) and (l_sat - 2*eta) <= l_cell <= (l_sat + 2*eta):
            d = haversine(
                (np.degrees(p_sat), np.degrees(l_sat)),
                (np.degrees(p_cell), np.degrees(l_cell)),
                unit=Unit.METERS
            )
            return d <= eta * RE
    return False

# %%
def cal_supply_all_cell(h, beta, a0):
    """
    Compute all ground coverage slots for a single stable satellite track.

    Args:
        h: Satellite altitude (km)
        beta: Inclination (rad)
        a0: Ascending node longitude (rad)

    Returns:
        total_supply: list of [covered_cells, lon, lat] for each slot
    """
    T = satellite_period(h * 1e3)
    p, q = approximate_ratio(int(T), TE, precision=1e-3)
    eta = coverage_eta(T)
    step = 2 * eta
    inc = beta

    total_supply = []
    slot_num = int(2 * np.pi * q / step)

    for i in range(slot_num):
        t = step * i / (2 * np.pi / T)
        a_sat = (a0 - (2 * np.pi / TE) * t) % (2 * np.pi)
        b_sat = (step * i) % (2 * np.pi)
        l_sat, p_sat = alpha_gamma_to_lambda_phi(a_sat, b_sat, inc)

        r_set = []
        for idx, demand in enumerate(demand_list):
            l_cell = demand['lat_lon'][1]
            p_cell = demand['lat_lon'][0]
            if is_cover(l_sat, p_sat, l_cell, p_cell, eta):
                S = S_set[idx]
                r_set.append([idx, S, demand['density']])

        if r_set:
            S_sum = np.sum([item[1] for item in r_set])
            factor = user_per_sat / S_sum
            r_set = [[item[0], item[1] * factor] for item in r_set]
            total_supply.append([r_set, l_sat, p_sat])

    return np.asarray(total_supply, dtype="object")

# %%
# Recover full-time user coverage from time-shifted satellites
def recover_fulltime(data):
    random_numbers, cover, n_length = data
    selected_cover = lil_matrix((1, n_length), dtype=np.float64)
    sat_location = []

    for t in range(time_split):
        for num in random_numbers:
            slot = (num + t) % time_split
            sat_location.append([cover[slot][1], cover[slot][2]])
            for idx, users in cover[slot][0]:
                selected_cover[0, t * len(demand_list) + idx] += users

    return [selected_cover.tocsr(), sat_location]

# Generate one base configuration with full-time coverage
def generate_baseset(args):
    file, random_numbers, sat_num = args
    file_param = file.split("/")[1].split("_")
    h = float(file_param[0])
    beta = float(file_param[1])
    alpha0 = float(file_param[2].split(".npy")[0])
    param = [h, beta, alpha0]
    cover = cal_supply_all_cell(h,beta,alpha0)
    fulltime_cover = recover_fulltime([random_numbers, cover, n_length])
    
    return [param, random_numbers, fulltime_cover, sat_num]

# %%
def compute_dot(args, show=False):
    """
    Compute dot product between a candidate's full-time coverage vector and residual demand R.
    
    Args:
        args: Tuple of (R, cid), where
            - R: residual demand vector
            - cid: candidate index
        show: optional debug flag

    Returns:
        List: [dot value, cid]
    """
    R, cid = args
    fulltime_cover = all_cover[cid][2][0]  # csr sparse matrix
    dot = fulltime_cover @ R  # single value (array of shape (1,))
    return [dot[0], cid]

def update_residual(R, cid):
    """
    Subtract selected candidate's contribution from residual demand R.

    Args:
        R: current residual vector
        cid: candidate ID

    Returns:
        Updated residual R (clipped at 0)
    """
    cover_csr = all_cover[cid][2][0]
    sat_num = all_cover[cid][3]
    R[cover_csr.indices] -= (cover_csr.data * sat_num)
    R = np.maximum(R, 0)  # ensure no negative values
    return R

def find_max_in_chunk(chunk):
    """
    Find the max value and corresponding candidate index in a chunk of dot results.

    Args:
        chunk: array-like of shape (N, 2) -> [dot_value, cid]

    Returns:
        [max_dot_value, cid]
    """
    chunk = np.array(chunk)
    max_value = np.max(chunk[:, 0])
    local_index = np.argmax(chunk[:, 0])
    max_index = chunk[local_index][1]
    return [max_value, int(max_index)]

# %% [markdown]
# # Starlink customer

# %%
sat_height = 573  # Satellite altitude in km
base_cover_path = f"candidate_orbits_starlink_customer_{sat_height}/"
time_split = 308  # Number of time slots

# Load user demand and convert lat/lon to radians
demand_list = np.load("../../Dataset/Demand/starlink_supply_2025_01_01_99449.npy", allow_pickle=True)
for demand in demand_list:
    demand['lat_lon'] = [np.radians(demand['lat_lon'][0]), np.radians(demand['lat_lon'][1])]

cell_size = 4  # Grid size in degrees
user_per_sat = 960

# Compute area of each demand cell
S_set = []
for demand in demand_list:
    p_cell = demand['lat_lon'][0]  # latitude in radians
    h = RE * np.radians(cell_size)

    L1 = RE * np.sin(np.pi / 2 - abs(p_cell)) * np.radians(cell_size)
    tmp = abs(p_cell - np.radians(cell_size))
    L2 = RE * np.sin(np.pi / 2 - min(tmp, np.pi/2)) * np.radians(cell_size)

    # Special case for South Pole
    if tmp > np.pi / 2:
        h = RE * abs(p_cell + np.pi / 2)

    S = 0.5 * h * (L1 + L2)
    S_set.append(S)

# %%
selected_params=np.load("data/Tinyleo_for_starlink_demand.npy",allow_pickle=True)
print(len(selected_params))
files=[]
sat_nums=0
for s_tmp in selected_params:
    param_tmp,slots,satmaps,sat_num=s_tmp
    tmp=base_cover_path+str(int(param_tmp[0]))+"_"+str(param_tmp[1])+"_"+str(param_tmp[2])+".npy"
    files.append([tmp,slots,sat_num])
    sat_nums+=sat_num
print(files[0])
print(sat_nums)
# Out:
# 1762
# ['candidate_orbits_starlink_customer_573/573_2.234021442552742_1.53588974175501.npy', [87], 1]
# 1762

# %%
# files=get_allfile(base_cover_path)
# print(files[0])
all_cover=[]
n_length=len(demand_list)*time_split

with mp.Pool(processes=100) as pool:
    all_cover = list(tqdm(pool.imap(generate_baseset, files), total=len(files), mininterval=10,maxinterval=20))
    pool.close()  # Prevents any more tasks from being submitted to the pool
    pool.join()  # Wait for the worker processes to exit
# Out:
# 100%|██████████| 1762/1762 [00:42<00:00, 41.56it/s]

# %%
num_processes = 20

# Initialize residual demand vector R_2 over all time slots
tmp_R = [demand['density'] for demand in demand_list]
R_2 = np.array(tmp_R * time_split).reshape(-1).copy()
R_sum_2 = np.sum(R_2)
print("Initial residual sum:", R_sum_2)

# Free memory
del tmp_R

process = []
for idx in range(len(all_cover)):
    R_2 = update_residual(R_2, idx)  # Subtract current satellite's supply
    covered = R_sum_2 - np.sum(R_2)  # Demand covered in this step
    process.append([all_cover[idx][3], covered])
    R_sum_2 = np.sum(R_2)
    print("Residual sum after", idx + 1, ":", R_sum_2)

# Final residual diagnostics
print(f"Remaining nonzero entries = {np.count_nonzero(R_2)}, "
      f"Max = {np.max(R_2):.3f}, Mean = {np.mean(R_2):.6f}")
# Out:
# Initial residual sum: 30630530.279174425
# Residual sum after 1 : 30574305.861058682
# Residual sum after 2 : 30518081.442942902
# Residual sum after 3 : 30461857.024827156
# Residual sum after 4 : 30405632.606711384
# Residual sum after 5 : 30349408.188595634
# Residual sum after 6 : 30293183.770479877
# Residual sum after 7 : 30236959.352364108
# Residual sum after 8 : 30180734.93424833
# Residual sum after 9 : 30124510.516132567
# Residual sum after 10 : 30068286.098016772
# Residual sum after 11 : 30012061.67990105
# Residual sum after 12 : 29955837.26178527
# Residual sum after 13 : 29899612.843669523
# Residual sum after 14 : 29843388.425553747
# Residual sum after 15 : 29787164.00743797
# Residual sum after 16 : 29730939.589322235
# Residual sum after 17 : 29674715.171206445
# Residual sum after 18 : 29618490.75309069
# Residual sum after 19 : 29562266.334974933
# Residual sum after 20 : 29506122.399195466
# Residual sum after 21 : 29449978.46341601
# Residual sum after 22 : 29393834.527636528
# Residual sum after 23 : 29338043.637115385
# Residual sum after 24 : 29282304.33811366
# Residual sum after 25 : 29226648.672988933
# Residual sum after 26 : 29170844.61030735
# Residual sum after 27 : 29115239.256508477
# Residual sum after 28 : 29059833.90301817
# Residual sum after 29 : 29004542.07080995
# Residual sum after 30 : 28949392.805746943
# Residual sum after 31 : 28893623.808592293
# Residual sum after 32 : 28838355.493792307
# Residual sum after 33 : 28783067.425610658
# Residual sum after 34 : 28727789.643427923
# Residual sum after 35 : 28672160.46646974
# Residual sum after 36 : 28616624.216618273
# Residual sum after 37 : 28561087.966766793
# Residual sum after 38 : 28505551.716915317
# Residual sum after 39 : 28450015.467063848
# Residual sum after 40 : 28394495.044297285
# Residual sum after 41 : 28338959.03479833
# Residual sum after 42 : 28283510.07118008
# Residual sum after 43 : 28228692.15453852
# Residual sum after 44 : 28173437.77651097
# Residual sum after 45 : 28118456.76935088
# Residual sum after 46 : 28063310.572665486
# Residual sum after 47 : 28009433.122363564
# Residual sum after 48 : 27954612.052189987
# Residual sum after 49 : 27900733.206311703
# Residual sum after 50 : 27845941.694780912
# Residual sum after 51 : 27791785.457291417
# Residual sum after 52 : 27737320.576018166
# Residual sum after 53 : 27682927.014472455
# Residual sum after 54 : 27628574.527010273
# Residual sum after 55 : 27574995.03254716
# Residual sum after 56 : 27520925.135440625
# Residual sum after 57 : 27466982.34503817
# Residual sum after 58 : 27413439.800283197
# Residual sum after 59 : 27359647.762238782
# Residual sum after 60 : 27305588.763168328
# Residual sum after 61 : 27252212.435957417
# Residual sum after 62 : 27198737.965852402
# Residual sum after 63 : 27145303.95078407
# Residual sum after 64 : 27091784.814416144
# Residual sum after 65 : 27038107.86629806
# Residual sum after 66 : 26984639.969120536
# Residual sum after 67 : 26931575.813063245
# Residual sum after 68 : 26878128.962525953
# Residual sum after 69 : 26824650.268417228
# Residual sum after 70 : 26771001.301130563
# Residual sum after 71 : 26717903.19684616
# Residual sum after 72 : 26664763.731989074
# Residual sum after 73 : 26611074.78062712
# Residual sum after 74 : 26557528.645522885
# Residual sum after 75 : 26504532.344631933
# Residual sum after 76 : 26452489.508454986
# Residual sum after 77 : 26399986.373956967
# Residual sum after 78 : 26347141.01467537
# Residual sum after 79 : 26294510.64480952
# Residual sum after 80 : 26242569.325705774
# Residual sum after 81 : 26190243.217225872
# Residual sum after 82 : 26138012.523918584
# Residual sum after 83 : 26085716.808563843
# Residual sum after 84 : 26034122.171241622
# Residual sum after 85 : 25981558.63796469
# Residual sum after 86 : 25929514.637831207
# Residual sum after 87 : 25877694.43836259
# Residual sum after 88 : 25825435.759405464
# Residual sum after 89 : 25773502.815848716
# Residual sum after 90 : 25722108.23282341
# Residual sum after 91 : 25671352.3332705
# Residual sum after 92 : 25620248.88007685
# Residual sum after 93 : 25569266.441244863
# Residual sum after 94 : 25518183.123590417
# Residual sum after 95 : 25468186.605669133
# Residual sum after 96 : 25418225.200944114
# Residual sum after 97 : 25367120.187158234
# Residual sum after 98 : 25316319.660201747
# Residual sum after 99 : 25265230.911782894
# Residual sum after 100 : 25215848.28512119
# Residual sum after 101 : 25165219.14601779
# Residual sum after 102 : 25114432.541025855
# Residual sum after 103 : 25064523.480403434
# Residual sum after 104 : 25014304.129458174
# Residual sum after 105 : 24963781.147175882
# Residual sum after 106 : 24914778.66211599
# Residual sum after 107 : 24864564.109930027
# Residual sum after 108 : 24814123.164276477
# Residual sum after 109 : 24764318.929339875
# Residual sum after 110 : 24713887.02053267
# Residual sum after 111 : 24664240.903728217
# Residual sum after 112 : 24613889.41651032
# Residual sum after 113 : 24563741.121542454
# Residual sum after 114 : 24513731.842612054
# Residual sum after 115 : 24463949.39772273
# Residual sum after 116 : 24414202.736420006
# Residual sum after 117 : 24364405.33349306
# Residual sum after 118 : 24315110.207131907
# Residual sum after 119 : 24265254.729999248
# Residual sum after 120 : 24216777.91830324
# Residual sum after 121 : 24166891.423128884
# Residual sum after 122 : 24117499.52149682
# Residual sum after 123 : 24067958.510709498
# Residual sum after 124 : 24018584.202574603
# Residual sum after 125 : 23969386.17591032
# Residual sum after 126 : 23920679.6737125
# Residual sum after 127 : 23871989.9807963
# Residual sum after 128 : 23822696.668028336
# Residual sum after 129 : 23773341.75106892
# Residual sum after 130 : 23724858.219554596
# Residual sum after 131 : 23676218.833560172
# Residual sum after 132 : 23627841.29380104
# Residual sum after 133 : 23578832.63222166
# Residual sum after 134 : 23530135.279700316
# Residual sum after 135 : 23481839.173483875
# Residual sum after 136 : 23433559.38932217
# Residual sum after 137 : 23385244.407464504
# Residual sum after 138 : 23337887.24330525
# Residual sum after 139 : 23290134.43085108
# Residual sum after 140 : 23242538.090416923
# Residual sum after 141 : 23194863.57307893
# Residual sum after 142 : 23147057.76174372
# Residual sum after 143 : 23099361.989610586
# Residual sum after 144 : 23051220.85173622
# Residual sum after 145 : 23004354.359054826
# Residual sum after 146 : 22958452.117573775
# Residual sum after 147 : 22910246.153179
# Residual sum after 148 : 22863378.44650338
# Residual sum after 149 : 22815380.850704078
# Residual sum after 150 : 22768528.875870973
# Residual sum after 151 : 22721740.52857701
# Residual sum after 152 : 22674710.84408798
# Residual sum after 153 : 22628445.084713
# Residual sum after 154 : 22581489.07889124
# Residual sum after 155 : 22534619.93144113
# Residual sum after 156 : 22488340.720270608
# Residual sum after 157 : 22441336.68982472
# Residual sum after 158 : 22394691.994337007
# Residual sum after 159 : 22347676.92739355
# Residual sum after 160 : 22301988.559444677
# Residual sum after 161 : 22255881.68052518
# Residual sum after 162 : 22210935.507901087
# Residual sum after 163 : 22166190.914419245
# Residual sum after 164 : 22120473.279169332
# Residual sum after 165 : 22076021.443557948
# Residual sum after 166 : 22030904.812707923
# Residual sum after 167 : 21986421.41068379
# Residual sum after 168 : 21942632.158957828
# Residual sum after 169 : 21897605.663233504
# Residual sum after 170 : 21852901.05305255
# Residual sum after 171 : 21808315.162165422
# Residual sum after 172 : 21765899.182211068
# Residual sum after 173 : 21723365.57949898
# Residual sum after 174 : 21680457.053866893
# Residual sum after 175 : 21638432.677560695
# Residual sum after 176 : 21594862.46818186
# Residual sum after 177 : 21552882.633983415
# Residual sum after 178 : 21509915.52910518
# Residual sum after 179 : 21466432.635065492
# Residual sum after 180 : 21422277.509164013
# Residual sum after 181 : 21380399.04241047
# Residual sum after 182 : 21337647.231636774
# Residual sum after 183 : 21295095.540118333
# Residual sum after 184 : 21252524.34866811
# Residual sum after 185 : 21211127.640770216
# Residual sum after 186 : 21170008.213614643
# Residual sum after 187 : 21128277.131721064
# Residual sum after 188 : 21085830.05321887
# Residual sum after 189 : 21045157.705276184
# Residual sum after 190 : 21002256.715041555
# Residual sum after 191 : 20960458.896993678
# Residual sum after 192 : 20919007.002498068
# Residual sum after 193 : 20876353.950039778
# Residual sum after 194 : 20834972.240288895
# Residual sum after 195 : 20793056.679787345
# Residual sum after 196 : 20752545.130787976
# Residual sum after 197 : 20710777.756044794
# Residual sum after 198 : 20669746.15791303
# Residual sum after 199 : 20627755.08063698
# Residual sum after 200 : 20587860.2854391
# Residual sum after 201 : 20547032.42505971
# Residual sum after 202 : 20505870.54101541
# Residual sum after 203 : 20464623.058686424
# Residual sum after 204 : 20424749.534864362
# Residual sum after 205 : 20384143.226362344
# Residual sum after 206 : 20344810.343144253
# Residual sum after 207 : 20303997.33293778
# Residual sum after 208 : 20263601.843606636
# Residual sum after 209 : 20223524.55800172
# Residual sum after 210 : 20183381.164907385
# Residual sum after 211 : 20142359.675060965
# Residual sum after 212 : 20101536.00752272
# Residual sum after 213 : 20060943.604385503
# Residual sum after 214 : 20022191.142294053
# Residual sum after 215 : 19981806.99446823
# Residual sum after 216 : 19942379.385465596
# Residual sum after 217 : 19902728.637197975
# Residual sum after 218 : 19863614.08490963
# Residual sum after 219 : 19824570.574563917
# Residual sum after 220 : 19784482.682675775
# Residual sum after 221 : 19744781.957514882
# Residual sum after 222 : 19704845.05363674
# Residual sum after 223 : 19665806.38354939
# Residual sum after 224 : 19626594.291276604
# Residual sum after 225 : 19588022.043768987
# Residual sum after 226 : 19547913.197824247
# Residual sum after 227 : 19508819.613983665
# Residual sum after 228 : 19469030.688074116
# Residual sum after 229 : 19429501.195769012
# Residual sum after 230 : 19390256.15631108
# Residual sum after 231 : 19350503.178102568
# Residual sum after 232 : 19312127.93259392
# Residual sum after 233 : 19273209.966811925
# Residual sum after 234 : 19234748.597650863
# Residual sum after 235 : 19195393.41316064
# Residual sum after 236 : 19155117.501937933
# Residual sum after 237 : 19116333.545555547
# Residual sum after 238 : 19077867.296457503
# Residual sum after 239 : 19038727.069778178
# Residual sum after 240 : 18999547.97339749
# Residual sum after 241 : 18960920.099150207
# Residual sum after 242 : 18922106.81375503
# Residual sum after 243 : 18882897.87256437
# Residual sum after 244 : 18844055.40513934
# Residual sum after 245 : 18805781.836750183
# Residual sum after 246 : 18767692.95431694
# Residual sum after 247 : 18729833.80637471
# Residual sum after 248 : 18692827.914063044
# Residual sum after 249 : 18654496.17754488
# Residual sum after 250 : 18616296.222123366
# Residual sum after 251 : 18578113.76580948
# Residual sum after 252 : 18540139.268622182
# Residual sum after 253 : 18501342.87025733
# Residual sum after 254 : 18463801.74474636
# Residual sum after 255 : 18427089.201974843
# Residual sum after 256 : 18389939.069932833
# Residual sum after 257 : 18351963.65394221
# Residual sum after 258 : 18315250.52730743
# Residual sum after 259 : 18277538.78256662
# Residual sum after 260 : 18240269.937956672
# Residual sum after 261 : 18203010.96470664
# Residual sum after 262 : 18166931.47965655
# Residual sum after 263 : 18129876.131098907
# Residual sum after 264 : 18092451.630428825
# Residual sum after 265 : 18055347.265671346
# Residual sum after 266 : 18018229.018160135
# Residual sum after 267 : 17981977.320844416
# Residual sum after 268 : 17944640.559554063
# Residual sum after 269 : 17907862.13231907
# Residual sum after 270 : 17870568.80542125
# Residual sum after 271 : 17834786.427406915
# Residual sum after 272 : 17798677.197786804
# Residual sum after 273 : 17762683.840858184
# Residual sum after 274 : 17725319.22958937
# Residual sum after 275 : 17688127.884724345
# Residual sum after 276 : 17652580.930732064
# Residual sum after 277 : 17616174.37778551
# Residual sum after 278 : 17578864.298704237
# Residual sum after 279 : 17541469.176147982
# Residual sum after 280 : 17505689.51383082
# Residual sum after 281 : 17469685.14041362
# Residual sum after 282 : 17432980.838000868
# Residual sum after 283 : 17397255.990822297
# Residual sum after 284 : 17361941.63686059
# Residual sum after 285 : 17325930.863713253
# Residual sum after 286 : 17289959.33374665
# Residual sum after 287 : 17253889.741960008
# Residual sum after 288 : 17218028.129236035
# Residual sum after 289 : 17182170.258272294
# Residual sum after 290 : 17145939.598085225
# Residual sum after 291 : 17109745.463899612
# Residual sum after 292 : 17074560.07065317
# Residual sum after 293 : 17039714.094713755
# Residual sum after 294 : 17003866.14500787
# Residual sum after 295 : 16967704.64670452
# Residual sum after 296 : 16931645.25957301
# Residual sum after 297 : 16896490.075553134
# Residual sum after 298 : 16862016.78380516
# Residual sum after 299 : 16827203.749196757
# Residual sum after 300 : 16790893.359883875
# Residual sum after 301 : 16756623.92136628
# Residual sum after 302 : 16720712.84300138
# Residual sum after 303 : 16685915.147540232
# Residual sum after 304 : 16650482.350845309
# Residual sum after 305 : 16616176.708201783
# Residual sum after 306 : 16581050.486804299
# Residual sum after 307 : 16546473.301159805
# Residual sum after 308 : 16511580.250795685
# Residual sum after 309 : 16476556.739217374
# Residual sum after 310 : 16442154.263688367
# Residual sum after 311 : 16407173.637917312
# Residual sum after 312 : 16372429.092031155
# Residual sum after 313 : 16337725.877229663
# Residual sum after 314 : 16303499.49078633
# Residual sum after 315 : 16269416.236298958
# Residual sum after 316 : 16234587.40156649
# Residual sum after 317 : 16200149.21150914
# Residual sum after 318 : 16165811.416947415
# Residual sum after 319 : 16131669.641103406
# Residual sum after 320 : 16097580.048247326
# Residual sum after 321 : 16064635.339675935
# Residual sum after 322 : 16030583.734392818
# Residual sum after 323 : 15997064.854705872
# Residual sum after 324 : 15963312.820829611
# Residual sum after 325 : 15929331.25485953
# Residual sum after 326 : 15895040.511786906
# Residual sum after 327 : 15861447.842686718
# Residual sum after 328 : 15827753.918247255
# Residual sum after 329 : 15793637.27120304
# Residual sum after 330 : 15760234.705888756
# Residual sum after 331 : 15726704.876892444
# Residual sum after 332 : 15693526.003433712
# Residual sum after 333 : 15660073.851236742
# Residual sum after 334 : 15625975.517603254
# Residual sum after 335 : 15593883.554764647
# Residual sum after 336 : 15560278.607202021
# Residual sum after 337 : 15527349.538471729
# Residual sum after 338 : 15494799.359277498
# Residual sum after 339 : 15461672.265716067
# Residual sum after 340 : 15429395.29398714
# Residual sum after 341 : 15397114.38367544
# Residual sum after 342 : 15364296.900195347
# Residual sum after 343 : 15331805.98019625
# Residual sum after 344 : 15299526.94961354
# Residual sum after 345 : 15267308.297462275
# Residual sum after 346 : 15234518.185284106
# Residual sum after 347 : 15202353.023469146
# Residual sum after 348 : 15170741.30971545
# Residual sum after 349 : 15139451.013963943
# Residual sum after 350 : 15107369.505529838
# Residual sum after 351 : 15075594.911863266
# Residual sum after 352 : 15044128.806555523
# Residual sum after 353 : 15012744.855122766
# Residual sum after 354 : 14980613.159743119
# Residual sum after 355 : 14949523.745804604
# Residual sum after 356 : 14917710.918262288
# Residual sum after 357 : 14885298.063865317
# Residual sum after 358 : 14854016.321324151
# Residual sum after 359 : 14822120.764200369
# Residual sum after 360 : 14790444.7886495
# Residual sum after 361 : 14759413.388820283
# Residual sum after 362 : 14727826.531270586
# Residual sum after 363 : 14696221.458696455
# Residual sum after 364 : 14665122.788252406
# Residual sum after 365 : 14634561.647897633
# Residual sum after 366 : 14601797.278812071
# Residual sum after 367 : 14571005.174540564
# Residual sum after 368 : 14540105.69245269
# Residual sum after 369 : 14509578.30193902
# Residual sum after 370 : 14478907.461609881
# Residual sum after 371 : 14447636.991047652
# Residual sum after 372 : 14416017.81902223
# Residual sum after 373 : 14384677.526175426
# Residual sum after 374 : 14353369.979433442
# Residual sum after 375 : 14322489.756230248
# Residual sum after 376 : 14291283.352123972
# Residual sum after 377 : 14261648.845363256
# Residual sum after 378 : 14230519.027192887
# Residual sum after 379 : 14200422.02295282
# Residual sum after 380 : 14170819.168601632
# Residual sum after 381 : 14140515.91075164
# Residual sum after 382 : 14110086.81636295
# Residual sum after 383 : 14079678.41698209
# Residual sum after 384 : 14049522.334992014
# Residual sum after 385 : 14019513.34629144
# Residual sum after 386 : 13989314.468313
# Residual sum after 387 : 13958882.709188085
# Residual sum after 388 : 13928267.384405429
# Residual sum after 389 : 13898430.38172469
# Residual sum after 390 : 13868610.501177192
# Residual sum after 391 : 13838806.19371208
# Residual sum after 392 : 13808475.237392852
# Residual sum after 393 : 13778415.813137727
# Residual sum after 394 : 13748684.06472371
# Residual sum after 395 : 13718814.377318691
# Residual sum after 396 : 13688308.474533543
# Residual sum after 397 : 13658007.317704767
# Residual sum after 398 : 13627879.850136308
# Residual sum after 399 : 13598656.878836902
# Residual sum after 400 : 13568383.45756
# Residual sum after 401 : 13538151.596633319
# Residual sum after 402 : 13507862.390695246
# Residual sum after 403 : 13478620.543394338
# Residual sum after 404 : 13448266.6270559
# Residual sum after 405 : 13418560.331547532
# Residual sum after 406 : 13389275.940528948
# Residual sum after 407 : 13359908.839186572
# Residual sum after 408 : 13329517.892539434
# Residual sum after 409 : 13301058.067697369
# Residual sum after 410 : 13271923.19419669
# Residual sum after 411 : 13243096.80601066
# Residual sum after 412 : 13213226.369140876
# Residual sum after 413 : 13183998.04479615
# Residual sum after 414 : 13155477.126236595
# Residual sum after 415 : 13126027.6512901
# Residual sum after 416 : 13097765.231394356
# Residual sum after 417 : 13068597.533965677
# Residual sum after 418 : 13039693.544136683
# Residual sum after 419 : 13010698.487004122
# Residual sum after 420 : 12982160.963709535
# Residual sum after 421 : 12953481.039768113
# Residual sum after 422 : 12925364.89817439
# Residual sum after 423 : 12896761.467601098
# Residual sum after 424 : 12868331.338643288
# Residual sum after 425 : 12839147.15076219
# Residual sum after 426 : 12810937.066855814
# Residual sum after 427 : 12781813.375872497
# Residual sum after 428 : 12753805.076999804
# Residual sum after 429 : 12725958.030977633
# Residual sum after 430 : 12697482.747660967
# Residual sum after 431 : 12669503.31993118
# Residual sum after 432 : 12641627.915382612
# Residual sum after 433 : 12613216.030817332
# Residual sum after 434 : 12585357.181625022
# Residual sum after 435 : 12558022.996635329
# Residual sum after 436 : 12528433.533203514
# Residual sum after 437 : 12500256.846709782
# Residual sum after 438 : 12472513.092598611
# Residual sum after 439 : 12444040.152399616
# Residual sum after 440 : 12416677.627732897
# Residual sum after 441 : 12389464.965505634
# Residual sum after 442 : 12361656.894745095
# Residual sum after 443 : 12334445.861800216
# Residual sum after 444 : 12306021.69114433
# Residual sum after 445 : 12278448.086338254
# Residual sum after 446 : 12250924.63754695
# Residual sum after 447 : 12223771.206289805
# Residual sum after 448 : 12196579.864625795
# Residual sum after 449 : 12168803.160617102
# Residual sum after 450 : 12141518.607771862
# Residual sum after 451 : 12113753.913260657
# Residual sum after 452 : 12086235.17074083
# Residual sum after 453 : 12058008.192989388
# Residual sum after 454 : 12029434.176647322
# Residual sum after 455 : 12001876.874296362
# Residual sum after 456 : 11974570.762941886
# Residual sum after 457 : 11947732.70055491
# Residual sum after 458 : 11919709.005364275
# Residual sum after 459 : 11892505.987524005
# Residual sum after 460 : 11866197.66958011
# Residual sum after 461 : 11838879.209016826
# Residual sum after 462 : 11812015.496640047
# Residual sum after 463 : 11785343.665544437
# Residual sum after 464 : 11758763.71025071
# Residual sum after 465 : 11731970.391310092
# Residual sum after 466 : 11704285.66968292
# Residual sum after 467 : 11676872.998155894
# Residual sum after 468 : 11650297.381920736
# Residual sum after 469 : 11623552.879336102
# Residual sum after 470 : 11597234.880739355
# Residual sum after 471 : 11570381.490480173
# Residual sum after 472 : 11543978.758611523
# Residual sum after 473 : 11516657.162009535
# Residual sum after 474 : 11489523.166846031
# Residual sum after 475 : 11462506.328149388
# Residual sum after 476 : 11436677.673345437
# Residual sum after 477 : 11409963.958579991
# Residual sum after 478 : 11384006.076658404
# Residual sum after 479 : 11358239.7422415
# Residual sum after 480 : 11332082.897588683
# Residual sum after 481 : 11306237.283037746
# Residual sum after 482 : 11279883.030233983
# Residual sum after 483 : 11253652.820977839
# Residual sum after 484 : 11228249.56153177
# Residual sum after 485 : 11202989.086854737
# Residual sum after 486 : 11176947.64420486
# Residual sum after 487 : 11150337.877775107
# Residual sum after 488 : 11125173.747142754
# Residual sum after 489 : 11099588.400755798
# Residual sum after 490 : 11072807.991656767
# Residual sum after 491 : 11047052.910673749
# Residual sum after 492 : 11021857.4360662
# Residual sum after 493 : 10996106.377665274
# Residual sum after 494 : 10971328.898504373
# Residual sum after 495 : 10946199.76119464
# Residual sum after 496 : 10921699.28226791
# Residual sum after 497 : 10895728.818081206
# Residual sum after 498 : 10870443.997766612
# Residual sum after 499 : 10845942.430795372
# Residual sum after 500 : 10820021.984834395
# Residual sum after 501 : 10795868.941381525
# Residual sum after 502 : 10769597.997759156
# Residual sum after 503 : 10744416.809216991
# Residual sum after 504 : 10720548.202414127
# Residual sum after 505 : 10694659.590248523
# Residual sum after 506 : 10668900.008486234
# Residual sum after 507 : 10643265.89496101
# Residual sum after 508 : 10618441.96125669
# Residual sum after 509 : 10592450.417690732
# Residual sum after 510 : 10568066.2649525
# Residual sum after 511 : 10543619.44295915
# Residual sum after 512 : 10518466.343952175
# Residual sum after 513 : 10493928.592278259
# Residual sum after 514 : 10469001.9474604
# Residual sum after 515 : 10444256.634454608
# Residual sum after 516 : 10418389.795707336
# Residual sum after 517 : 10394722.96589654
# Residual sum after 518 : 10369168.891820736
# Residual sum after 519 : 10344912.63769976
# Residual sum after 520 : 10320284.378136594
# Residual sum after 521 : 10295640.735198298
# Residual sum after 522 : 10271449.426731177
# Residual sum after 523 : 10247280.594626855
# Residual sum after 524 : 10222807.7400516
# Residual sum after 525 : 10198242.381040968
# Residual sum after 526 : 10173907.648419805
# Residual sum after 527 : 10149020.098866018
# Residual sum after 528 : 10124465.994113898
# Residual sum after 529 : 10099970.28630301
# Residual sum after 530 : 10076384.015679646
# Residual sum after 531 : 10052131.27935373
# Residual sum after 532 : 10027183.601121673
# Residual sum after 533 : 10003556.79542904
# Residual sum after 534 : 9979945.839038339
# Residual sum after 535 : 9955574.665044801
# Residual sum after 536 : 9931494.247004544
# Residual sum after 537 : 9907568.966592563
# Residual sum after 538 : 9883440.795832487
# Residual sum after 539 : 9859849.293543458
# Residual sum after 540 : 9836839.878872462
# Residual sum after 541 : 9813190.316275818
# Residual sum after 542 : 9788769.506374275
# Residual sum after 543 : 9764558.757364929
# Residual sum after 544 : 9740306.376412744
# Residual sum after 545 : 9716093.593599178
# Residual sum after 546 : 9692408.623613102
# Residual sum after 547 : 9668785.317368161
# Residual sum after 548 : 9645833.21460978
# Residual sum after 549 : 9621881.091545032
# Residual sum after 550 : 9597804.303703316
# Residual sum after 551 : 9573890.35278951
# Residual sum after 552 : 9551160.133072512
# Residual sum after 553 : 9528181.155121872
# Residual sum after 554 : 9505376.108691422
# Residual sum after 555 : 9481930.293544961
# Residual sum after 556 : 9457985.809574047
# Residual sum after 557 : 9434318.849176155
# Residual sum after 558 : 9411326.926623652
# Residual sum after 559 : 9388256.1285798
# Residual sum after 560 : 9365168.741906386
# Residual sum after 561 : 9342627.219515588
# Residual sum after 562 : 9318762.38858736
# Residual sum after 563 : 9295653.286251886
# Residual sum after 564 : 9272179.291395964
# Residual sum after 565 : 9250874.55052863
# Residual sum after 566 : 9227989.553730816
# Residual sum after 567 : 9205456.494101929
# Residual sum after 568 : 9182802.524547447
# Residual sum after 569 : 9160239.277006136
# Residual sum after 570 : 9137943.039354227
# Residual sum after 571 : 9116235.111199794
# Residual sum after 572 : 9093899.802516045
# Residual sum after 573 : 9071836.035596177
# Residual sum after 574 : 9049447.575268632
# Residual sum after 575 : 9027293.085402919
# Residual sum after 576 : 9005005.71649285
# Residual sum after 577 : 8983471.174750984
# Residual sum after 578 : 8961667.89344285
# Residual sum after 579 : 8940246.971766654
# Residual sum after 580 : 8917374.897733368
# Residual sum after 581 : 8896241.860000297
# Residual sum after 582 : 8874741.741398694
# Residual sum after 583 : 8853882.150994452
# Residual sum after 584 : 8831778.68384906
# Residual sum after 585 : 8809806.756923862
# Residual sum after 586 : 8788773.017933916
# Residual sum after 587 : 8767349.163671868
# Residual sum after 588 : 8745122.236538958
# Residual sum after 589 : 8723388.01030237
# Residual sum after 590 : 8701430.423720784
# Residual sum after 591 : 8679816.99459966
# Residual sum after 592 : 8658645.403210947
# Residual sum after 593 : 8637255.307198869
# Residual sum after 594 : 8615261.205184504
# Residual sum after 595 : 8593824.508000316
# Residual sum after 596 : 8572827.615564974
# Residual sum after 597 : 8551615.564274171
# Residual sum after 598 : 8530168.634321023
# Residual sum after 599 : 8509786.180997925
# Residual sum after 600 : 8489364.704155631
# Residual sum after 601 : 8467162.707988843
# Residual sum after 602 : 8445557.093752932
# Residual sum after 603 : 8423060.18041976
# Residual sum after 604 : 8402541.680286577
# Residual sum after 605 : 8382038.696488395
# Residual sum after 606 : 8360456.3104592515
# Residual sum after 607 : 8339077.983658278
# Residual sum after 608 : 8317957.821219637
# Residual sum after 609 : 8297106.733136797
# Residual sum after 610 : 8276560.538841729
# Residual sum after 611 : 8255196.995776816
# Residual sum after 612 : 8232689.198208008
# Residual sum after 613 : 8211328.518664481
# Residual sum after 614 : 8190827.57512302
# Residual sum after 615 : 8170237.430413251
# Residual sum after 616 : 8150223.028335309
# Residual sum after 617 : 8130328.465088535
# Residual sum after 618 : 8108190.4474355485
# Residual sum after 619 : 8088376.144227353
# Residual sum after 620 : 8068034.2865880625
# Residual sum after 621 : 8046702.124538689
# Residual sum after 622 : 8025161.905109386
# Residual sum after 623 : 8004828.988999754
# Residual sum after 624 : 7984408.0153945135
# Residual sum after 625 : 7963576.5345836235
# Residual sum after 626 : 7943824.285985728
# Residual sum after 627 : 7924702.778483058
# Residual sum after 628 : 7905101.657261557
# Residual sum after 629 : 7884913.91969455
# Residual sum after 630 : 7864774.381585939
# Residual sum after 631 : 7845496.243768858
# Residual sum after 632 : 7824518.143749276
# Residual sum after 633 : 7804942.8029820565
# Residual sum after 634 : 7783861.107374402
# Residual sum after 635 : 7764736.053985089
# Residual sum after 636 : 7745568.205630313
# Residual sum after 637 : 7726075.066292484
# Residual sum after 638 : 7706395.603127515
# Residual sum after 639 : 7685959.892058238
# Residual sum after 640 : 7664375.236422959
# Residual sum after 641 : 7644349.487508538
# Residual sum after 642 : 7624779.9626210565
# Residual sum after 643 : 7604870.231241145
# Residual sum after 644 : 7584761.843475296
# Residual sum after 645 : 7564999.598637264
# Residual sum after 646 : 7545302.988317137
# Residual sum after 647 : 7525636.882049344
# Residual sum after 648 : 7507173.881283912
# Residual sum after 649 : 7486212.855650206
# Residual sum after 650 : 7465355.165950989
# Residual sum after 651 : 7445979.05250603
# Residual sum after 652 : 7426240.369623721
# Residual sum after 653 : 7406392.588422483
# Residual sum after 654 : 7387190.227322185
# Residual sum after 655 : 7367506.624486659
# Residual sum after 656 : 7348364.903007403
# Residual sum after 657 : 7328916.299973887
# Residual sum after 658 : 7309825.668735686
# Residual sum after 659 : 7291256.988771335
# Residual sum after 660 : 7272231.895878521
# Residual sum after 661 : 7253233.542263863
# Residual sum after 662 : 7233478.9602183895
# Residual sum after 663 : 7213994.4788187975
# Residual sum after 664 : 7194408.483946668
# Residual sum after 665 : 7175832.876022318
# Residual sum after 666 : 7157285.697150634
# Residual sum after 667 : 7137961.751402469
# Residual sum after 668 : 7118725.018777896
# Residual sum after 669 : 7098440.7764146635
# Residual sum after 670 : 7080039.95773525
# Residual sum after 671 : 7061817.798794365
# Residual sum after 672 : 7042688.932614233
# Residual sum after 673 : 7024129.512364596
# Residual sum after 674 : 7005011.438540637
# Residual sum after 675 : 6986289.350414466
# Residual sum after 676 : 6967459.0018784255
# Residual sum after 677 : 6949290.694308419
# Residual sum after 678 : 6930935.18639667
# Residual sum after 679 : 6911817.032693406
# Residual sum after 680 : 6893793.08161465
# Residual sum after 681 : 6874724.247113425
# Residual sum after 682 : 6856309.099472574
# Residual sum after 683 : 6837856.017432498
# Residual sum after 684 : 6819645.303748248
# Residual sum after 685 : 6802648.345053789
# Residual sum after 686 : 6784059.873014482
# Residual sum after 687 : 6766453.932121653
# Residual sum after 688 : 6747406.793132343
# Residual sum after 689 : 6729004.099227945
# Residual sum after 690 : 6709618.090832552
# Residual sum after 691 : 6691341.375377783
# Residual sum after 692 : 6672306.299537616
# Residual sum after 693 : 6653882.9688076405
# Residual sum after 694 : 6635418.880544178
# Residual sum after 695 : 6617144.762433371
# Residual sum after 696 : 6599624.368607159
# Residual sum after 697 : 6581783.390396346
# Residual sum after 698 : 6562521.287169224
# Residual sum after 699 : 6544863.507394807
# Residual sum after 700 : 6527610.7660383405
# Residual sum after 701 : 6509204.378017145
# Residual sum after 702 : 6490145.272141239
# Residual sum after 703 : 6472771.340319117
# Residual sum after 704 : 6455962.615769877
# Residual sum after 705 : 6438915.284045298
# Residual sum after 706 : 6420922.993807319
# Residual sum after 707 : 6402797.493518712
# Residual sum after 708 : 6384485.001619524
# Residual sum after 709 : 6366752.672860874
# Residual sum after 710 : 6348689.536173421
# Residual sum after 711 : 6333098.355590318
# Residual sum after 712 : 6316491.4271992855
# Residual sum after 713 : 6299974.9809676455
# Residual sum after 714 : 6282846.447566084
# Residual sum after 715 : 6265087.448832552
# Residual sum after 716 : 6246654.865013814
# Residual sum after 717 : 6229014.686793939
# Residual sum after 718 : 6211675.399828611
# Residual sum after 719 : 6193776.554869504
# Residual sum after 720 : 6176059.392153638
# Residual sum after 721 : 6159654.573494837
# Residual sum after 722 : 6143094.148472282
# Residual sum after 723 : 6125056.774966279
# Residual sum after 724 : 6108604.733413079
# Residual sum after 725 : 6090699.286547844
# Residual sum after 726 : 6072543.800364897
# Residual sum after 727 : 6055293.644634319
# Residual sum after 728 : 6037630.03674248
# Residual sum after 729 : 6020634.2816874115
# Residual sum after 730 : 6003364.499415683
# Residual sum after 731 : 5986277.6966345785
# Residual sum after 732 : 5969615.811796263
# Residual sum after 733 : 5951930.062393509
# Residual sum after 734 : 5935733.841444809
# Residual sum after 735 : 5918530.330487968
# Residual sum after 736 : 5902017.044796665
# Residual sum after 737 : 5884559.649167533
# Residual sum after 738 : 5868851.818690849
# Residual sum after 739 : 5853467.404443027
# Residual sum after 740 : 5837250.721921361
# Residual sum after 741 : 5821131.891611179
# Residual sum after 742 : 5805157.698581759
# Residual sum after 743 : 5787957.0674551185
# Residual sum after 744 : 5771639.643381826
# Residual sum after 745 : 5754385.849035856
# Residual sum after 746 : 5738728.610669444
# Residual sum after 747 : 5723141.451735691
# Residual sum after 748 : 5706742.672751882
# Residual sum after 749 : 5689920.461801722
# Residual sum after 750 : 5674419.785899147
# Residual sum after 751 : 5658866.478424224
# Residual sum after 752 : 5642939.637706068
# Residual sum after 753 : 5626894.515393243
# Residual sum after 754 : 5610280.974454718
# Residual sum after 755 : 5594063.551943153
# Residual sum after 756 : 5578471.226221111
# Residual sum after 757 : 5563049.309618771
# Residual sum after 758 : 5546390.6749163
# Residual sum after 759 : 5529842.91705182
# Residual sum after 760 : 5514211.223686014
# Residual sum after 761 : 5498188.160242348
# Residual sum after 762 : 5481511.622353731
# Residual sum after 763 : 5465213.833909116
# Residual sum after 764 : 5450132.1811334435
# Residual sum after 765 : 5435699.471053646
# Residual sum after 766 : 5421356.536371854
# Residual sum after 767 : 5403385.770041165
# Residual sum after 768 : 5387193.173329205
# Residual sum after 769 : 5371312.761919514
# Residual sum after 770 : 5355640.88421984
# Residual sum after 771 : 5339266.296714101
# Residual sum after 772 : 5324611.303066388
# Residual sum after 773 : 5309518.622670582
# Residual sum after 774 : 5294837.70003601
# Residual sum after 775 : 5279719.083151548
# Residual sum after 776 : 5263880.9724150775
# Residual sum after 777 : 5248501.6673695035
# Residual sum after 778 : 5234284.909317947
# Residual sum after 779 : 5218380.917720479
# Residual sum after 780 : 5201807.280271807
# Residual sum after 781 : 5186191.344425696
# Residual sum after 782 : 5172048.707534025
# Residual sum after 783 : 5157780.929683379
# Residual sum after 784 : 5143486.723417014
# Residual sum after 785 : 5129331.666793666
# Residual sum after 786 : 5113556.239988556
# Residual sum after 787 : 5097841.372764695
# Residual sum after 788 : 5082482.432217121
# Residual sum after 789 : 5068212.634943088
# Residual sum after 790 : 5052836.0368440375
# Residual sum after 791 : 5038351.479894434
# Residual sum after 792 : 5024227.224519392
# Residual sum after 793 : 5008947.413061509
# Residual sum after 794 : 4993981.86663591
# Residual sum after 795 : 4980376.461686734
# Residual sum after 796 : 4964963.777978795
# Residual sum after 797 : 4949658.682617315
# Residual sum after 798 : 4935764.159741985
# Residual sum after 799 : 4920690.847014984
# Residual sum after 800 : 4906287.8607208785
# Residual sum after 801 : 4891360.343577752
# Residual sum after 802 : 4876444.692991324
# Residual sum after 803 : 4861534.849950794
# Residual sum after 804 : 4846371.734379647
# Residual sum after 805 : 4833557.678001031
# Residual sum after 806 : 4818576.983008576
# Residual sum after 807 : 4805106.798360351
# Residual sum after 808 : 4790908.169673688
# Residual sum after 809 : 4774557.87292785
# Residual sum after 810 : 4760109.451525458
# Residual sum after 811 : 4744816.284971068
# Residual sum after 812 : 4727777.5671442095
# Residual sum after 813 : 4713094.847361649
# Residual sum after 814 : 4698086.024936178
# Residual sum after 815 : 4685334.29716752
# Residual sum after 816 : 4670421.8066973565
# Residual sum after 817 : 4655584.805547954
# Residual sum after 818 : 4642420.921356897
# Residual sum after 819 : 4629127.32536265
# Residual sum after 820 : 4615161.821952344
# Residual sum after 821 : 4602605.471979852
# Residual sum after 822 : 4588796.085689594
# Residual sum after 823 : 4576317.15189067
# Residual sum after 824 : 4561518.011115461
# Residual sum after 825 : 4547466.947992344
# Residual sum after 826 : 4533221.239535781
# Residual sum after 827 : 4520862.071548899
# Residual sum after 828 : 4507362.241352556
# Residual sum after 829 : 4490586.042814085
# Residual sum after 830 : 4475006.111644692
# Residual sum after 831 : 4460859.999721782
# Residual sum after 832 : 4443979.182845239
# Residual sum after 833 : 4429949.212545199
# Residual sum after 834 : 4417482.381457014
# Residual sum after 835 : 4403559.077378463
# Residual sum after 836 : 4389380.181913134
# Residual sum after 837 : 4375143.462316237
# Residual sum after 838 : 4361167.804464939
# Residual sum after 839 : 4347252.628719072
# Residual sum after 840 : 4335204.175159851
# Residual sum after 841 : 4322013.4162757965
# Residual sum after 842 : 4307876.468282644
# Residual sum after 843 : 4294047.612869529
# Residual sum after 844 : 4279808.885875399
# Residual sum after 845 : 4265906.697958677
# Residual sum after 846 : 4251514.120998775
# Residual sum after 847 : 4239064.207118855
# Residual sum after 848 : 4226530.606197383
# Residual sum after 849 : 4214270.495850397
# Residual sum after 850 : 4202020.051484132
# Residual sum after 851 : 4188335.2466375898
# Residual sum after 852 : 4174642.76590492
# Residual sum after 853 : 4160700.2680008844
# Residual sum after 854 : 4146985.407827696
# Residual sum after 855 : 4134713.7121017915
# Residual sum after 856 : 4121736.309642527
# Residual sum after 857 : 4106072.7769988324
# Residual sum after 858 : 4092711.0099695656
# Residual sum after 859 : 4080928.5278354143
# Residual sum after 860 : 4067735.8840982397
# Residual sum after 861 : 4054203.4538756744
# Residual sum after 862 : 4040995.5156017784
# Residual sum after 863 : 4029028.783026389
# Residual sum after 864 : 4016703.868806249
# Residual sum after 865 : 4005327.7782100067
# Residual sum after 866 : 3990521.7869946086
# Residual sum after 867 : 3977568.080877847
# Residual sum after 868 : 3962632.2250939896
# Residual sum after 869 : 3949925.9919408504
# Residual sum after 870 : 3936848.295156082
# Residual sum after 871 : 3924271.027100841
# Residual sum after 872 : 3912392.1349214865
# Residual sum after 873 : 3900179.3384325206
# Residual sum after 874 : 3888887.490371326
# Residual sum after 875 : 3877346.641831034
# Residual sum after 876 : 3864714.727172788
# Residual sum after 877 : 3851360.617863691
# Residual sum after 878 : 3838427.738025031
# Residual sum after 879 : 3824562.839720923
# Residual sum after 880 : 3812478.1123176967
# Residual sum after 881 : 3798468.5407616985
# Residual sum after 882 : 3786625.722415171
# Residual sum after 883 : 3774273.3007173105
# Residual sum after 884 : 3763154.427686585
# Residual sum after 885 : 3750044.7686169334
# Residual sum after 886 : 3737618.683501307
# Residual sum after 887 : 3725799.35560085
# Residual sum after 888 : 3711968.5963618034
# Residual sum after 889 : 3700586.9905732656
# Residual sum after 890 : 3688010.9695341773
# Residual sum after 891 : 3673908.2964472924
# Residual sum after 892 : 3660810.0663276883
# Residual sum after 893 : 3648713.8018634263
# Residual sum after 894 : 3635982.5193262557
# Residual sum after 895 : 3623838.9916815716
# Residual sum after 896 : 3612266.8522467967
# Residual sum after 897 : 3601060.5475323917
# Residual sum after 898 : 3589930.099218729
# Residual sum after 899 : 3577046.2192435726
# Residual sum after 900 : 3565554.3753795824
# Residual sum after 901 : 3555023.4117307537
# Residual sum after 902 : 3541631.972683618
# Residual sum after 903 : 3530327.279582847
# Residual sum after 904 : 3517396.4710842883
# Residual sum after 905 : 3506899.2882922227
# Residual sum after 906 : 3495520.5712780817
# Residual sum after 907 : 3481671.241655172
# Residual sum after 908 : 3471438.939915381
# Residual sum after 909 : 3460805.155392333
# Residual sum after 910 : 3450519.156485797
# Residual sum after 911 : 3439186.3721975624
# Residual sum after 912 : 3425491.6830207435
# Residual sum after 913 : 3414053.322224662
# Residual sum after 914 : 3402444.9890955747
# Residual sum after 915 : 3392189.1945381477
# Residual sum after 916 : 3381282.9378223964
# Residual sum after 917 : 3371141.227434997
# Residual sum after 918 : 3359637.2515511983
# Residual sum after 919 : 3349611.724951488
# Residual sum after 920 : 3338072.00700513
# Residual sum after 921 : 3328219.780220442
# Residual sum after 922 : 3316931.7700147512
# Residual sum after 923 : 3306910.6681992216
# Residual sum after 924 : 3294069.2336754897
# Residual sum after 925 : 3282747.267856714
# Residual sum after 926 : 3272034.819962003
# Residual sum after 927 : 3261411.397906739
# Residual sum after 928 : 3248037.19984754
# Residual sum after 929 : 3238179.569469386
# Residual sum after 930 : 3227662.9961861013
# Residual sum after 931 : 3217170.491830314
# Residual sum after 932 : 3206104.0475651734
# Residual sum after 933 : 3195729.04646378
# Residual sum after 934 : 3185061.097547635
# Residual sum after 935 : 3174829.119780514
# Residual sum after 936 : 3164919.4830194293
# Residual sum after 937 : 3154881.8496973417
# Residual sum after 938 : 3144412.474520593
# Residual sum after 939 : 3133773.0807827525
# Residual sum after 940 : 3121377.7739431993
# Residual sum after 941 : 3111356.5905220727
# Residual sum after 942 : 3101425.6110425587
# Residual sum after 943 : 3088766.9714461146
# Residual sum after 944 : 3078412.469739931
# Residual sum after 945 : 3068739.830861239
# Residual sum after 946 : 3059407.0439913324
# Residual sum after 947 : 3049594.6975725046
# Residual sum after 948 : 3038677.790534097
# Residual sum after 949 : 3028310.8832155587
# Residual sum after 950 : 3018942.7679736856
# Residual sum after 951 : 3006605.6106758034
# Residual sum after 952 : 2995417.771126795
# Residual sum after 953 : 2983888.8428765857
# Residual sum after 954 : 2973869.0182817196
# Residual sum after 955 : 2962801.877290062
# Residual sum after 956 : 2953483.3758668113
# Residual sum after 957 : 2940506.9274779186
# Residual sum after 958 : 2930634.852242682
# Residual sum after 959 : 2921697.62601545
# Residual sum after 960 : 2912414.4104898926
# Residual sum after 961 : 2902965.4037530874
# Residual sum after 962 : 2892928.7495849314
# Residual sum after 963 : 2883469.7722353833
# Residual sum after 964 : 2874188.904210295
# Residual sum after 965 : 2863587.0670201574
# Residual sum after 966 : 2853712.514013601
# Residual sum after 967 : 2841645.8084557382
# Residual sum after 968 : 2831787.1553744734
# Residual sum after 969 : 2821482.93183393
# Residual sum after 970 : 2811287.3152878187
# Residual sum after 971 : 2801926.607923139
# Residual sum after 972 : 2792769.415847658
# Residual sum after 973 : 2783047.616414378
# Residual sum after 974 : 2772845.0864876043
# Residual sum after 975 : 2760489.952936304
# Residual sum after 976 : 2751912.195920443
# Residual sum after 977 : 2741828.594354422
# Residual sum after 978 : 2733179.0762338787
# Residual sum after 979 : 2723897.1204596283
# Residual sum after 980 : 2714797.501006286
# Residual sum after 981 : 2706208.1437291885
# Residual sum after 982 : 2696777.693930179
# Residual sum after 983 : 2687035.6922516623
# Residual sum after 984 : 2678560.125284612
# Residual sum after 985 : 2668175.605542532
# Residual sum after 986 : 2657612.807686788
# Residual sum after 987 : 2646167.6513169203
# Residual sum after 988 : 2634645.0456386246
# Residual sum after 989 : 2625901.6382381674
# Residual sum after 990 : 2616411.948343645
# Residual sum after 991 : 2604497.738565119
# Residual sum after 992 : 2594022.3177868132
# Residual sum after 993 : 2583376.885817788
# Residual sum after 994 : 2573719.062804908
# Residual sum after 995 : 2563643.9340144033
# Residual sum after 996 : 2552840.8484746064
# Residual sum after 997 : 2541280.130834996
# Residual sum after 998 : 2533121.231975287
# Residual sum after 999 : 2522584.4344650456
# Residual sum after 1000 : 2513847.865051902
# Residual sum after 1001 : 2505472.427089132
# Residual sum after 1002 : 2496415.4523685174
# Residual sum after 1003 : 2487971.127129369
# Residual sum after 1004 : 2478807.5813061944
# Residual sum after 1005 : 2469010.961724267
# Residual sum after 1006 : 2460287.3820716543
# Residual sum after 1007 : 2449816.7971672798
# Residual sum after 1008 : 2439121.505453822
# Residual sum after 1009 : 2430005.2912524254
# Residual sum after 1010 : 2421694.338145105
# Residual sum after 1011 : 2413502.2816001778
# Residual sum after 1012 : 2405296.1418116484
# Residual sum after 1013 : 2397458.384435274
# Residual sum after 1014 : 2387611.13493138
# Residual sum after 1015 : 2377122.585737752
# Residual sum after 1016 : 2368107.8252884448
# Residual sum after 1017 : 2357781.3704727506
# Residual sum after 1018 : 2346679.8709115745
# Residual sum after 1019 : 2338475.3750089454
# Residual sum after 1020 : 2328571.7941491534
# Residual sum after 1021 : 2320034.0180652924
# Residual sum after 1022 : 2311482.31309212
# Residual sum after 1023 : 2302122.7088881824
# Residual sum after 1024 : 2292151.4211427737
# Residual sum after 1025 : 2284266.8999276888
# Residual sum after 1026 : 2274286.284437571
# Residual sum after 1027 : 2264075.842583891
# Residual sum after 1028 : 2255887.3385715145
# Residual sum after 1029 : 2247219.0812835232
# Residual sum after 1030 : 2238084.017923099
# Residual sum after 1031 : 2230491.2659601117
# Residual sum after 1032 : 2221736.907529653
# Residual sum after 1033 : 2212574.8119369466
# Residual sum after 1034 : 2204175.110979533
# Residual sum after 1035 : 2196590.1013524975
# Residual sum after 1036 : 2187924.5759897362
# Residual sum after 1037 : 2178178.3052536245
# Residual sum after 1038 : 2168965.4087216924
# Residual sum after 1039 : 2158553.833812399
# Residual sum after 1040 : 2148104.13315668
# Residual sum after 1041 : 2138004.4331658846
# Residual sum after 1042 : 2129685.365259482
# Residual sum after 1043 : 2121755.647210862
# Residual sum after 1044 : 2114196.6464717654
# Residual sum after 1045 : 2106710.260973094
# Residual sum after 1046 : 2096930.1629857589
# Residual sum after 1047 : 2089274.3705578395
# Residual sum after 1048 : 2081214.8133420204
# Residual sum after 1049 : 2071000.505388627
# Residual sum after 1050 : 2061600.4747693888
# Residual sum after 1051 : 2054162.018270267
# Residual sum after 1052 : 2045946.5169068403
# Residual sum after 1053 : 2038004.6067338912
# Residual sum after 1054 : 2030308.9997553239
# Residual sum after 1055 : 2022393.423311821
# Residual sum after 1056 : 2014466.4680467409
# Residual sum after 1057 : 2004689.847005049
# Residual sum after 1058 : 1995579.0372963448
# Residual sum after 1059 : 1987957.233945144
# Residual sum after 1060 : 1980716.3973419298
# Residual sum after 1061 : 1970850.2431420214
# Residual sum after 1062 : 1962813.710984081
# Residual sum after 1063 : 1954679.8090768491
# Residual sum after 1064 : 1944849.10552653
# Residual sum after 1065 : 1935280.6246607092
# Residual sum after 1066 : 1927988.7878773932
# Residual sum after 1067 : 1918313.8196027577
# Residual sum after 1068 : 1910717.963500553
# Residual sum after 1069 : 1901463.5027420698
# Residual sum after 1070 : 1892000.9036846517
# Residual sum after 1071 : 1883237.0065515281
# Residual sum after 1072 : 1874905.0503310259
# Residual sum after 1073 : 1866692.626427391
# Residual sum after 1074 : 1859875.0808773735
# Residual sum after 1075 : 1852055.4162719238
# Residual sum after 1076 : 1845024.9478656743
# Residual sum after 1077 : 1836262.0125309995
# Residual sum after 1078 : 1829233.6381383832
# Residual sum after 1079 : 1822418.863723266
# Residual sum after 1080 : 1815687.3002033941
# Residual sum after 1081 : 1806831.449025103
# Residual sum after 1082 : 1799236.9625008272
# Residual sum after 1083 : 1790628.858967589
# Residual sum after 1084 : 1783896.2770546556
# Residual sum after 1085 : 1774992.1842776574
# Residual sum after 1086 : 1767736.0204309833
# Residual sum after 1087 : 1760876.0528374661
# Residual sum after 1088 : 1751675.4894567614
# Residual sum after 1089 : 1742584.3202381015
# Residual sum after 1090 : 1735651.0583478562
# Residual sum after 1091 : 1727141.7999631306
# Residual sum after 1092 : 1720299.295937256
# Residual sum after 1093 : 1713703.218346475
# Residual sum after 1094 : 1706776.156183336
# Residual sum after 1095 : 1698294.575858051
# Residual sum after 1096 : 1690035.416489178
# Residual sum after 1097 : 1681929.3899369924
# Residual sum after 1098 : 1672450.7392426692
# Residual sum after 1099 : 1663751.7294660846
# Residual sum after 1100 : 1657007.2733468655
# Residual sum after 1101 : 1650414.086170861
# Residual sum after 1102 : 1644063.7738682295
# Residual sum after 1103 : 1635828.8994266144
# Residual sum after 1104 : 1629189.6580736309
# ...
# Residual sum after 1405 : 275616.81467338826
# Residual sum after 1406 : 273358.28412024706
# Residual sum after 1407 : 271514.6636740214
# Residual sum after 1408 : 269318.30191096733
# Residual sum after 1409 : 267519.9178597741
# Residual sum after 1410 : 265287.57374194544
# Residual sum after 1411 : 263300.367842062
# Residual sum after 1412 : 261102.65344409013
# Residual sum after 1413 : 258844.31005076072
# Residual sum after 1414 : 256404.78764690322
# Residual sum after 1415 : 254408.32982676575
# Residual sum after 1416 : 252252.25557177322
# Residual sum after 1417 : 250580.7646461516
# Residual sum after 1418 : 248701.5498782932
# Residual sum after 1419 : 246394.82171236572
# Residual sum after 1420 : 244488.97675170127
# Residual sum after 1421 : 242505.11873692306
# Residual sum after 1422 : 240837.82554337033
# Residual sum after 1423 : 238860.16079448359
# Residual sum after 1424 : 237095.2630282301
# Residual sum after 1425 : 235459.71286321522
# Residual sum after 1426 : 233203.90014743563
# Residual sum after 1427 : 231648.55906196576
# Residual sum after 1428 : 230008.55665887275
# Residual sum after 1429 : 228085.38077151962
# Residual sum after 1430 : 226001.690496412
# Residual sum after 1431 : 223858.28550919433
# Residual sum after 1432 : 221992.23641865063
# Residual sum after 1433 : 220241.12956843656
# Residual sum after 1434 : 218067.6806764174
# Residual sum after 1435 : 216388.23253091678
# Residual sum after 1436 : 214598.5949816841
# Residual sum after 1437 : 212842.7812275973
# Residual sum after 1438 : 210925.71796060752
# Residual sum after 1439 : 209225.28793397508
# Residual sum after 1440 : 207510.89665910395
# Residual sum after 1441 : 205879.4717939696
# Residual sum after 1442 : 204362.09337374134
# Residual sum after 1443 : 202651.6019023248
# Residual sum after 1444 : 200664.68245827907
# Residual sum after 1445 : 199099.14347298737
# Residual sum after 1446 : 197267.87658087115
# Residual sum after 1447 : 195212.12021556514
# Residual sum after 1448 : 193297.99465584548
# Residual sum after 1449 : 191807.9269077581
# Residual sum after 1450 : 189953.2626863958
# Residual sum after 1451 : 188010.61241251315
# Residual sum after 1452 : 186196.71518932455
# Residual sum after 1453 : 184507.04890702778
# Residual sum after 1454 : 182877.1654327753
# Residual sum after 1455 : 181277.28240057616
# Residual sum after 1456 : 179440.06761670712
# Residual sum after 1457 : 177827.5598417203
# Residual sum after 1458 : 176483.5796818833
# Residual sum after 1459 : 174866.66396358956
# Residual sum after 1460 : 173067.98589803383
# Residual sum after 1461 : 171317.9525800866
# Residual sum after 1462 : 169374.38396393124
# Residual sum after 1463 : 167952.29654343257
# Residual sum after 1464 : 166243.1896259888
# Residual sum after 1465 : 164815.21606521783
# Residual sum after 1466 : 163371.32407374054
# Residual sum after 1467 : 161985.4850425481
# Residual sum after 1468 : 160437.28252775455
# Residual sum after 1469 : 158677.22106374806
# Residual sum after 1470 : 157292.96535397653
# Residual sum after 1471 : 155548.27312587717
# Residual sum after 1472 : 154239.0244773276
# Residual sum after 1473 : 152882.6748218966
# Residual sum after 1474 : 151670.79442512622
# Residual sum after 1475 : 150179.2779237912
# Residual sum after 1476 : 148603.48985286473
# Residual sum after 1477 : 147226.25426524572
# Residual sum after 1478 : 145838.06335406637
# Residual sum after 1479 : 144589.56866475704
# Residual sum after 1480 : 143345.38139331478
# Residual sum after 1481 : 141816.34942875634
# Residual sum after 1482 : 140255.1830699383
# Residual sum after 1483 : 138954.91644251853
# Residual sum after 1484 : 137479.48841382214
# Residual sum after 1485 : 136222.63562491757
# Residual sum after 1486 : 135134.44421559628
# Residual sum after 1487 : 133879.5471301093
# Residual sum after 1488 : 132573.83438862715
# Residual sum after 1489 : 131386.3948609194
# Residual sum after 1490 : 129722.93059860816
# Residual sum after 1491 : 128371.22014435117
# Residual sum after 1492 : 126972.3544410163
# Residual sum after 1493 : 125666.91739508594
# Residual sum after 1494 : 124573.97366992656
# Residual sum after 1495 : 122972.83873440039
# Residual sum after 1496 : 121498.3099589612
# Residual sum after 1497 : 120314.0685145904
# Residual sum after 1498 : 119215.35963411332
# Residual sum after 1499 : 117845.123628835
# Residual sum after 1500 : 116395.2795766326
# Residual sum after 1501 : 115322.84794470348
# Residual sum after 1502 : 113842.25789534669
# Residual sum after 1503 : 112585.80581147046
# Residual sum after 1504 : 111575.6064254843
# Residual sum after 1505 : 110349.77643949132
# Residual sum after 1506 : 109273.04609276385
# Residual sum after 1507 : 108051.38088009997
# Residual sum after 1508 : 106832.98510293318
# Residual sum after 1509 : 105611.9845727873
# Residual sum after 1510 : 104530.52748303204
# Residual sum after 1511 : 103308.3479877264
# Residual sum after 1512 : 102408.7849178499
# Residual sum after 1513 : 101449.2660678442
# Residual sum after 1514 : 100439.90084488953
# Residual sum after 1515 : 99534.6993378723
# Residual sum after 1516 : 98257.7377514296
# Residual sum after 1517 : 97285.40088337853
# Residual sum after 1518 : 96099.06508167999
# Residual sum after 1519 : 95159.66021045194
# Residual sum after 1520 : 94168.36195374448
# Residual sum after 1521 : 92979.3912701021
# Residual sum after 1522 : 91722.81885924657
# Residual sum after 1523 : 90843.83522215924
# Residual sum after 1524 : 89751.52873976507
# Residual sum after 1525 : 88704.36355363089
# Residual sum after 1526 : 87597.74919375924
# Residual sum after 1527 : 86468.67297435217
# Residual sum after 1528 : 85339.74510679327
# Residual sum after 1529 : 84350.33432892482
# Residual sum after 1530 : 83429.41273340936
# Residual sum after 1531 : 82588.70784819807
# Residual sum after 1532 : 81651.68051311225
# Residual sum after 1533 : 80654.21084154605
# Residual sum after 1534 : 79842.75291494113
# Residual sum after 1535 : 78977.92825989294
# Residual sum after 1536 : 78172.86144900258
# Residual sum after 1537 : 77336.6446680687
# Residual sum after 1538 : 76463.21480334106
# Residual sum after 1539 : 75679.80274027355
# Residual sum after 1540 : 74735.39998935394
# Residual sum after 1541 : 73896.80547116876
# Residual sum after 1542 : 72832.01425710245
# Residual sum after 1543 : 71864.2360482675
# Residual sum after 1544 : 71030.02897101648
# Residual sum after 1545 : 70121.60564996752
# Residual sum after 1546 : 69330.41541994536
# Residual sum after 1547 : 68451.40721148817
# Residual sum after 1548 : 67612.82149925968
# Residual sum after 1549 : 66944.80630855369
# Residual sum after 1550 : 66258.28801562842
# Residual sum after 1551 : 65438.34223415299
# Residual sum after 1552 : 64668.92450708153
# Residual sum after 1553 : 63824.333576169214
# Residual sum after 1554 : 62988.652980313345
# Residual sum after 1555 : 62251.38292344114
# Residual sum after 1556 : 61457.51764315231
# Residual sum after 1557 : 60775.01353890881
# Residual sum after 1558 : 59969.50374958234
# Residual sum after 1559 : 59181.95635103828
# Residual sum after 1560 : 58363.899714322266
# Residual sum after 1561 : 57784.337678732
# Residual sum after 1562 : 56965.75640132302
# Residual sum after 1563 : 56266.249689111675
# Residual sum after 1564 : 55364.56181675484
# Residual sum after 1565 : 54542.65334402718
# Residual sum after 1566 : 53948.27157704926
# Residual sum after 1567 : 53142.362026936295
# Residual sum after 1568 : 52479.1883565051
# Residual sum after 1569 : 51850.19083768184
# Residual sum after 1570 : 51151.438319674315
# Residual sum after 1571 : 50538.33146036176
# Residual sum after 1572 : 49884.71633209412
# Residual sum after 1573 : 49258.225989484265
# Residual sum after 1574 : 48614.83357753422
# Residual sum after 1575 : 48007.38700372252
# Residual sum after 1576 : 47316.24040138641
# Residual sum after 1577 : 46684.738401167335
# Residual sum after 1578 : 46015.610645231805
# Residual sum after 1579 : 45360.00187964426
# Residual sum after 1580 : 44781.58314310842
# Residual sum after 1581 : 44171.019629099756
# Residual sum after 1582 : 43615.31660588673
# Residual sum after 1583 : 42952.92004500751
# Residual sum after 1584 : 42277.5832783747
# Residual sum after 1585 : 41566.73215022257
# Residual sum after 1586 : 40902.83684133167
# Residual sum after 1587 : 40280.54478021168
# Residual sum after 1588 : 39660.64247713443
# Residual sum after 1589 : 39116.77397480377
# Residual sum after 1590 : 38518.18235504912
# Residual sum after 1591 : 38017.010316341664
# Residual sum after 1592 : 37422.314861867824
# Residual sum after 1593 : 36758.46165364432
# Residual sum after 1594 : 36253.98528023686
# Residual sum after 1595 : 35735.97860488635
# Residual sum after 1596 : 35249.42413836268
# Residual sum after 1597 : 34597.587101722114
# Residual sum after 1598 : 34118.20469087268
# Residual sum after 1599 : 33660.180445470134
# Residual sum after 1600 : 33091.73948021933
# Residual sum after 1601 : 32624.462296746067
# Residual sum after 1602 : 31864.21188777708
# Residual sum after 1603 : 31333.969248276022
# Residual sum after 1604 : 30851.329509096162
# Residual sum after 1605 : 30334.584275634094
# Residual sum after 1606 : 29899.565138393846
# Residual sum after 1607 : 29479.380174714912
# Residual sum after 1608 : 28994.529844755616
# Residual sum after 1609 : 28422.17815106602
# Residual sum after 1610 : 27837.207817813738
# Residual sum after 1611 : 27360.438484577335
# Residual sum after 1612 : 26964.468630191965
# Residual sum after 1613 : 26532.57505300268
# Residual sum after 1614 : 26029.120152019597
# Residual sum after 1615 : 25529.489527995782
# Residual sum after 1616 : 25043.09555624877
# Residual sum after 1617 : 24616.378246022967
# Residual sum after 1618 : 24272.655159526446
# Residual sum after 1619 : 23836.4789173101
# Residual sum after 1620 : 23466.679470021434
# Residual sum after 1621 : 23043.639433014076
# Residual sum after 1622 : 22670.187842411837
# Residual sum after 1623 : 22256.63808843636
# Residual sum after 1624 : 21851.175646932876
# Residual sum after 1625 : 21451.616373386525
# Residual sum after 1626 : 21102.184397069665
# Residual sum after 1627 : 20691.727468159705
# Residual sum after 1628 : 20257.53585135569
# Residual sum after 1629 : 19942.186603729657
# Residual sum after 1630 : 19634.495549831947
# Residual sum after 1631 : 19213.866855189288
# Residual sum after 1632 : 18855.766187482797
# Residual sum after 1633 : 18493.53407780961
# Residual sum after 1634 : 18192.529345087423
# Residual sum after 1635 : 17811.678646302127
# Residual sum after 1636 : 17396.819299508014
# Residual sum after 1637 : 17042.011872503263
# Residual sum after 1638 : 16716.290658485108
# Residual sum after 1639 : 16412.27006003322
# Residual sum after 1640 : 16071.813482151407
# Residual sum after 1641 : 15701.272014597835
# Residual sum after 1642 : 15400.783375286499
# Residual sum after 1643 : 15020.085585921533
# Residual sum after 1644 : 14652.961180659571
# Residual sum after 1645 : 14347.651194992897
# Residual sum after 1646 : 13993.100115650494
# Residual sum after 1647 : 13645.925557900056
# Residual sum after 1648 : 13415.273931209695
# Residual sum after 1649 : 13166.079356827937
# Residual sum after 1650 : 12927.095895104161
# Residual sum after 1651 : 12678.521090661836
# Residual sum after 1652 : 12424.104713437124
# Residual sum after 1653 : 12079.786424313785
# Residual sum after 1654 : 11771.414162518038
# Residual sum after 1655 : 11406.661065217862
# Residual sum after 1656 : 11151.692418984834
# Residual sum after 1657 : 10860.1634553286
# Residual sum after 1658 : 10593.442736460578
# Residual sum after 1659 : 10312.409403121059
# Residual sum after 1660 : 10102.75394017994
# Residual sum after 1661 : 9805.845844525611
# Residual sum after 1662 : 9560.217913034316
# Residual sum after 1663 : 9312.806681485949
# Residual sum after 1664 : 9065.121719443878
# Residual sum after 1665 : 8796.204838828535
# Residual sum after 1666 : 8540.202780752408
# Residual sum after 1667 : 8345.517232632095
# Residual sum after 1668 : 8145.193414117505
# Residual sum after 1669 : 7920.7853112872735
# Residual sum after 1670 : 7679.487463868191
# Residual sum after 1671 : 7443.293114607187
# Residual sum after 1672 : 7263.415334179635
# Residual sum after 1673 : 7041.1158070914735
# Residual sum after 1674 : 6781.771771601296
# Residual sum after 1675 : 6593.801929248629
# Residual sum after 1676 : 6393.842911845339
# Residual sum after 1677 : 6217.525885090627
# Residual sum after 1678 : 6005.626497036111
# Residual sum after 1679 : 5789.863790786444
# Residual sum after 1680 : 5609.013997286511
# Residual sum after 1681 : 5439.6008090800615
# Residual sum after 1682 : 5228.281580164583
# Residual sum after 1683 : 5072.14856989527
# Residual sum after 1684 : 4934.763130071874
# Residual sum after 1685 : 4768.457728755265
# Residual sum after 1686 : 4621.8395876546
# Residual sum after 1687 : 4450.756512636806
# Residual sum after 1688 : 4295.306079315759
# Residual sum after 1689 : 4136.779350233067
# Residual sum after 1690 : 3970.649473414053
# Residual sum after 1691 : 3807.452663732242
# Residual sum after 1692 : 3672.1985624577574
# Residual sum after 1693 : 3548.699019224766
# Residual sum after 1694 : 3471.9646679722637
# Residual sum after 1695 : 3362.6942616710503
# Residual sum after 1696 : 3277.990782097323
# Residual sum after 1697 : 3165.451658902057
# Residual sum after 1698 : 3079.95403287126
# Residual sum after 1699 : 2997.5304490460258
# Residual sum after 1700 : 2876.932256022758
# Residual sum after 1701 : 2753.905368493494
# Residual sum after 1702 : 2662.04391317803
# Residual sum after 1703 : 2572.850302339654
# Residual sum after 1704 : 2470.0892267376416
# Residual sum after 1705 : 2368.4616767481666
# Residual sum after 1706 : 2268.53281194523
# Residual sum after 1707 : 2177.523674515919
# Residual sum after 1708 : 2079.78553615254
# Residual sum after 1709 : 2012.2609710516974
# Residual sum after 1710 : 1898.2453887864078
# Residual sum after 1711 : 1778.8545894554702
# Residual sum after 1712 : 1705.0286021563845
# Residual sum after 1713 : 1617.7870485233107
# Residual sum after 1714 : 1534.7288991008372
# Residual sum after 1715 : 1480.4649834496188
# Residual sum after 1716 : 1430.3576686855379
# Residual sum after 1717 : 1382.6225925187891
# Residual sum after 1718 : 1319.807443184371
# Residual sum after 1719 : 1242.1180627554425
# Residual sum after 1720 : 1177.2561156286201
# Residual sum after 1721 : 1128.6123661721083
# Residual sum after 1722 : 1066.7404130642922
# Residual sum after 1723 : 1016.835721364185
# Residual sum after 1724 : 961.9329826816472
# Residual sum after 1725 : 892.2949503015639
# Residual sum after 1726 : 840.8308436468983
# Residual sum after 1727 : 789.0322769130632
# Residual sum after 1728 : 760.5875565008348
# Residual sum after 1729 : 723.1303285265542
# Residual sum after 1730 : 693.3027574112897
# Residual sum after 1731 : 656.7023004482494
# Residual sum after 1732 : 610.6982543959285
# Residual sum after 1733 : 569.8858014066449
# Residual sum after 1734 : 524.9246526783267
# Residual sum after 1735 : 504.1093590976763
# Residual sum after 1736 : 473.8288231475855
# Residual sum after 1737 : 442.1411284280983
# Residual sum after 1738 : 411.17873367741794
# Residual sum after 1739 : 377.83195501328504
# Residual sum after 1740 : 343.32022320095103
# Residual sum after 1741 : 314.936809803629
# Residual sum after 1742 : 282.9401234135463
# Residual sum after 1743 : 267.46739899261115
# Residual sum after 1744 : 246.3609188699265
# Residual sum after 1745 : 225.63119778765804
# Residual sum after 1746 : 209.6611855714859
# Residual sum after 1747 : 196.3905547451135
# Residual sum after 1748 : 175.57227587322186
# Residual sum after 1749 : 158.18411863885456
# Residual sum after 1750 : 142.75101365376074
# Residual sum after 1751 : 129.90248905039073
# Residual sum after 1752 : 115.14160085486336
# Residual sum after 1753 : 107.7525335434164
# Residual sum after 1754 : 91.67559225705968
# Residual sum after 1755 : 80.38485880335215
# Residual sum after 1756 : 70.0737853971214
# Residual sum after 1757 : 57.10056276683344
# Residual sum after 1758 : 47.67326844852831
# Residual sum after 1759 : 41.890724890993035
# Residual sum after 1760 : 34.20211433817492
# Residual sum after 1761 : 30.784823768118645
# Residual sum after 1762 : 26.54640800018687
# Remaining nonzero entries = 38, Max = 2.838, Mean = 0.000021

# %%
print(f"Remaining nonzero entries = {np.count_nonzero(R_2)}, Max = {np.max(R_2):.2f}, Mean = {np.mean(R_2):.2f}")
# Out:
# Remaining nonzero entries = 38, Max = 2.84, Mean = 0.00

# %%
plt_data=[0]
r_sum=sum([demand['density'] for demand in demand_list])*time_split
for item in process:
    for _ in range(item[0]):
        v=item[1]/item[0]/r_sum*100+plt_data[-1]
        plt_data.append(v)
np.save("data/network_availability_official_demand.npy",plt_data)

# %%
time_shift=0
total_supply=[0]*len(demand_list)
for cover in tqdm(all_cover):
    cover_csr = cover[2][0]
    sat_num = cover[3]
    total_supply += cover_csr.toarray().flatten()[len(demand_list)*time_shift:len(demand_list)*(time_shift+1)] * sat_num
# Out:
# 100%|██████████| 1762/1762 [00:02<00:00, 869.21it/s]

# %%
print(np.mean(total_supply))
# Out:
# 417.6592592592593

# %%
supply_demand_ratio=[]
for idx,demand in enumerate(demand_list):
    if demand['density']!=0:
        supply_demand_ratio.append(total_supply[idx]/demand['density'])
print(np.mean(supply_demand_ratio))
np.save("data/supply_demand_ratio_official.npy",supply_demand_ratio)
# Out:
# 375.8320275716796

# %%
def FeasibilityCheck_one_slot(params):
    t,mega=params
    two_pi=2*np.pi
    total_supply=[]
    for idx,shell in enumerate(mega):
        T=T_list[idx]
        eta=coverage_eta(T)
        inc=inc_list[idx]
        for mid in range(shell["m"]):
            for nid in range(shell["n"]):
                r_set=[]
                a_sat=(two_pi/shell["m"]*mid-t/TE*two_pi)%two_pi
                b_sat=(two_pi/shell["n"]*nid+t/T*two_pi)%two_pi
                l_sat,p_sat=alpha_gamma_to_lambda_phi(a_sat,b_sat,inc)
                for idx,demand in enumerate(demand_list):
                    l_cell=demand['lat_lon'][1]
                    p_cell=demand['lat_lon'][0]
                    r=is_cover(l_sat,p_sat,l_cell,p_cell,eta) #用经纬度判断
                    if r:
                        S=S_set[idx]
                        r_set.append([idx,S,demand['density']])
                if len(r_set)!=0:
                    S_sum=np.sum([item[1] for item in r_set])
                    factor=user_per_sat/S_sum
                    r_set=[[item[0],item[1]*factor]for item in r_set]
                    total_supply.append(r_set)
    # check the demand
    supply=[0]*len(demand_list)
    for r_set in total_supply:
        for item in r_set:
            supply[item[0]]+=item[1]
    return supply

# %%
official_data=np.load("data/satisfied_mega_official_demand.npy",allow_pickle=True)
selected_data=official_data[-1][0]
T_list = np.array([satellite_period(shell["h"] * 1e3) for shell in selected_data])
inc_list = np.radians(np.array([shell["inc"] for shell in selected_data]))
total_supply=FeasibilityCheck_one_slot([0,selected_data])

# %%
supply_demand_ratio=[]
for idx,demand in enumerate(demand_list):
    if demand['density']!=0:
        supply_demand_ratio.append(total_supply[idx]/demand['density'])
print(np.mean(supply_demand_ratio))
np.save("data/supply_demand_ratio_official_megareduce.npy",supply_demand_ratio)
# Out:
# 1319.6789211893495
