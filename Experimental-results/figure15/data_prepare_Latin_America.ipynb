# %%
import numpy as np
import math
from fractions import Fraction
from tqdm import tqdm
import multiprocessing as mp
from haversine import haversine, Unit
import matplotlib.pyplot as plt
import os
import random
import matplotlib
from scipy.sparse import lil_matrix, csr_matrix
import gc
import time
from multiprocessing import shared_memory

# %%
# Astronomy-related constants

TE = 24 * 3600  # One Earth sidereal day in seconds

RE = 6371e3  # Mean radius of Earth in meters

u = 3.986e14  # Standard gravitational parameter (μ = GM) in m^3/s^2

K = RE / pow(u, 1/3) * pow(2 * np.pi, 2/3)  

eps = 25 * np.pi / 180  # Maximum elevation angle for ground access, in radians (25°)

# %%
def get_allfile(path):
    """
    Get all files in a directory (excluding Jupyter checkpoint folders).
    """
    all_file = []
    for f in os.listdir(path):
        f_name = os.path.join(path, f)
        if "ipynb_checkpoints" not in f_name:
            all_file.append(f_name)
    return all_file


def satellite_period(h):
    """
    Calculate orbital period (in seconds) for altitude h (in meters).
    """
    a = RE + h
    T = float(2 * np.pi * pow(a**3 / u, 0.5))
    return T


def coverage_eta(T):
    """
    Calculate half ground coverage angle (in radians) based on period T.
    """
    eta = math.acos(K * math.cos(eps) / pow(T, 2 / 3)) - eps
    return eta


def approximate_ratio(a, b, precision=1e-3):
    """
    Approximate a/b as a reduced integer ratio with given precision.
    """
    if b == 0:
        raise ValueError("Denominator cannot be zero")
    ratio = Fraction(a, b).limit_denominator(int(1 / precision))
    return ratio.numerator, ratio.denominator


def alpha_gamma_to_lambda_phi(alpha, gamma, inc):
    """
    Convert orbital plane coordinates (alpha, gamma) to Earth-fixed coordinates (longitude, latitude).
    """
    phi = math.asin(math.sin(inc) * math.sin(gamma))
    temp = math.atan2(math.cos(inc) * math.sin(gamma), math.cos(gamma))
    lamb = (temp + alpha) % (2 * math.pi)
    if lamb > math.pi:
        lamb -= 2 * math.pi
    return lamb, phi


def is_cover(l_sat, p_sat, l_cell, p_cell, eta):
    """
    Determine whether a satellite at (l_sat, p_sat) covers a ground cell at (l_cell, p_cell).
    """
    lat_check = (p_sat - 2 * eta) < -np.pi/2 or (p_sat + 2 * eta) > np.pi/2
    lon_check = (l_sat - 2 * eta) < -np.pi or (l_sat + 2 * eta) > np.pi
    if lat_check or lon_check:
        d = haversine(
            (np.degrees(p_sat), np.degrees(l_sat)),
            (np.degrees(p_cell), np.degrees(l_cell)),
            unit=Unit.METERS
        )
        return d <= eta * RE
    else:
        if (p_sat - 2 * eta) <= p_cell <= (p_sat + 2 * eta) and \
           (l_sat - 2 * eta) <= l_cell <= (l_sat + 2 * eta):
            d = haversine(
                (np.degrees(p_sat), np.degrees(l_sat)),
                (np.degrees(p_cell), np.degrees(l_cell)),
                unit=Unit.METERS
            )
            return d <= eta * RE
    return False


def cal_supply_all_cell(h, beta, a0):
    """
    For a given stable satellite ground track (h, beta, a0),
    compute coverage of each time slot along its orbit.
    """
    T = satellite_period(h * 1e3)
    p, q = approximate_ratio(int(T), TE, precision=1e-3)
    eta = coverage_eta(T)
    step = 2 * eta
    inc = beta
    total_supply = []

    for i in range(int(2 * np.pi * q / step)):
        t = step * i / (2 * np.pi / T)
        a_sat = (a0 - (2 * np.pi / TE) * t) % (2 * np.pi)
        b_sat = (step * i) % (2 * np.pi)
        l_sat, p_sat = alpha_gamma_to_lambda_phi(a_sat, b_sat, inc)
        
        r_set = []
        for idx, demand in enumerate(demand_list):
            l_cell = demand['lat_lon'][1]
            p_cell = demand['lat_lon'][0]
            if is_cover(l_sat, p_sat, l_cell, p_cell, eta):
                S = S_set[idx]
                r_set.append([idx, S, demand['density']])
        
        if r_set:
            S_sum = np.sum([item[1] for item in r_set])
            factor = user_per_sat / S_sum
            r_set = [[item[0], item[1] * factor] for item in r_set]
            total_supply.append([r_set, l_sat, p_sat])
    
    return np.asarray(total_supply, dtype="object")


def recover_fulltime(data):
    """
    Aggregate full-time coverage over time slots for a set of random slot selections.
    """
    random_numbers, cover, n_length = data
    selected_cover = lil_matrix((1, n_length), dtype=np.float64)
    sat_location = []

    for t in range(time_split):
        for num in random_numbers:
            num = (num + t) % int(time_split)
            sat_location.append([cover[num][1], cover[num][2]])
            for idx, users in cover[num][0]:
                selected_cover[0, t * len(demand_list) + idx] += users
    
    return [selected_cover.tocsr(), sat_location]


def generate_baseset(args):
    """
    Build fulltime coverage for a satellite configuration.
    """
    file, random_numbers, sat_num = args
    file_param = file.split("/")[1].split("_")
    h = float(file_param[0])
    beta = float(file_param[1])
    alpha0 = float(file_param[2].split(".npy")[0])
    param = [h, beta, alpha0]

    cover = cal_supply_all_cell(h, beta, alpha0)
    fulltime_cover = recover_fulltime([random_numbers, cover, n_length])
    
    return [param, random_numbers, fulltime_cover, sat_num]

# %%
# === Simulation parameters ===
sat_height = 573  # Satellite altitude in km

# Path to precomputed candidate orbit coverage data
base_cover_path = f"candidate_orbits_eval1_{sat_height}/"

# Number of time slots in the coverage window (e.g. daily temporal resolution)
time_split = 308

# %%
# === Load demand data ===
demand_list = np.load("data/south_america_starlink_demand_99449.npy", allow_pickle=True)

# Convert lat/lon from degrees to radians
for idx in range(len(demand_list)):
    demand_list[idx]['lat_lon'][0] = np.radians(demand_list[idx]['lat_lon'][0])  # latitude
    demand_list[idx]['lat_lon'][1] = np.radians(demand_list[idx]['lat_lon'][1])  # longitude

# === Cell parameters ===
cell_size = 4  # degrees per cell
user_per_sat = 960  # total users a satellite can serve

# === Compute area of each demand cell ===
S_set = []
for idx, demand in enumerate(demand_list):
    p_cell = demand['lat_lon'][0]  # latitude in radians

    # Approximate cell height in meters (north-south)
    h = RE * np.radians(cell_size)

    # Compute arc length at top and bottom edges of the cell (east-west)
    L1 = RE * np.sin(np.pi / 2 - abs(p_cell)) * np.radians(cell_size)
    tmp = abs(p_cell - np.radians(cell_size))
    L2 = RE * np.sin(np.pi / 2 - min(tmp, np.pi / 2)) * np.radians(cell_size)

    # Special handling near the south pole (only for extreme southern cells)
    if tmp > np.pi / 2:
        h = RE * abs(p_cell + np.pi / 2)

    # Trapezoidal approximation of cell area
    S = 0.5 * h * (L1 + L2)
    S_set.append(S)

# %%
selected_params=np.load("data/TinyLEO_for_Latin_America.npy",allow_pickle=True)
print(len(selected_params))
files=[]
sat_nums=0
for s_tmp in selected_params:
    param_tmp,slots,satmaps,sat_num=s_tmp
    tmp=base_cover_path+str(int(param_tmp[0]))+"_"+str(param_tmp[1])+"_"+str(param_tmp[2])+".npy"
    files.append([tmp,slots,sat_num])
    sat_nums+=sat_num
print(files[0])
print(sat_nums)
# Out:
# 1065
# ['candidate_orbits_eval1_573/573_0.0_3.07177948351002.npy', [76], 1]
# 1065

# %%
all_cover=[]
n_length=len(demand_list)*time_split

with mp.Pool(processes=100) as pool:
    all_cover = list(tqdm(pool.imap(generate_baseset, files), total=len(files), mininterval=10,maxinterval=20))
    pool.close()  # Prevents any more tasks from being submitted to the pool
    pool.join()  # Wait for the worker processes to exit
# Out:
# 100%|██████████| 1065/1065 [00:25<00:00, 42.59it/s]

# %%
# === Initialize residual demand vector ===
# Repeat the demand density vector across all time slots
tmp_R = [demand['density'] for demand in demand_list]
ttmpR = tmp_R * int(time_split)
R = np.array(ttmpR).reshape(-1)  # Final residual vector R
del ttmpR, tmp_R  # Free memory

selected = []  # Selected satellite set (to be filled later)
num_processes = 110  # Number of parallel processes

# === Dot product utility for greedy selection ===
def compute_dot(args, show=False):
    """
    Compute the dot product between coverage matrix and residual R
    """
    R, cid = args
    global all_cover
    fulltime_cover = all_cover[cid][2][0]  # Sparse matrix (1, T*|cells|)
    dot = fulltime_cover @ R
    return [dot[0], cid]

# === Residual update after selecting one satellite ===
def update_residual(R, cid):
    """
    Update residual vector R after using coverage from satellite `cid`
    """
    global all_cover
    cover = all_cover[cid][2][0]  # Sparse matrix
    sat_num = all_cover[cid][3]   # Number of satellites in this set

    # Subtract served demand (per satellite * number of sats)
    R[cover.indices] -= (cover.data * sat_num)
    
    # Ensure non-negativity
    R = np.maximum(R, 0)
    return R

# === Find best candidate from a chunk ===
def find_max_in_chunk(chunk):
    """
    Find maximum dot product value and corresponding candidate ID in a chunk
    """
    chunk = np.array(chunk)
    max_value = np.max(chunk[:, 0])
    local_index = np.argmax(chunk[:, 0])
    max_index = chunk[local_index][1]
    return [max_value, int(max_index)]

# %%
# === Initialize residual demand ===
tmp_R = [demand['density'] for demand in demand_list]
ttmpR = tmp_R * int(time_split)  # Repeat over all time slots
R_2 = np.array(ttmpR).reshape(-1).copy()  # Residual vector
R_sum_2 = np.sum(R_2)
print("Initial residual:", R_sum_2)
del ttmpR, tmp_R

# === Greedy sequential selection and tracking ===
process = []  # Store [satellite count, coverage gain] for each selected set
for idx in range(len(all_cover)):
    # Apply satellite group `idx` and update residual
    R_2 = update_residual(R_2, idx)

    # Record improvement
    covered = R_sum_2 - np.sum(R_2)
    process.append([all_cover[idx][3], covered])
    R_sum_2 = np.sum(R_2)

    print("Residual after set", idx, ":", R_sum_2)

# === Final residual stats ===
print(f"Final residual non-zeros = {np.count_nonzero(R_2)}, "
      f"max = {np.max(R_2):.2f}, mean = {np.mean(R_2):.2f}")
# Out:
# Initial residual: 7006629.521062489
# Residual after set 0 : 6976824.947982652
# Residual after set 1 : 6947020.37490282
# Residual after set 2 : 6917215.801822986
# Residual after set 3 : 6887411.228743151
# Residual after set 4 : 6857606.655663317
# Residual after set 5 : 6827802.082583482
# Residual after set 6 : 6797997.509503648
# Residual after set 7 : 6768192.936423816
# Residual after set 8 : 6738388.36334398
# Residual after set 9 : 6708583.790264148
# Residual after set 10 : 6678779.2171843145
# Residual after set 11 : 6649270.315507767
# Residual after set 12 : 6619761.413831219
# Residual after set 13 : 6590252.512154672
# Residual after set 14 : 6560743.610478125
# Residual after set 15 : 6531234.708801577
# Residual after set 16 : 6501725.807125028
# Residual after set 17 : 6472216.9054484805
# Residual after set 18 : 6442708.003771934
# Residual after set 19 : 6413199.102095384
# Residual after set 20 : 6383690.200418837
# Residual after set 21 : 6354322.0817428045
# Residual after set 22 : 6331237.5241761105
# Residual after set 23 : 6308244.2515437845
# Residual after set 24 : 6285250.978911455
# Residual after set 25 : 6262257.706279128
# Residual after set 26 : 6239264.4336468
# Residual after set 27 : 6216271.161014474
# Residual after set 28 : 6193277.888382147
# Residual after set 29 : 6170284.615749819
# Residual after set 30 : 6147291.343117492
# Residual after set 31 : 6124298.070485163
# Residual after set 32 : 6101304.797852834
# Residual after set 33 : 6078608.290843077
# Residual after set 34 : 6055911.783833321
# Residual after set 35 : 6033215.276823564
# Residual after set 36 : 6010518.769813808
# Residual after set 37 : 5987822.262804051
# Residual after set 38 : 5965125.755794292
# Residual after set 39 : 5942429.2487845365
# Residual after set 40 : 5919732.74177478
# Residual after set 41 : 5897036.234765022
# Residual after set 42 : 5874339.727755266
# Residual after set 43 : 5851676.3646574095
# Residual after set 44 : 5831271.234712704
# Residual after set 45 : 5811177.401359051
# Residual after set 46 : 5791083.568005399
# Residual after set 47 : 5770989.734651747
# Residual after set 48 : 5750895.901298095
# Residual after set 49 : 5730802.067944441
# Residual after set 50 : 5710708.234590788
# Residual after set 51 : 5690614.401237135
# Residual after set 52 : 5670520.567883483
# Residual after set 53 : 5650426.734529828
# Residual after set 54 : 5630332.901176175
# Residual after set 55 : 5611261.962279155
# Residual after set 56 : 5592191.023382136
# Residual after set 57 : 5573120.084485118
# Residual after set 58 : 5554049.145588101
# Residual after set 59 : 5534978.2066910835
# Residual after set 60 : 5515907.267794064
# Residual after set 61 : 5496836.328897046
# Residual after set 62 : 5477765.390000026
# Residual after set 63 : 5458694.451103008
# Residual after set 64 : 5439623.512205992
# Residual after set 65 : 5420747.71692742
# Residual after set 66 : 5403528.166958784
# Residual after set 67 : 5386308.616990146
# Residual after set 68 : 5369089.06702151
# Residual after set 69 : 5351869.517052872
# Residual after set 70 : 5334649.967084235
# Residual after set 71 : 5317430.417115596
# Residual after set 72 : 5300210.86714696
# Residual after set 73 : 5282991.317178323
# Residual after set 74 : 5265771.767209686
# Residual after set 75 : 5248552.217241047
# Residual after set 76 : 5230297.65463108
# Residual after set 77 : 5213255.5316219935
# Residual after set 78 : 5196832.875891188
# Residual after set 79 : 5180410.220160385
# Residual after set 80 : 5163987.564429582
# Residual after set 81 : 5147564.9086987795
# Residual after set 82 : 5131142.252967975
# Residual after set 83 : 5114719.597237171
# Residual after set 84 : 5098296.941506367
# Residual after set 85 : 5081874.285775565
# Residual after set 86 : 5065451.630044758
# Residual after set 87 : 5049119.193693232
# Residual after set 88 : 5033210.234039973
# Residual after set 89 : 5017301.274386713
# Residual after set 90 : 5001392.314733454
# Residual after set 91 : 4985483.355080193
# Residual after set 92 : 4969574.395426932
# Residual after set 93 : 4953665.435773673
# Residual after set 94 : 4937756.476120412
# Residual after set 95 : 4921847.516467155
# Residual after set 96 : 4905938.556813897
# Residual after set 97 : 4889681.049320595
# Residual after set 98 : 4875077.57430508
# Residual after set 99 : 4859651.207312653
# Residual after set 100 : 4844357.1597348545
# Residual after set 101 : 4829063.112157058
# Residual after set 102 : 4813769.064579261
# Residual after set 103 : 4798475.017001463
# Residual after set 104 : 4783180.969423667
# Residual after set 105 : 4767886.921845869
# Residual after set 106 : 4752592.874268073
# Residual after set 107 : 4737298.826690275
# Residual after set 108 : 4722563.8163600145
# Residual after set 109 : 4707015.803250633
# Residual after set 110 : 4690863.632393968
# Residual after set 111 : 4675117.493599262
# Residual after set 112 : 4660036.451427875
# Residual after set 113 : 4644842.61948016
# Residual after set 114 : 4629648.787532445
# Residual after set 115 : 4614454.955584731
# Residual after set 116 : 4599261.123637017
# Residual after set 117 : 4584067.291689301
# Residual after set 118 : 4568873.459741585
# Residual after set 119 : 4553679.627793868
# Residual after set 120 : 4538485.795846155
# Residual after set 121 : 4522873.933869049
# Residual after set 122 : 4507300.221905828
# Residual after set 123 : 4491726.509942608
# Residual after set 124 : 4476152.7979793865
# Residual after set 125 : 4460579.086016165
# Residual after set 126 : 4445005.3740529455
# Residual after set 127 : 4429431.662089724
# Residual after set 128 : 4413857.9501265045
# Residual after set 129 : 4400048.25776791
# Residual after set 130 : 4386492.165239618
# Residual after set 131 : 4373249.562026106
# Residual after set 132 : 4359797.298479428
# Residual after set 133 : 4346132.241319628
# Residual after set 134 : 4332467.184159829
# Residual after set 135 : 4318802.127000029
# Residual after set 136 : 4305137.069840229
# Residual after set 137 : 4291472.012680429
# Residual after set 138 : 4277806.955520628
# Residual after set 139 : 4264141.898360826
# Residual after set 140 : 4251907.706034415
# Residual after set 141 : 4239060.747731933
# Residual after set 142 : 4226148.928312307
# Residual after set 143 : 4213716.319788164
# Residual after set 144 : 4201676.99413634
# Residual after set 145 : 4188694.8725879295
# Residual after set 146 : 4176097.384385408
# Residual after set 147 : 4163499.896182887
# Residual after set 148 : 4150902.4079803643
# Residual after set 149 : 4138304.9197778427
# Residual after set 150 : 4125707.4315753207
# Residual after set 151 : 4113109.943372799
# Residual after set 152 : 4099346.7083100486
# Residual after set 153 : 4086754.3942232695
# Residual after set 154 : 4074119.071571964
# Residual after set 155 : 4061836.3451172127
# Residual after set 156 : 4049759.943894091
# Residual after set 157 : 4037534.01928515
# Residual after set 158 : 4025378.122681887
# Residual after set 159 : 4013345.5294414586
# Residual after set 160 : 4001312.936201032
# Residual after set 161 : 3989280.342960605
# Residual after set 162 : 3977247.749720178
# Residual after set 163 : 3965215.156479752
# Residual after set 164 : 3953182.563239325
# Residual after set 165 : 3941190.344804861
# Residual after set 166 : 3929018.126304377
# Residual after set 167 : 3916829.3664391334
# Residual after set 168 : 3904805.6122124856
# Residual after set 169 : 3892781.8579858383
# Residual after set 170 : 3880758.1037591915
# Residual after set 171 : 3868734.3495325437
# Residual after set 172 : 3856710.5953058973
# Residual after set 173 : 3844857.79912117
# Residual after set 174 : 3833025.0866312096
# Residual after set 175 : 3822119.696336576
# Residual after set 176 : 3811222.589396812
# Residual after set 177 : 3799879.3023739606
# Residual after set 178 : 3788745.921200662
# Residual after set 179 : 3777504.0618554875
# Residual after set 180 : 3766318.729139287
# Residual after set 181 : 3755133.396423086
# Residual after set 182 : 3743948.063706886
# Residual after set 183 : 3732762.730990685
# Residual after set 184 : 3721577.3982744836
# Residual after set 185 : 3710109.68748732
# Residual after set 186 : 3699397.7842775164
# Residual after set 187 : 3688385.908540082
# Residual after set 188 : 3677374.032802648
# Residual after set 189 : 3666362.1570652137
# Residual after set 190 : 3655350.2813277794
# Residual after set 191 : 3644338.405590344
# Residual after set 192 : 3633326.52985291
# Residual after set 193 : 3621788.6147380862
# Residual after set 194 : 3611178.469823864
# Residual after set 195 : 3599953.30741622
# Residual after set 196 : 3589246.9417949794
# Residual after set 197 : 3577846.8702604566
# Residual after set 198 : 3566873.1364676873
# Residual after set 199 : 3555636.033412383
# Residual after set 200 : 3544273.455616695
# Residual after set 201 : 3533771.5337935034
# Residual after set 202 : 3522934.527612026
# Residual after set 203 : 3511802.786097612
# Residual after set 204 : 3500671.044583198
# Residual after set 205 : 3489539.303068784
# Residual after set 206 : 3478407.5615543704
# Residual after set 207 : 3467275.8200399564
# Residual after set 208 : 3456356.4273890294
# Residual after set 209 : 3445808.185430836
# Residual after set 210 : 3435667.022506342
# Residual after set 211 : 3424868.409915141
# Residual after set 212 : 3414367.161458071
# Residual after set 213 : 3403832.439739053
# Residual after set 214 : 3393508.1063300148
# Residual after set 215 : 3383399.519869598
# Residual after set 216 : 3373290.9334091833
# Residual after set 217 : 3363182.3469487666
# Residual after set 218 : 3353073.76048835
# Residual after set 219 : 3342652.5558278435
# Residual after set 220 : 3332186.4298156644
# Residual after set 221 : 3321770.7765232837
# Residual after set 222 : 3311355.1232309025
# Residual after set 223 : 3300939.469938522
# Residual after set 224 : 3291037.4203856178
# Residual after set 225 : 3280693.7157729836
# Residual after set 226 : 3270545.011888731
# Residual after set 227 : 3260462.1864492814
# Residual after set 228 : 3250302.0847819843
# Residual after set 229 : 3240212.6971704722
# Residual after set 230 : 3229838.852391563
# Residual after set 231 : 3220131.1646547895
# Residual after set 232 : 3210097.0785582312
# Residual after set 233 : 3199865.120361958
# Residual after set 234 : 3189633.162165686
# Residual after set 235 : 3179401.203969413
# Residual after set 236 : 3169310.8406919017
# Residual after set 237 : 3158975.126030519
# Residual after set 238 : 3149309.153017779
# Residual after set 239 : 3139211.7102167173
# Residual after set 240 : 3129382.792970157
# Residual after set 241 : 3119299.258859863
# Residual after set 242 : 3109618.6648446536
# Residual after set 243 : 3100217.618389225
# Residual after set 244 : 3090236.875232487
# Residual after set 245 : 3080070.811813009
# Residual after set 246 : 3070141.910213063
# Residual after set 247 : 3060213.008613117
# Residual after set 248 : 3050457.2406401807
# Residual after set 249 : 3040598.5792002785
# Residual after set 250 : 3031270.5024720267
# Residual after set 251 : 3021522.5220107543
# Residual after set 252 : 3011893.6574022444
# Residual after set 253 : 3002358.2368634613
# Residual after set 254 : 2992747.904919373
# Residual after set 255 : 2983236.9764202833
# Residual after set 256 : 2973348.9858566197
# Residual after set 257 : 2963463.2461068546
# Residual after set 258 : 2953993.594833861
# Residual after set 259 : 2944523.943560868
# Residual after set 260 : 2935590.1825267775
# Residual after set 261 : 2925640.3299579835
# Residual after set 262 : 2916105.3051132103
# Residual after set 263 : 2906443.503681611
# Residual after set 264 : 2896697.334182081
# Residual after set 265 : 2887056.516104798
# Residual after set 266 : 2877749.8520447076
# Residual after set 267 : 2868388.633576216
# Residual after set 268 : 2858860.0372525733
# Residual after set 269 : 2849654.9219047087
# Residual after set 270 : 2840310.375413147
# Residual after set 271 : 2831230.4570932547
# Residual after set 272 : 2822350.253143577
# Residual after set 273 : 2813207.6854068637
# Residual after set 274 : 2804065.1176701505
# Residual after set 275 : 2794922.549933438
# Residual after set 276 : 2785556.7110163155
# Residual after set 277 : 2776345.8008473846
# Residual after set 278 : 2767182.3719404847
# Residual after set 279 : 2757918.942825186
# Residual after set 280 : 2748657.2644226355
# Residual after set 281 : 2739088.1888578134
# Residual after set 282 : 2729790.897689595
# Residual after set 283 : 2720542.094191082
# Residual after set 284 : 2711456.8470643447
# Residual after set 285 : 2702663.195416083
# Residual after set 286 : 2693482.9679054827
# Residual after set 287 : 2684505.756331186
# Residual after set 288 : 2675400.877473137
# Residual after set 289 : 2666344.4862847915
# Residual after set 290 : 2657277.9249388645
# Residual after set 291 : 2648143.3947852245
# Residual after set 292 : 2638897.9323836532
# Residual after set 293 : 2629757.915233629
# Residual after set 294 : 2620457.0268148878
# Residual after set 295 : 2611673.724129933
# Residual after set 296 : 2602899.7419678057
# Residual after set 297 : 2594296.867569851
# Residual after set 298 : 2585271.888041208
# Residual after set 299 : 2576177.5718534123
# Residual after set 300 : 2566990.846745766
# Residual after set 301 : 2558331.780805474
# Residual after set 302 : 2549011.939932249
# Residual after set 303 : 2540445.014541605
# Residual after set 304 : 2531688.8564718417
# Residual after set 305 : 2523113.6968545136
# Residual after set 306 : 2514677.386735483
# Residual after set 307 : 2506212.6618209123
# Residual after set 308 : 2497615.3103589285
# Residual after set 309 : 2489050.3282571216
# Residual after set 310 : 2480274.401736536
# Residual after set 311 : 2471581.6875041593
# Residual after set 312 : 2463199.884972547
# Residual after set 313 : 2454859.092919963
# Residual after set 314 : 2446372.5739901713
# Residual after set 315 : 2437606.192720839
# Residual after set 316 : 2429285.0071960245
# Residual after set 317 : 2421021.5835995437
# Residual after set 318 : 2412245.789064931
# Residual after set 319 : 2403502.3982391553
# Residual after set 320 : 2395078.3944374304
# Residual after set 321 : 2386517.7894385266
# Residual after set 322 : 2377901.750149973
# Residual after set 323 : 2369742.6730784434
# Residual after set 324 : 2361254.8182911775
# Residual after set 325 : 2352991.0458061676
# Residual after set 326 : 2344822.8268784815
# Residual after set 327 : 2337014.608405392
# Residual after set 328 : 2328910.1734787584
# Residual after set 329 : 2320595.100283447
# Residual after set 330 : 2312216.958176003
# Residual after set 331 : 2303714.340232288
# Residual after set 332 : 2295521.8744551637
# Residual after set 333 : 2287426.942201099
# Residual after set 334 : 2279550.2440134753
# Residual after set 335 : 2271867.7717656475
# Residual after set 336 : 2263742.0521053667
# Residual after set 337 : 2255456.7713383767
# Residual after set 338 : 2247574.440713831
# Residual after set 339 : 2239720.5003980873
# Residual after set 340 : 2231980.5847148146
# Residual after set 341 : 2223655.188327572
# Residual after set 342 : 2215712.425939965
# Residual after set 343 : 2207656.731806482
# Residual after set 344 : 2199642.8106421763
# Residual after set 345 : 2191690.707037095
# Residual after set 346 : 2183609.6193289245
# Residual after set 347 : 2175640.14115435
# Residual after set 348 : 2167789.978952867
# Residual after set 349 : 2159896.696052311
# Residual after set 350 : 2151644.99666791
# Residual after set 351 : 2143266.3857305227
# Residual after set 352 : 2135126.738877653
# Residual after set 353 : 2127196.471660278
# Residual after set 354 : 2119314.743999595
# Residual after set 355 : 2111401.3310313304
# Residual after set 356 : 2103588.1250205627
# Residual after set 357 : 2095745.8950985365
# Residual after set 358 : 2088428.815034211
# Residual after set 359 : 2080454.3600316418
# Residual after set 360 : 2072568.397778564
# Residual after set 361 : 2064914.7936105204
# Residual after set 362 : 2057523.3689498825
# Residual after set 363 : 2049872.1768598475
# Residual after set 364 : 2041758.0921721784
# Residual after set 365 : 2034362.8050250234
# Residual after set 366 : 2026618.3651541292
# Residual after set 367 : 2018941.9070740677
# Residual after set 368 : 2011391.9636547037
# Residual after set 369 : 2004196.4481482308
# Residual after set 370 : 1996443.5255312137
# Residual after set 371 : 1988815.055720901
# Residual after set 372 : 1981706.950635355
# Residual after set 373 : 1974409.0288851897
# Residual after set 374 : 1966805.6375274067
# Residual after set 375 : 1959284.9294419186
# Residual after set 376 : 1951707.0882192792
# Residual after set 377 : 1944207.239902434
# Residual after set 378 : 1936726.453865828
# Residual after set 379 : 1929316.038667207
# Residual after set 380 : 1921818.906846229
# Residual after set 381 : 1914655.0207712986
# Residual after set 382 : 1907270.9557400553
# Residual after set 383 : 1900107.910873063
# Residual after set 384 : 1892833.3207929162
# Residual after set 385 : 1885253.2772947582
# Residual after set 386 : 1878052.4681995343
# Residual after set 387 : 1870835.5814651023
# Residual after set 388 : 1863172.6266340422
# Residual after set 389 : 1855702.4887258587
# Residual after set 390 : 1848374.831366915
# Residual after set 391 : 1841211.5540065288
# Residual after set 392 : 1833832.3354402948
# Residual after set 393 : 1827024.436445364
# Residual after set 394 : 1819972.3743924065
# Residual after set 395 : 1812748.1392887908
# Residual after set 396 : 1805728.9078159186
# Residual after set 397 : 1798527.9987156899
# Residual after set 398 : 1791632.6987332741
# Residual after set 399 : 1784501.544837408
# Residual after set 400 : 1777582.2427549534
# Residual after set 401 : 1770515.0974179755
# Residual after set 402 : 1763385.2636049662
# Residual after set 403 : 1756593.1843255458
# Residual after set 404 : 1749472.771925092
# Residual after set 405 : 1742468.4657610266
# Residual after set 406 : 1735535.8679760785
# Residual after set 407 : 1728763.1267441404
# Residual after set 408 : 1721782.1556480534
# Residual after set 409 : 1714573.756229623
# Residual after set 410 : 1707482.4945908887
# Residual after set 411 : 1700457.88368252
# Residual after set 412 : 1693632.0453718228
# Residual after set 413 : 1686707.4610487737
# Residual after set 414 : 1679639.512010184
# Residual after set 415 : 1672448.02897173
# Residual after set 416 : 1665441.678440335
# Residual after set 417 : 1658635.0633742309
# Residual after set 418 : 1652490.8387689574
# Residual after set 419 : 1645701.97957332
# Residual after set 420 : 1638677.9157072292
# Residual after set 421 : 1632297.9474799065
# Residual after set 422 : 1625731.1469385128
# Residual after set 423 : 1618826.5578879425
# Residual after set 424 : 1612120.387896644
# Residual after set 425 : 1605511.015806007
# Residual after set 426 : 1599014.447758067
# Residual after set 427 : 1592362.6815691378
# Residual after set 428 : 1585642.1293696144
# Residual after set 429 : 1578934.9302456786
# Residual after set 430 : 1571722.0452809834
# Residual after set 431 : 1565577.7987566285
# Residual after set 432 : 1558942.1249386515
# Residual after set 433 : 1552146.5045869765
# Residual after set 434 : 1545575.5038192538
# Residual after set 435 : 1538873.6474484615
# Residual after set 436 : 1532070.454761159
# Residual after set 437 : 1525720.894986502
# Residual after set 438 : 1518715.883738998
# Residual after set 439 : 1511985.7978503949
# Residual after set 440 : 1505562.5112739631
# Residual after set 441 : 1499003.0214240712
# Residual after set 442 : 1492875.8847632713
# Residual after set 443 : 1486539.3608442422
# Residual after set 444 : 1479991.106825392
# Residual after set 445 : 1474068.7580024276
# Residual after set 446 : 1467899.581845051
# Residual after set 447 : 1461591.5835525596
# Residual after set 448 : 1455394.0236379083
# Residual after set 449 : 1449097.4147432921
# Residual after set 450 : 1442712.3349199847
# Residual after set 451 : 1436390.9184978032
# Residual after set 452 : 1430032.1498759687
# Residual after set 453 : 1423554.907048879
# Residual after set 454 : 1417436.251739389
# Residual after set 455 : 1411188.2665730356
# Residual after set 456 : 1405142.743496858
# Residual after set 457 : 1399219.5234238943
# Residual after set 458 : 1393107.7731430589
# Residual after set 459 : 1387135.320615761
# Residual after set 460 : 1380747.6906311463
# Residual after set 461 : 1374576.8442668938
# Residual after set 462 : 1368564.447313472
# Residual after set 463 : 1362536.4263692794
# Residual after set 464 : 1356139.0827870055
# Residual after set 465 : 1349993.8730789472
# Residual after set 466 : 1344103.6699816184
# Residual after set 467 : 1338163.0557688938
# Residual after set 468 : 1332166.854422062
# Residual after set 469 : 1326075.0867212513
# Residual after set 470 : 1320060.8823300414
# Residual after set 471 : 1313893.0408944248
# Residual after set 472 : 1307875.5566515923
# Residual after set 473 : 1301847.0404694777
# Residual after set 474 : 1295683.6280914748
# Residual after set 475 : 1289590.2487641536
# Residual after set 476 : 1283491.8008518973
# Residual after set 477 : 1277939.231564075
# Residual after set 478 : 1272073.3063248943
# Residual after set 479 : 1266523.7536215908
# Residual after set 480 : 1260667.1270418533
# Residual after set 481 : 1254687.9793742846
# Residual after set 482 : 1248789.6162219048
# Residual after set 483 : 1242816.3035746948
# Residual after set 484 : 1236991.6953204684
# Residual after set 485 : 1231194.1404347478
# Residual after set 486 : 1225442.5584826984
# Residual after set 487 : 1219579.541138343
# Residual after set 488 : 1214102.2572582106
# Residual after set 489 : 1208668.6630242274
# Residual after set 490 : 1203075.3973517392
# Residual after set 491 : 1197589.995236523
# Residual after set 492 : 1192039.0560233383
# Residual after set 493 : 1186363.006123197
# Residual after set 494 : 1180497.3439750515
# Residual after set 495 : 1174899.7036045985
# Residual after set 496 : 1169425.5720764974
# Residual after set 497 : 1163889.7822733202
# Residual after set 498 : 1158513.0116114297
# Residual after set 499 : 1153015.7515569532
# Residual after set 500 : 1147384.009568643
# Residual after set 501 : 1141527.0392046259
# Residual after set 502 : 1136191.6959961196
# Residual after set 503 : 1131008.130059472
# Residual after set 504 : 1125869.6674934584
# Residual after set 505 : 1120419.4779570268
# Residual after set 506 : 1115108.3126516952
# Residual after set 507 : 1109623.0442107841
# Residual after set 508 : 1104252.0922845774
# Residual after set 509 : 1099327.382437887
# Residual after set 510 : 1093980.3929548077
# Residual after set 511 : 1088223.934766277
# Residual after set 512 : 1083126.3178400316
# Residual after set 513 : 1078075.6085168514
# Residual after set 514 : 1073094.7159870255
# Residual after set 515 : 1068077.8446307569
# Residual after set 516 : 1062787.1189399231
# Residual after set 517 : 1057471.4226909534
# Residual after set 518 : 1052070.7082148723
# Residual after set 519 : 1046697.8201043063
# Residual after set 520 : 1041766.2842955812
# Residual after set 521 : 1036522.0320541583
# Residual after set 522 : 1031343.2388534542
# Residual after set 523 : 1026223.5298419658
# Residual after set 524 : 1021089.8602489085
# Residual after set 525 : 1015962.9980182028
# Residual after set 526 : 1010948.3823550687
# Residual after set 527 : 1005889.8535726243
# Residual after set 528 : 1000934.5194078381
# Residual after set 529 : 996172.0426785415
# Residual after set 530 : 991122.267306424
# Residual after set 531 : 986080.1571637384
# Residual after set 532 : 981244.5624692829
# Residual after set 533 : 976142.4236951558
# Residual after set 534 : 971363.379266501
# Residual after set 535 : 966581.9186490125
# Residual after set 536 : 961771.4680335227
# Residual after set 537 : 956999.3821037351
# Residual after set 538 : 952243.5367413574
# Residual after set 539 : 947673.3102874659
# Residual after set 540 : 942764.3859437766
# Residual after set 541 : 937843.1821989162
# Residual after set 542 : 933123.7148758564
# Residual after set 543 : 928439.1550100191
# Residual after set 544 : 923582.3046534903
# Residual after set 545 : 918780.7918541944
# Residual after set 546 : 913821.0581215451
# Residual after set 547 : 909120.4929432386
# Residual after set 548 : 904401.513497664
# Residual after set 549 : 899603.6454682847
# Residual after set 550 : 894997.41383025
# Residual after set 551 : 890383.2995439079
# Residual after set 552 : 885730.5469266996
# Residual after set 553 : 881088.2870357197
# Residual after set 554 : 876933.9416793699
# Residual after set 555 : 872565.8731543787
# Residual after set 556 : 867561.5435444359
# Residual after set 557 : 862989.7695234765
# Residual after set 558 : 858555.4437161413
# Residual after set 559 : 853863.3916418776
# Residual after set 560 : 849628.5428132025
# Residual after set 561 : 845535.5416372938
# Residual after set 562 : 841149.1687871456
# Residual after set 563 : 836674.1454166307
# Residual after set 564 : 832404.0391477112
# Residual after set 565 : 827914.6889429548
# Residual after set 566 : 823630.581479358
# Residual after set 567 : 818995.3035825971
# Residual after set 568 : 814626.1309004935
# Residual after set 569 : 810352.0589286657
# Residual after set 570 : 806135.4856106561
# Residual after set 571 : 801658.6314587288
# Residual after set 572 : 797656.4485831665
# Residual after set 573 : 793641.0481695761
# Residual after set 574 : 789351.3474861955
# Residual after set 575 : 785125.073616924
# Residual after set 576 : 780751.5301143664
# Residual after set 577 : 776739.5149220196
# Residual after set 578 : 772638.975704032
# Residual after set 579 : 768650.2195620881
# Residual after set 580 : 764408.2960164626
# Residual after set 581 : 760099.8796052113
# Residual after set 582 : 756055.8586947364
# Residual after set 583 : 751654.8139644584
# Residual after set 584 : 747368.3572115048
# Residual after set 585 : 743353.4625944232
# Residual after set 586 : 739260.1267902541
# Residual after set 587 : 735361.4624166114
# Residual after set 588 : 731305.8662066951
# Residual after set 589 : 727288.3477596422
# Residual after set 590 : 723304.7766593345
# Residual after set 591 : 719190.5850410443
# Residual after set 592 : 714949.2887242651
# Residual after set 593 : 710967.7988254931
# Residual after set 594 : 706842.4251906518
# Residual after set 595 : 703194.8398915264
# Residual after set 596 : 699304.259484675
# Residual after set 597 : 695140.7218251863
# Residual after set 598 : 691099.113761108
# Residual after set 599 : 687005.9854853771
# Residual after set 600 : 683066.0777999947
# Residual after set 601 : 679095.7597541456
# Residual after set 602 : 675084.1206613939
# Residual after set 603 : 671454.6432097107
# Residual after set 604 : 667494.9700070978
# Residual after set 605 : 663884.8139460277
# Residual after set 606 : 660264.9723625412
# Residual after set 607 : 656605.1968538694
# Residual after set 608 : 652885.6271438
# Residual after set 609 : 649210.1785998761
# Residual after set 610 : 645296.2383969247
# Residual after set 611 : 641666.5458806771
# Residual after set 612 : 637979.5758017532
# Residual after set 613 : 634195.6370485661
# Residual after set 614 : 630867.1429222425
# Residual after set 615 : 627032.8052807302
# Residual after set 616 : 623314.5263333238
# Residual after set 617 : 619722.8274343002
# Residual after set 618 : 615976.0857509159
# Residual after set 619 : 612405.4682489039
# Residual after set 620 : 608913.3176126506
# Residual after set 621 : 605429.7026454704
# Residual after set 622 : 601846.072285046
# Residual after set 623 : 598170.3591403038
# Residual after set 624 : 594566.1359384134
# Residual after set 625 : 590988.103174687
# Residual after set 626 : 587476.6643986917
# Residual after set 627 : 584242.0151214623
# Residual after set 628 : 580900.8181185289
# Residual after set 629 : 577373.7314802217
# Residual after set 630 : 573907.8257499131
# Residual after set 631 : 570498.7935144623
# Residual after set 632 : 567175.949866887
# Residual after set 633 : 563705.0613765792
# Residual after set 634 : 560321.5594885251
# Residual after set 635 : 556779.6970471127
# Residual after set 636 : 553497.5532283102
# Residual after set 637 : 550045.0602771586
# Residual after set 638 : 546657.2420670217
# Residual after set 639 : 543232.0174985036
# Residual after set 640 : 540000.3830570224
# Residual after set 641 : 536461.4009417978
# Residual after set 642 : 533192.2738881125
# Residual after set 643 : 529674.6672646726
# Residual after set 644 : 526225.5577128363
# Residual after set 645 : 523045.13844088424
# Residual after set 646 : 519679.8595850835
# Residual after set 647 : 516315.90415701334
# Residual after set 648 : 513080.5829827374
# Residual after set 649 : 509829.43840073835
# Residual after set 650 : 506523.32399759657
# Residual after set 651 : 503654.80392435985
# Residual after set 652 : 500292.04467648006
# Residual after set 653 : 497104.5697479609
# Residual after set 654 : 493661.6655068424
# Residual after set 655 : 490753.6044826376
# Residual after set 656 : 487673.3029451536
# Residual after set 657 : 484460.80232837354
# Residual after set 658 : 481512.29933481326
# Residual after set 659 : 478273.4135313617
# Residual after set 660 : 475262.00259830366
# Residual after set 661 : 471926.52589163405
# Residual after set 662 : 468696.9598435123
# Residual after set 663 : 465337.3968045134
# Residual after set 664 : 462352.0298486396
# Residual after set 665 : 459168.29330549715
# Residual after set 666 : 456188.37008979503
# Residual after set 667 : 453189.3877265987
# Residual after set 668 : 450154.9912200095
# Residual after set 669 : 447121.5201972772
# Residual after set 670 : 443958.96340637835
# Residual after set 671 : 440902.4040566487
# Residual after set 672 : 438020.7634177287
# Residual after set 673 : 434889.96865141985
# Residual after set 674 : 431998.3307089937
# Residual after set 675 : 429041.8126731366
# Residual after set 676 : 425910.39605762064
# Residual after set 677 : 422836.6384431883
# Residual after set 678 : 420010.03428228054
# Residual after set 679 : 417110.29822075414
# Residual after set 680 : 414080.07765193284
# Residual after set 681 : 411247.9090001704
# Residual after set 682 : 408420.7248597233
# Residual after set 683 : 405617.02989661606
# Residual after set 684 : 402811.4673630617
# Residual after set 685 : 399973.93258809834
# Residual after set 686 : 396982.9336514789
# Residual after set 687 : 393933.13620409166
# Residual after set 688 : 390949.0671615788
# Residual after set 689 : 388173.7693435225
# Residual after set 690 : 385242.96226383536
# Residual after set 691 : 382578.6686644178
# Residual after set 692 : 379664.31522225845
# Residual after set 693 : 376972.3353957877
# Residual after set 694 : 374341.3462642243
# Residual after set 695 : 371780.95863939216
# Residual after set 696 : 369003.9410803865
# Residual after set 697 : 366100.81657115713
# Residual after set 698 : 363252.7889269502
# Residual after set 699 : 360720.83878942503
# Residual after set 700 : 358186.1904517142
# Residual after set 701 : 355572.9973890764
# Residual after set 702 : 352939.650697308
# Residual after set 703 : 350475.4083566302
# Residual after set 704 : 347854.91454258433
# Residual after set 705 : 345315.19485138485
# Residual after set 706 : 342753.67434379103
# Residual after set 707 : 340077.0269726887
# Residual after set 708 : 337555.62145595864
# Residual after set 709 : 334975.1629819727
# Residual after set 710 : 332275.82323368645
# Residual after set 711 : 329753.9482532068
# Residual after set 712 : 327298.34206239856
# Residual after set 713 : 325023.4760782821
# Residual after set 714 : 322782.6718173753
# Residual after set 715 : 320108.50354010897
# Residual after set 716 : 317757.02536868013
# Residual after set 717 : 315351.1994884866
# Residual after set 718 : 312921.81636832486
# Residual after set 719 : 310334.1534193316
# Residual after set 720 : 307803.5345360858
# Residual after set 721 : 305336.6832657692
# Residual after set 722 : 303065.4810213227
# Residual after set 723 : 300690.04599689954
# Residual after set 724 : 298130.2912014553
# Residual after set 725 : 295696.8062950131
# Residual after set 726 : 293222.53325146734
# Residual after set 727 : 290885.8617917755
# Residual after set 728 : 288416.98889788816
# Residual after set 729 : 286211.49217001663
# Residual after set 730 : 283662.91880130675
# Residual after set 731 : 281445.308763297
# Residual after set 732 : 278995.9193851392
# Residual after set 733 : 276887.8975653004
# Residual after set 734 : 274659.47509652865
# Residual after set 735 : 272528.54031796154
# Residual after set 736 : 270243.01189850195
# Residual after set 737 : 268075.2433074521
# Residual after set 738 : 265842.14132384816
# Residual after set 739 : 263574.36414747144
# Residual after set 740 : 261224.13226120893
# Residual after set 741 : 259098.4174811329
# Residual after set 742 : 256910.64236778027
# Residual after set 743 : 254579.71052570062
# Residual after set 744 : 252354.9491064977
# Residual after set 745 : 250040.49803961298
# Residual after set 746 : 247970.576959664
# Residual after set 747 : 245717.28004444946
# Residual after set 748 : 243673.44990990328
# Residual after set 749 : 241583.0802079569
# Residual after set 750 : 239546.06981655408
# Residual after set 751 : 237516.43803962326
# Residual after set 752 : 235529.59983073326
# Residual after set 753 : 233408.9089022843
# Residual after set 754 : 231173.4707549778
# Residual after set 755 : 229232.10068463045
# Residual after set 756 : 227286.31628617574
# Residual after set 757 : 225237.03499450753
# Residual after set 758 : 223264.25313871837
# Residual after set 759 : 221286.65823363533
# Residual after set 760 : 219208.12843271947
# Residual after set 761 : 217257.4472008113
# Residual after set 762 : 215304.0936145583
# Residual after set 763 : 213277.9086394294
# Residual after set 764 : 211520.6688801754
# Residual after set 765 : 209692.1643253109
# Residual after set 766 : 207676.5614686355
# Residual after set 767 : 205750.66906507468
# Residual after set 768 : 203855.73949306062
# Residual after set 769 : 201891.17112070165
# Residual after set 770 : 200084.87602411557
# Residual after set 771 : 198205.2667392375
# Residual after set 772 : 196200.01680355796
# Residual after set 773 : 194496.63252600262
# Residual after set 774 : 192678.17389975683
# Residual after set 775 : 190943.04903700636
# Residual after set 776 : 189262.0050965807
# Residual after set 777 : 187633.75069279893
# Residual after set 778 : 185709.88198173148
# Residual after set 779 : 183906.7939997686
# Residual after set 780 : 182155.04985328662
# Residual after set 781 : 180349.6255067744
# Residual after set 782 : 178516.08878200396
# Residual after set 783 : 176691.691139945
# Residual after set 784 : 175085.98694340175
# Residual after set 785 : 173349.0472020778
# Residual after set 786 : 171581.55735960967
# Residual after set 787 : 169836.44141230572
# Residual after set 788 : 168098.5821777621
# Residual after set 789 : 166441.39371752643
# Residual after set 790 : 164807.52477934895
# Residual after set 791 : 163129.47801658828
# Residual after set 792 : 161533.42529892534
# Residual after set 793 : 159930.33568526464
# Residual after set 794 : 158233.54931578727
# Residual after set 795 : 156608.77462260693
# Residual after set 796 : 154942.43688753154
# Residual after set 797 : 153232.1267334124
# Residual after set 798 : 151518.23093055902
# Residual after set 799 : 149880.2394288417
# Residual after set 800 : 148466.78975224524
# Residual after set 801 : 147013.63014484447
# Residual after set 802 : 145402.99307530245
# Residual after set 803 : 143752.50236398808
# Residual after set 804 : 142199.19675544783
# Residual after set 805 : 140683.36372128973
# Residual after set 806 : 139033.258860473
# Residual after set 807 : 137600.47276709817
# Residual after set 808 : 136103.8843926313
# Residual after set 809 : 134633.27595774073
# Residual after set 810 : 133320.58968300128
# Residual after set 811 : 131745.51365239138
# Residual after set 812 : 130257.3854584493
# Residual after set 813 : 128922.42712042735
# Residual after set 814 : 127675.91990362002
# Residual after set 815 : 126282.08892654876
# Residual after set 816 : 124795.11819789476
# Residual after set 817 : 123511.09540747966
# Residual after set 818 : 122154.37898489244
# Residual after set 819 : 120787.09528720977
# Residual after set 820 : 119421.66245998345
# Residual after set 821 : 118094.66693100856
# Residual after set 822 : 116892.75630050921
# Residual after set 823 : 115693.20253794652
# Residual after set 824 : 114512.1031073621
# Residual after set 825 : 113248.23606394231
# Residual after set 826 : 111930.75539587307
# Residual after set 827 : 110686.83206921464
# Residual after set 828 : 109421.04602306677
# Residual after set 829 : 108193.39136680882
# Residual after set 830 : 106887.43846785455
# Residual after set 831 : 105601.50183479892
# Residual after set 832 : 104378.36019410937
# Residual after set 833 : 103180.98810041914
# Residual after set 834 : 101942.11734508857
# Residual after set 835 : 100694.61111431976
# Residual after set 836 : 99519.90471029241
# Residual after set 837 : 98307.38097217481
# Residual after set 838 : 97137.5048506377
# Residual after set 839 : 95969.9419835017
# Residual after set 840 : 94866.02429538949
# Residual after set 841 : 93624.96391267174
# Residual after set 842 : 92544.16694688615
# Residual after set 843 : 91369.97389436133
# Residual after set 844 : 90306.99576583343
# Residual after set 845 : 89210.43345439315
# Residual after set 846 : 88062.21330485323
# Residual after set 847 : 87019.50784482248
# Residual after set 848 : 86029.11237113053
# Residual after set 849 : 85027.17577948634
# Residual after set 850 : 83953.06292642906
# Residual after set 851 : 82865.14233401393
# Residual after set 852 : 81819.17622733522
# Residual after set 853 : 80667.71094536211
# Residual after set 854 : 79800.91654509428
# Residual after set 855 : 78754.78046420855
# Residual after set 856 : 77824.98241807801
# Residual after set 857 : 76866.23721906889
# Residual after set 858 : 75970.71903372016
# Residual after set 859 : 74962.48613884565
# Residual after set 860 : 74030.94955753234
# Residual after set 861 : 72994.33992448296
# Residual after set 862 : 71997.46791425234
# Residual after set 863 : 71113.66734361989
# Residual after set 864 : 70223.07455432712
# Residual after set 865 : 69300.60778371806
# Residual after set 866 : 68363.22157713448
# Residual after set 867 : 67450.55554978037
# Residual after set 868 : 66510.20931616442
# Residual after set 869 : 65619.71234342472
# Residual after set 870 : 64712.438464521234
# Residual after set 871 : 63847.25729393912
# Residual after set 872 : 62994.539368968515
# Residual after set 873 : 62200.388521514746
# Residual after set 874 : 61278.81955620281
# Residual after set 875 : 60397.86669274123
# Residual after set 876 : 59534.807964976106
# Residual after set 877 : 58735.37770767252
# Residual after set 878 : 57922.050145697496
# Residual after set 879 : 57079.312677210066
# Residual after set 880 : 56306.91632475387
# Residual after set 881 : 55473.93582357069
# Residual after set 882 : 54668.15018546379
# Residual after set 883 : 53993.51964036457
# Residual after set 884 : 53222.30687828492
# Residual after set 885 : 52458.35495492466
# Residual after set 886 : 51698.39979954742
# Residual after set 887 : 50899.195002676905
# Residual after set 888 : 50102.42669396871
# Residual after set 889 : 49457.40596566786
# Residual after set 890 : 48707.30015460648
# Residual after set 891 : 47958.325969050755
# Residual after set 892 : 47249.47702995342
# Residual after set 893 : 46531.816520887274
# Residual after set 894 : 45811.1676599883
# Residual after set 895 : 45084.462730397216
# Residual after set 896 : 44369.6097952818
# Residual after set 897 : 43705.835177373454
# Residual after set 898 : 42989.408916819535
# Residual after set 899 : 42354.726215067574
# Residual after set 900 : 41668.53346159985
# Residual after set 901 : 40976.70930387604
# Residual after set 902 : 40398.5297696139
# Residual after set 903 : 39744.61150499871
# Residual after set 904 : 39088.476057690226
# Residual after set 905 : 38475.4597582661
# Residual after set 906 : 37816.047887857676
# Residual after set 907 : 37179.15599556129
# Residual after set 908 : 36534.0923152236
# Residual after set 909 : 35898.38534447033
# Residual after set 910 : 35270.337263295245
# Residual after set 911 : 34736.46254580895
# Residual after set 912 : 34109.81428083639
# Residual after set 913 : 33543.56337012205
# Residual after set 914 : 32966.86648839237
# Residual after set 915 : 32382.897412750855
# Residual after set 916 : 31785.00744147598
# Residual after set 917 : 31173.183558719702
# Residual after set 918 : 30601.547777485262
# Residual after set 919 : 30016.825230732284
# Residual after set 920 : 29466.90034358992
# Residual after set 921 : 28942.382084042976
# Residual after set 922 : 28402.748236704123
# Residual after set 923 : 27878.89441309841
# Residual after set 924 : 27335.481925064487
# Residual after set 925 : 26835.333020815033
# Residual after set 926 : 26364.050147699974
# Residual after set 927 : 25890.80411489056
# Residual after set 928 : 25450.14399109152
# Residual after set 929 : 24975.549292057374
# Residual after set 930 : 24490.77065435185
# Residual after set 931 : 23984.439388025607
# Residual after set 932 : 23510.2663772501
# Residual after set 933 : 23124.67207595077
# Residual after set 934 : 22681.522006037456
# Residual after set 935 : 22240.200170839173
# Residual after set 936 : 21808.18256957077
# Residual after set 937 : 21357.701180549466
# Residual after set 938 : 20956.749958930868
# Residual after set 939 : 20572.499115167422
# Residual after set 940 : 20149.466416988937
# Residual after set 941 : 19738.05350698903
# Residual after set 942 : 19325.30057220207
# Residual after set 943 : 18939.42177245587
# Residual after set 944 : 18584.870225677358
# Residual after set 945 : 18210.72132171618
# Residual after set 946 : 17850.477807321364
# Residual after set 947 : 17504.28015179116
# Residual after set 948 : 17141.172384579713
# Residual after set 949 : 16822.7020054506
# Residual after set 950 : 16442.470049079744
# Residual after set 951 : 16056.299709043007
# Residual after set 952 : 15755.970486690227
# Residual after set 953 : 15415.824793941398
# Residual after set 954 : 15075.788248464318
# Residual after set 955 : 14746.08781118047
# Residual after set 956 : 14454.265159380928
# Residual after set 957 : 14124.512113452769
# Residual after set 958 : 13816.906036987419
# Residual after set 959 : 13485.04129954909
# Residual after set 960 : 13189.42926630094
# Residual after set 961 : 12886.915545076741
# Residual after set 962 : 12586.55521209493
# Residual after set 963 : 12280.523559298928
# Residual after set 964 : 11979.37556588161
# Residual after set 965 : 11723.609480859774
# Residual after set 966 : 11450.658637573806
# Residual after set 967 : 11171.609946626479
# Residual after set 968 : 10882.265458585842
# Residual after set 969 : 10628.72376667007
# Residual after set 970 : 10367.901356213233
# Residual after set 971 : 10093.031967704426
# Residual after set 972 : 9832.379455600536
# Residual after set 973 : 9573.82464589231
# Residual after set 974 : 9312.660906208297
# Residual after set 975 : 9057.64730456965
# Residual after set 976 : 8801.540377732827
# Residual after set 977 : 8603.219561979076
# Residual after set 978 : 8357.880386554845
# Residual after set 979 : 8162.138090222593
# Residual after set 980 : 7987.689706848258
# Residual after set 981 : 7773.643439643762
# Residual after set 982 : 7555.399756841414
# Residual after set 983 : 7371.051357070409
# Residual after set 984 : 7150.782315703017
# Residual after set 985 : 6941.657615695057
# Residual after set 986 : 6732.211164867738
# Residual after set 987 : 6528.526135504702
# Residual after set 988 : 6335.965829480571
# Residual after set 989 : 6136.794223932626
# Residual after set 990 : 5926.817517422049
# Residual after set 991 : 5738.4469947154585
# Residual after set 992 : 5537.81137320646
# Residual after set 993 : 5345.5623179004415
# Residual after set 994 : 5154.697654143005
# Residual after set 995 : 4995.929902999752
# Residual after set 996 : 4828.1053596215
# Residual after set 997 : 4696.710509530318
# Residual after set 998 : 4533.287169534178
# Residual after set 999 : 4383.975938004395
# Residual after set 1000 : 4237.994797889462
# Residual after set 1001 : 4070.0457744622763
# Residual after set 1002 : 3913.9054551346157
# Residual after set 1003 : 3775.211180762579
# Residual after set 1004 : 3625.573914023244
# Residual after set 1005 : 3486.3416706495022
# Residual after set 1006 : 3342.142325327691
# Residual after set 1007 : 3210.2121069740447
# Residual after set 1008 : 3077.037269343568
# Residual after set 1009 : 2970.5695044178956
# Residual after set 1010 : 2852.700196289228
# Residual after set 1011 : 2741.4422973422515
# Residual after set 1012 : 2651.252568439252
# Residual after set 1013 : 2544.187170999595
# Residual after set 1014 : 2429.1400828592864
# Residual after set 1015 : 2311.1245701769444
# Residual after set 1016 : 2202.6258151173747
# Residual after set 1017 : 2099.667149869219
# Residual after set 1018 : 2004.987122710325
# Residual after set 1019 : 1911.2248892775292
# Residual after set 1020 : 1819.3878956139042
# Residual after set 1021 : 1727.1318030718585
# Residual after set 1022 : 1633.0504146928633
# Residual after set 1023 : 1543.625456707291
# Residual after set 1024 : 1466.020899185185
# Residual after set 1025 : 1406.2446715230594
# Residual after set 1026 : 1333.5178140943817
# Residual after set 1027 : 1265.1823167128
# Residual after set 1028 : 1197.313943448154
# Residual after set 1029 : 1125.7335177457242
# Residual after set 1030 : 1068.9647025233937
# Residual after set 1031 : 998.4747689237606
# Residual after set 1032 : 931.7284958748135
# Residual after set 1033 : 869.7544774933813
# Residual after set 1034 : 817.1558919397157
# Residual after set 1035 : 757.6619694893384
# Residual after set 1036 : 697.1759337101428
# Residual after set 1037 : 644.9785379187974
# Residual after set 1038 : 591.545113368594
# Residual after set 1039 : 553.2716362996468
# Residual after set 1040 : 498.496042615957
# Residual after set 1041 : 460.70269620476256
# Residual after set 1042 : 417.64462272284254
# Residual after set 1043 : 376.49308980521823
# Residual after set 1044 : 340.17467153988775
# Residual after set 1045 : 305.4344964645326
# Residual after set 1046 : 277.47205831667213
# Residual after set 1047 : 246.0390133993127
# Residual after set 1048 : 213.65970548480044
# Residual after set 1049 : 188.82038027815366
# Residual after set 1050 : 155.11596804750252
# Residual after set 1051 : 129.82155759880382
# Residual after set 1052 : 106.9722174216347
# Residual after set 1053 : 89.43651536847884
# Residual after set 1054 : 69.97406210251415
# Residual after set 1055 : 53.940068058849086
# Residual after set 1056 : 44.31503290424689
# Residual after set 1057 : 36.45485442246045
# Residual after set 1058 : 29.08280433026842
# Residual after set 1059 : 21.853790385343952
# Residual after set 1060 : 17.45277244709693
# Residual after set 1061 : 13.62710705898687
# Residual after set 1062 : 9.852323991812558
# Residual after set 1063 : 7.94382131655907
# Residual after set 1064 : 6.29376683331716
# Final residual non-zeros = 7, max = 1.89, mean = 0.00

# %%
print(f"Remaining nonzero entries = {np.count_nonzero(R_2)}, Max = {np.max(R_2):.2f}, Mean = {np.mean(R_2):.2f}")
# Out:
# Remaining nonzero entries = 7, Max = 1.89, Mean = 0.00

# %%
plt_data=[0]
r_sum=sum([demand['density'] for demand in demand_list])*time_split
for item in process:
    for _ in range(item[0]):
        v=item[1]/item[0]/r_sum*100+plt_data[-1]
        plt_data.append(v)
np.save("data/network_availability_Latin_America_demand.npy",plt_data)

# %%
time_shift=0
total_supply=[0]*len(demand_list)
for cover in tqdm(all_cover):
    cover_csr = cover[2][0]
    sat_num = cover[3]
    total_supply += cover_csr.toarray().flatten()[len(demand_list)*time_shift:len(demand_list)*(time_shift+1)] * sat_num
# Out:
# 100%|██████████| 1065/1065 [00:06<00:00, 162.94it/s]

# %%
supply_demand_ratio=[]
for idx,demand in enumerate(demand_list):
    if demand['density']!=0:
        supply_demand_ratio.append(total_supply[idx]/demand['density'])
print(np.mean(supply_demand_ratio))
np.save("data/supply_demand_ratio_south.npy",supply_demand_ratio)
# Out:
# 174.43454264899722

# %%
def FeasibilityCheck_one_slot(params):
    t,mega=params
    two_pi=2*np.pi
    total_supply=[]
    for idx,shell in tqdm(enumerate(mega)):
        T=T_list[idx]
        eta=coverage_eta(T)
        inc=inc_list[idx]
        for mid in range(shell["m"]):
            for nid in range(shell["n"]):
                r_set=[]
                a_sat=(two_pi/shell["m"]*mid-t/TE*two_pi)%two_pi
                b_sat=(two_pi/shell["n"]*nid+t/T*two_pi)%two_pi
                l_sat,p_sat=alpha_gamma_to_lambda_phi(a_sat,b_sat,inc)
                for idx,demand in enumerate(demand_list):
                    l_cell=demand['lat_lon'][1]
                    p_cell=demand['lat_lon'][0]
                    r=is_cover(l_sat,p_sat,l_cell,p_cell,eta) #用经纬度判断
                    if r:
                        S=S_set[idx]
                        r_set.append([idx,S,demand['density']])
                if len(r_set)!=0:
                    S_sum=np.sum([item[1] for item in r_set])
                    factor=user_per_sat/S_sum
                    r_set=[[item[0],item[1]*factor]for item in r_set]
                    total_supply.append(r_set)
    # check the demand
    supply=[0]*len(demand_list)
    for r_set in total_supply:
        for item in r_set:
            supply[item[0]]+=item[1]
    return supply

# %%
south_data=np.load("data/MegaReduce_South_America.npy",allow_pickle=True)
selected_data_south=south_data[-1][0]
T_list = np.array([satellite_period(shell["h"] * 1e3) for shell in selected_data_south])
inc_list = np.radians(np.array([shell["inc"] for shell in selected_data_south]))
total_supply_south=FeasibilityCheck_one_slot([0,selected_data_south])

demand_list=np.load("data/south_america_starlink_demand_99449.npy",allow_pickle=True)
for idx in range(len(demand_list)):
    demand_list[idx]['lat_lon'][0]=np.radians(demand_list[idx]['lat_lon'][0])
    demand_list[idx]['lat_lon'][1]=np.radians(demand_list[idx]['lat_lon'][1])

supply_demand_ratio=[]
for idx,demand in enumerate(demand_list):
    if demand['density']!=0:
        supply_demand_ratio.append(total_supply_south[idx]/demand['density'])
print(np.mean(supply_demand_ratio))
np.save("data/supply_demand_ratio_south_megareduce.npy",supply_demand_ratio)
# Out:
# 353.84081046257586
