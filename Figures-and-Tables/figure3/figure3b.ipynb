# %%
import json
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import os
from datetime import datetime, timedelta
import matplotlib.ticker as ticker

# %%
folder_path = '../../Dataset/Cloudflare-dataset/traffic_data_from_cloudflare_0707/'  
json_files = [f for f in os.listdir(folder_path) if f.endswith('.json')]
# print(json_files)

# %%
def get_time_and_values(file):
    """
    Extracts timestamp and value pairs from a Cloudflare-style JSON file.

    Args:
        file (str): Path to the JSON file.

    Returns:
        list: A list of [timestamp, value] pairs, with value converted to float.
    """
    with open(file, 'r') as f:
        data = json.load(f)

    timestamps = data['result']['main']['timestamps']
    values = data['result']['main']['values']

    result = [[t, float(v)] for t, v in zip(timestamps, values)]
    return result

# %%
for json_file in json_files:
    json_file_path = folder_path + '/' + json_file
    country_name = json_file.split('_')[0]

    result = get_time_and_values(json_file_path)

    times = []
    values = []
    for item in result:

        # Record the hourly data within 24 hours
        if ':00:00Z' in item[0] and len(times) < 24:
            times.append(item[0])
            values.append(item[1])
    # Print max, min, and percentage difference of traffic values for a given country
    print(f'{country_name}: Max traffic = {max(values):.4f}, Min traffic = {min(values):.4f}, '
      f'Difference = {(max(values) - min(values)) * 100:.2f}%')

# Print the list of timestamps
print(times)
# Out:
# UY: Max traffic = 0.6514, Min traffic = 0.1645, Difference = 48.70%
# TH: Max traffic = 0.9099, Min traffic = 0.3153, Difference = 59.47%
# WS: Max traffic = 0.8340, Min traffic = 0.1476, Difference = 68.63%
# ZW: Max traffic = 0.8340, Min traffic = 0.2834, Difference = 55.05%
# TM: Max traffic = 0.7055, Min traffic = 0.1948, Difference = 51.07%
# AG: Max traffic = 0.8597, Min traffic = 0.1931, Difference = 66.66%
# DM: Max traffic = 0.7572, Min traffic = 0.1463, Difference = 61.09%
# FJ: Max traffic = 0.9081, Min traffic = 0.1938, Difference = 71.43%
# GF: Max traffic = 0.6765, Min traffic = 0.1030, Difference = 57.35%
# BS: Max traffic = 0.9870, Min traffic = 0.2779, Difference = 70.91%
# TV: Max traffic = 0.7363, Min traffic = 0.0234, Difference = 71.30%
# PH: Max traffic = 0.8883, Min traffic = 0.2536, Difference = 63.48%
# JE: Max traffic = 0.8020, Min traffic = 0.1205, Difference = 68.16%
# MX: Max traffic = 0.8381, Min traffic = 0.1937, Difference = 64.43%
# BR: Max traffic = 0.7732, Min traffic = 0.1662, Difference = 60.71%
# GL: Max traffic = 0.8004, Min traffic = 0.2348, Difference = 56.56%
# LT: Max traffic = 0.8034, Min traffic = 0.1889, Difference = 61.45%
# NF: Max traffic = 0.0816, Min traffic = 0.0000, Difference = 8.16%
# VI: Max traffic = 0.9504, Min traffic = 0.2542, Difference = 69.62%
# UA: Max traffic = 0.8570, Min traffic = 0.2474, Difference = 60.97%
# DK: Max traffic = 0.8829, Min traffic = 0.2300, Difference = 65.28%
# MC: Max traffic = 0.4489, Min traffic = 0.1005, Difference = 34.85%
# HM: Max traffic = 0.0000, Min traffic = 0.0000, Difference = 0.00%
# CO: Max traffic = 0.7777, Min traffic = 0.1585, Difference = 61.92%
# FK: Max traffic = 0.3930, Min traffic = 0.0000, Difference = 39.30%
# BF: Max traffic = 0.4833, Min traffic = 0.0153, Difference = 46.80%
# PF: Max traffic = 0.7599, Min traffic = 0.1501, Difference = 60.98%
# DZ: Max traffic = 0.6492, Min traffic = 0.0684, Difference = 58.08%
# BM: Max traffic = 0.9531, Min traffic = 0.3824, Difference = 57.07%
# IR: Max traffic = 0.6915, Min traffic = 0.1949, Difference = 49.66%
# BD: Max traffic = 0.7527, Min traffic = 0.1641, Difference = 58.86%
# TF: Max traffic = 0.1606, Min traffic = 0.0293, Difference = 13.13%
# LR: Max traffic = 0.5918, Min traffic = 0.0372, Difference = 55.46%
# SR: Max traffic = 0.9469, Min traffic = 0.1776, Difference = 76.92%
# NU: Max traffic = 0.1376, Min traffic = 0.0000, Difference = 13.76%
# SA: Max traffic = 0.8432, Min traffic = 0.2961, Difference = 54.71%
# LC: Max traffic = 0.7719, Min traffic = 0.1530, Difference = 61.89%
# HK: Max traffic = 0.9679, Min traffic = 0.3128, Difference = 65.51%
# KE: Max traffic = 0.6425, Min traffic = 0.1106, Difference = 53.19%
# IM: Max traffic = 0.8841, Min traffic = 0.2061, Difference = 67.80%
# AF: Max traffic = 0.9192, Min traffic = 0.2108, Difference = 70.84%
# ML: Max traffic = 0.6689, Min traffic = 0.0203, Difference = 64.85%
# IS: Max traffic = 0.6875, Min traffic = 0.1993, Difference = 48.82%
# AI: Max traffic = 0.9213, Min traffic = 0.1879, Difference = 73.34%
# IL: Max traffic = 0.9585, Min traffic = 0.3026, Difference = 65.59%
# TT: Max traffic = 0.9714, Min traffic = 0.1666, Difference = 80.49%
# ZA: Max traffic = 0.8986, Min traffic = 0.2120, Difference = 68.66%
# BY: Max traffic = 0.9231, Min traffic = 0.1948, Difference = 72.82%
# UZ: Max traffic = 0.9423, Min traffic = 0.2700, Difference = 67.23%
# SI: Max traffic = 0.8035, Min traffic = 0.1551, Difference = 64.85%
# NE: Max traffic = 0.6149, Min traffic = 0.0169, Difference = 59.80%
# TN: Max traffic = 0.6385, Min traffic = 0.0876, Difference = 55.09%
# GU: Max traffic = 0.5876, Min traffic = 0.1889, Difference = 39.87%
# FM: Max traffic = 0.5183, Min traffic = 0.1301, Difference = 38.81%
# MM: Max traffic = 0.9075, Min traffic = 0.1319, Difference = 77.56%
# ID: Max traffic = 0.9045, Min traffic = 0.3577, Difference = 54.68%
# GQ: Max traffic = 0.9016, Min traffic = 0.2518, Difference = 64.98%
# MV: Max traffic = 0.8494, Min traffic = 0.2302, Difference = 61.92%
# GH: Max traffic = 0.8355, Min traffic = 0.2442, Difference = 59.13%
# SM: Max traffic = 0.7064, Min traffic = 0.0644, Difference = 64.20%
# MD: Max traffic = 0.8696, Min traffic = 0.1982, Difference = 67.15%
# SE: Max traffic = 0.9259, Min traffic = 0.2815, Difference = 64.44%
# SV: Max traffic = 0.8205, Min traffic = 0.1204, Difference = 70.02%
# CK: Max traffic = 0.8234, Min traffic = 0.1516, Difference = 67.18%
# YT: Max traffic = 0.6119, Min traffic = 0.0755, Difference = 53.64%
# TR: Max traffic = 0.8759, Min traffic = 0.1609, Difference = 71.50%
# SC: Max traffic = 0.8433, Min traffic = 0.2256, Difference = 61.77%
# MA: Max traffic = 0.7288, Min traffic = 0.0433, Difference = 68.56%
# RO: Max traffic = 0.8801, Min traffic = 0.2637, Difference = 61.64%
# BN: Max traffic = 0.9223, Min traffic = 0.1955, Difference = 72.68%
# TO: Max traffic = 0.8640, Min traffic = 0.1264, Difference = 73.75%
# MW: Max traffic = 0.6458, Min traffic = 0.0663, Difference = 57.95%
# TC: Max traffic = 0.7784, Min traffic = 0.1157, Difference = 66.26%
# QA: Max traffic = 0.8566, Min traffic = 0.2558, Difference = 60.08%
# SX: Max traffic = 0.9683, Min traffic = 0.2768, Difference = 69.15%
# MK: Max traffic = 0.7408, Min traffic = 0.1333, Difference = 60.74%
# SO: Max traffic = 0.6023, Min traffic = 0.0419, Difference = 56.05%
# GS: Max traffic = 0.0592, Min traffic = 0.0000, Difference = 5.92%
# ES: Max traffic = 0.7836, Min traffic = 0.1660, Difference = 61.76%
# GI: Max traffic = 1.0000, Min traffic = 0.2484, Difference = 75.16%
# SG: Max traffic = 0.9338, Min traffic = 0.4198, Difference = 51.41%
# EG: Max traffic = 0.7769, Min traffic = 0.1399, Difference = 63.70%
# NA: Max traffic = 0.9204, Min traffic = 0.2334, Difference = 68.70%
# CX: Max traffic = 0.7974, Min traffic = 0.0000, Difference = 79.74%
# TW: Max traffic = 0.8671, Min traffic = 0.2874, Difference = 57.97%
# BL: Max traffic = 0.5269, Min traffic = 0.0538, Difference = 47.31%
# RE: Max traffic = 0.8171, Min traffic = 0.1066, Difference = 71.05%
# AM: Max traffic = 0.7298, Min traffic = 0.1366, Difference = 59.32%
# SL: Max traffic = 0.8205, Min traffic = 0.1505, Difference = 67.01%
# PT: Max traffic = 0.5282, Min traffic = 0.1012, Difference = 42.70%
# AU: Max traffic = 0.9008, Min traffic = 0.2083, Difference = 69.25%
# NC: Max traffic = 0.7896, Min traffic = 0.1276, Difference = 66.19%
# TD: Max traffic = 0.5590, Min traffic = 0.0261, Difference = 53.29%
# GR: Max traffic = 0.9319, Min traffic = 0.2156, Difference = 71.63%
# BT: Max traffic = 0.8136, Min traffic = 0.2155, Difference = 59.81%
# KH: Max traffic = 0.9040, Min traffic = 0.3541, Difference = 55.00%
# NR: Max traffic = 0.4258, Min traffic = 0.1317, Difference = 29.40%
# BE: Max traffic = 0.8768, Min traffic = 0.2475, Difference = 62.93%
# LA: Max traffic = 0.8441, Min traffic = 0.3342, Difference = 50.99%
# GP: Max traffic = 0.7854, Min traffic = 0.2096, Difference = 57.57%
# GB: Max traffic = 0.9043, Min traffic = 0.2170, Difference = 68.73%
# ER: Max traffic = 0.3503, Min traffic = 0.0679, Difference = 28.24%
# US: Max traffic = 0.8292, Min traffic = 0.4306, Difference = 39.86%
# AO: Max traffic = 0.9141, Min traffic = 0.1957, Difference = 71.84%
# CM: Max traffic = 0.7909, Min traffic = 0.1764, Difference = 61.45%
# CU: Max traffic = 0.8576, Min traffic = 0.2962, Difference = 56.15%
# SN: Max traffic = 0.6654, Min traffic = 0.0428, Difference = 62.26%
# MQ: Max traffic = 0.7480, Min traffic = 0.2164, Difference = 53.16%
# AR: Max traffic = 0.7807, Min traffic = 0.1804, Difference = 60.03%
# JP: Max traffic = 0.9396, Min traffic = 0.3674, Difference = 57.22%
# OM: Max traffic = 0.8535, Min traffic = 0.0900, Difference = 76.35%
# FO: Max traffic = 0.7268, Min traffic = 0.1499, Difference = 57.70%
# AT: Max traffic = 0.8094, Min traffic = 0.2337, Difference = 57.57%
# MG: Max traffic = 0.7481, Min traffic = 0.0479, Difference = 70.03%
# BQ: Max traffic = 0.7206, Min traffic = 0.0976, Difference = 62.30%
# GW: Max traffic = 0.5600, Min traffic = 0.0114, Difference = 54.86%
# ST: Max traffic = 0.6457, Min traffic = 0.0650, Difference = 58.06%
# NI: Max traffic = 0.7829, Min traffic = 0.1130, Difference = 66.99%
# AZ: Max traffic = 0.9746, Min traffic = 0.1121, Difference = 86.25%
# AE: Max traffic = 0.8894, Min traffic = 0.2378, Difference = 65.16%
# LS: Max traffic = 0.9482, Min traffic = 0.1446, Difference = 80.36%
# PR: Max traffic = 0.7250, Min traffic = 0.1963, Difference = 52.87%
# UG: Max traffic = 0.7596, Min traffic = 0.1063, Difference = 65.33%
# KY: Max traffic = 0.6718, Min traffic = 0.2104, Difference = 46.14%
# PW: Max traffic = 0.8916, Min traffic = 0.1980, Difference = 69.35%
# CF: Max traffic = 0.7358, Min traffic = 0.0051, Difference = 73.07%
# TZ: Max traffic = 0.8215, Min traffic = 0.1307, Difference = 69.09%
# GE: Max traffic = 0.9511, Min traffic = 0.1781, Difference = 77.29%
# IN: Max traffic = 0.8208, Min traffic = 0.1838, Difference = 63.70%
# BB: Max traffic = 0.7810, Min traffic = 0.1924, Difference = 58.85%
# VC: Max traffic = 0.8465, Min traffic = 0.1221, Difference = 72.44%
# PN: Max traffic = 0.6170, Min traffic = 0.0000, Difference = 61.70%
# SB: Max traffic = 0.6582, Min traffic = 0.2286, Difference = 42.96%
# VN: Max traffic = 0.8867, Min traffic = 0.2125, Difference = 67.41%
# RW: Max traffic = 0.9272, Min traffic = 0.1440, Difference = 78.32%
# LK: Max traffic = 0.8302, Min traffic = 0.2236, Difference = 60.66%
# AS: Max traffic = 0.6734, Min traffic = 0.0714, Difference = 60.20%
# KZ: Max traffic = 0.8647, Min traffic = 0.2354, Difference = 62.93%
# NO: Max traffic = 0.8751, Min traffic = 0.3364, Difference = 53.87%
# DO: Max traffic = 0.9098, Min traffic = 0.1994, Difference = 71.04%
# BJ: Max traffic = 0.6004, Min traffic = 0.0643, Difference = 53.60%
# IQ: Max traffic = 0.7913, Min traffic = 0.2506, Difference = 54.06%
# HT: Max traffic = 0.7757, Min traffic = 0.0934, Difference = 68.22%
# KN: Max traffic = 0.8680, Min traffic = 0.1687, Difference = 69.93%
# TJ: Max traffic = 0.9019, Min traffic = 0.3957, Difference = 50.62%
# PA: Max traffic = 0.6738, Min traffic = 0.1422, Difference = 53.15%
# MF: Max traffic = 0.7425, Min traffic = 0.1598, Difference = 58.27%
# CL: Max traffic = 0.8742, Min traffic = 0.2048, Difference = 66.94%
# KI: Max traffic = 1.0000, Min traffic = 0.1626, Difference = 83.74%
# SK: Max traffic = 0.7729, Min traffic = 0.1322, Difference = 64.07%
# NZ: Max traffic = 0.8100, Min traffic = 0.2041, Difference = 60.59%
# CR: Max traffic = 0.8455, Min traffic = 0.1273, Difference = 71.82%
# MU: Max traffic = 0.8239, Min traffic = 0.0988, Difference = 72.51%
# CC: Max traffic = 0.6177, Min traffic = 0.0000, Difference = 61.77%
# ZM: Max traffic = 0.8548, Min traffic = 0.1223, Difference = 73.25%
# LI: Max traffic = 1.0000, Min traffic = 0.0938, Difference = 90.62%
# KG: Max traffic = 0.8980, Min traffic = 0.1479, Difference = 75.01%
# FI: Max traffic = 0.8770, Min traffic = 0.4850, Difference = 39.21%
# VU: Max traffic = 0.7834, Min traffic = 0.1690, Difference = 61.44%
# DJ: Max traffic = 0.7906, Min traffic = 0.0975, Difference = 69.30%
# BW: Max traffic = 0.9075, Min traffic = 0.1777, Difference = 72.99%
# JO: Max traffic = 0.8194, Min traffic = 0.1419, Difference = 67.75%
# IO: Max traffic = 0.0000, Min traffic = 0.0000, Difference = 0.00%
# GG: Max traffic = 0.7376, Min traffic = 0.1196, Difference = 61.80%
# BO: Max traffic = 0.7532, Min traffic = 0.1216, Difference = 63.16%
# ME: Max traffic = 0.8201, Min traffic = 0.1590, Difference = 66.11%
# BG: Max traffic = 0.9204, Min traffic = 0.2699, Difference = 65.04%
# MO: Max traffic = 0.9537, Min traffic = 0.3693, Difference = 58.44%
# CN: Max traffic = 0.8256, Min traffic = 0.3455, Difference = 48.01%
# MZ: Max traffic = 0.8659, Min traffic = 0.0852, Difference = 78.07%
# EE: Max traffic = 0.9335, Min traffic = 0.2781, Difference = 65.55%
# PY: Max traffic = 0.7109, Min traffic = 0.1636, Difference = 54.73%
# SY: Max traffic = 0.7441, Min traffic = 0.2485, Difference = 49.55%
# SH: Max traffic = 1.0000, Min traffic = 0.0000, Difference = 100.00%
# CG: Max traffic = 0.6431, Min traffic = 0.0743, Difference = 56.88%
# CW: Max traffic = 0.8248, Min traffic = 0.2078, Difference = 61.70%
# BA: Max traffic = 0.8910, Min traffic = 0.1927, Difference = 69.84%
# BI: Max traffic = 0.6481, Min traffic = 0.1108, Difference = 53.73%
# CZ: Max traffic = 0.6866, Min traffic = 0.1865, Difference = 50.01%
# IE: Max traffic = 0.9140, Min traffic = 0.4118, Difference = 50.23%
# TK: Max traffic = 0.7777, Min traffic = 0.0000, Difference = 77.77%
# PS: Max traffic = 0.7840, Min traffic = 0.1157, Difference = 66.82%
# TL: Max traffic = 0.7641, Min traffic = 0.1823, Difference = 58.18%
# RS: Max traffic = 0.7859, Min traffic = 0.2039, Difference = 58.21%
# ET: Max traffic = 0.7463, Min traffic = 0.1098, Difference = 63.65%
# AW: Max traffic = 0.8878, Min traffic = 0.1516, Difference = 73.62%
# LB: Max traffic = 0.7623, Min traffic = 0.1963, Difference = 56.59%
# MN: Max traffic = 0.6495, Min traffic = 0.0849, Difference = 56.46%
# CH: Max traffic = 0.8564, Min traffic = 0.2732, Difference = 58.32%
# KP: Max traffic = 0.6470, Min traffic = 0.0006, Difference = 64.64%
# AX: Max traffic = 0.6681, Min traffic = 0.0792, Difference = 58.89%
# GM: Max traffic = 0.5602, Min traffic = 0.0434, Difference = 51.68%
# PL: Max traffic = 0.8432, Min traffic = 0.2188, Difference = 62.44%
# MY: Max traffic = 0.8560, Min traffic = 0.2760, Difference = 58.00%
# RU: Max traffic = 0.8839, Min traffic = 0.2936, Difference = 59.03%
# KM: Max traffic = 0.6154, Min traffic = 0.0264, Difference = 58.90%
# LU: Max traffic = 0.8650, Min traffic = 0.4266, Difference = 43.85%
# HU: Max traffic = 0.8551, Min traffic = 0.1903, Difference = 66.48%
# AQ: Max traffic = 0.8969, Min traffic = 0.0469, Difference = 85.00%
# AL: Max traffic = 0.8836, Min traffic = 0.1341, Difference = 74.95%
# JM: Max traffic = 0.9688, Min traffic = 0.2125, Difference = 75.63%
# YE: Max traffic = 0.6542, Min traffic = 0.0974, Difference = 55.68%
# VA: Max traffic = 0.7506, Min traffic = 0.0218, Difference = 72.88%
# HN: Max traffic = 0.7767, Min traffic = 0.1286, Difference = 64.81%
# PE: Max traffic = 0.8349, Min traffic = 0.1480, Difference = 68.69%
# GN: Max traffic = 0.5979, Min traffic = 0.0794, Difference = 51.85%
# MR: Max traffic = 0.5823, Min traffic = 0.0185, Difference = 56.38%
# GY: Max traffic = 0.9691, Min traffic = 0.1328, Difference = 83.62%
# CV: Max traffic = 0.5406, Min traffic = 0.0642, Difference = 47.63%
# BH: Max traffic = 0.8191, Min traffic = 0.1854, Difference = 63.37%
# EH: Max traffic = 0.8113, Min traffic = 0.0292, Difference = 78.21%
# TG: Max traffic = 0.7019, Min traffic = 0.0790, Difference = 62.30%
# EC: Max traffic = 0.8861, Min traffic = 0.1570, Difference = 72.91%
# PG: Max traffic = 0.8842, Min traffic = 0.2841, Difference = 60.01%
# WF: Max traffic = 0.3480, Min traffic = 0.0148, Difference = 33.32%
# DE: Max traffic = 0.8721, Min traffic = 0.3720, Difference = 50.02%
# NG: Max traffic = 0.7763, Min traffic = 0.1236, Difference = 65.27%
# VE: Max traffic = 0.8744, Min traffic = 0.1181, Difference = 75.63%
# LV: Max traffic = 0.9019, Min traffic = 0.2487, Difference = 65.31%
# SJ: Max traffic = 1.0000, Min traffic = 0.0137, Difference = 98.63%
# NP: Max traffic = 0.6391, Min traffic = 0.0783, Difference = 56.07%
# MS: Max traffic = 0.2656, Min traffic = 0.0009, Difference = 26.46%
# FR: Max traffic = 0.8550, Min traffic = 0.2746, Difference = 58.03%
# CA: Max traffic = 0.8423, Min traffic = 0.2805, Difference = 56.19%
# GT: Max traffic = 0.7386, Min traffic = 0.1157, Difference = 62.30%
# SS: Max traffic = 0.5671, Min traffic = 0.0213, Difference = 54.58%
# CY: Max traffic = 0.7674, Min traffic = 0.1747, Difference = 59.27%
# NL: Max traffic = 0.8650, Min traffic = 0.4909, Difference = 37.41%
# CD: Max traffic = 0.7293, Min traffic = 0.0621, Difference = 66.72%
# KW: Max traffic = 0.8395, Min traffic = 0.2500, Difference = 58.95%
# KR: Max traffic = 0.9002, Min traffic = 0.3108, Difference = 58.95%
# MH: Max traffic = 0.7706, Min traffic = 0.1739, Difference = 59.66%
# CI: Max traffic = 0.5967, Min traffic = 0.0703, Difference = 52.63%
# LY: Max traffic = 0.7398, Min traffic = 0.1900, Difference = 54.97%
# SD: Max traffic = 0.5768, Min traffic = 0.0445, Difference = 53.22%
# MT: Max traffic = 0.8642, Min traffic = 0.3696, Difference = 49.45%
# VG: Max traffic = 0.6669, Min traffic = 0.1240, Difference = 54.29%
# PM: Max traffic = 0.5557, Min traffic = 0.0272, Difference = 52.85%
# AD: Max traffic = 0.5717, Min traffic = 0.1522, Difference = 41.95%
# PK: Max traffic = 0.8393, Min traffic = 0.3617, Difference = 47.76%
# UM: Max traffic = 0.0000, Min traffic = 0.0000, Difference = 0.00%
# SZ: Max traffic = 0.8638, Min traffic = 0.2117, Difference = 65.22%
# BZ: Max traffic = 0.8035, Min traffic = 0.3500, Difference = 45.36%
# BV: Max traffic = 0.0000, Min traffic = 0.0000, Difference = 0.00%
# GA: Max traffic = 0.6846, Min traffic = 0.0799, Difference = 60.47%
# IT: Max traffic = 0.8659, Min traffic = 0.1598, Difference = 70.62%
# GD: Max traffic = 0.6724, Min traffic = 0.1152, Difference = 55.72%
# HR: Max traffic = 0.8869, Min traffic = 0.1763, Difference = 71.06%
# MP: Max traffic = 0.4828, Min traffic = 0.0666, Difference = 41.62%
# ['2025-07-05T14:00:00Z', '2025-07-05T15:00:00Z', '2025-07-05T16:00:00Z', '2025-07-05T17:00:00Z', '2025-07-05T18:00:00Z', '2025-07-05T19:00:00Z', '2025-07-05T20:00:00Z', '2025-07-05T21:00:00Z', '2025-07-05T22:00:00Z', '2025-07-05T23:00:00Z', '2025-07-06T00:00:00Z', '2025-07-06T01:00:00Z', '2025-07-06T02:00:00Z', '2025-07-06T03:00:00Z', '2025-07-06T04:00:00Z', '2025-07-06T05:00:00Z', '2025-07-06T06:00:00Z', '2025-07-06T07:00:00Z', '2025-07-06T08:00:00Z', '2025-07-06T09:00:00Z', '2025-07-06T10:00:00Z', '2025-07-06T11:00:00Z', '2025-07-06T12:00:00Z', '2025-07-06T13:00:00Z']

# %%
countries = ['US', 'DE', 'JP']
labels = [
    'United States',
    'Germany',
    'Japan'
]

# %%
begin = "2025-07-05-14"
end = "2025-07-06-13"

# %%
time_length = len(times)

# Two-dimensional list, each row represents the total active IP of a country
raw_active_ips = []

for country in countries:
    for json_file in json_files:
        json_file_path = folder_path + '/' + json_file
        country_name = json_file.split('_')[0]

        if country_name == country:
            result = get_time_and_values(json_file_path)

            times = []
            values = []
            for item in result:
        
                # 记录24小时内的整点数据
                if ':00:00Z' in item[0] and len(times) < 24:
                    times.append(item[0])
                    values.append(item[1])

            raw_active_ips.append(values)

for item in raw_active_ips:
    print(item)
# Out:
# [0.526864, 0.589153, 0.603992, 0.598283, 0.619906, 0.636373, 0.656985, 0.675401, 0.681899, 0.688526, 0.712099, 0.727058, 0.775383, 0.829169, 0.822818, 0.662805, 0.633441, 0.588004, 0.495624, 0.430661, 0.430615, 0.454022, 0.44511, 0.499063]
# [0.765099, 0.8269, 0.798261, 0.765966, 0.798311, 0.787165, 0.861582, 0.85397, 0.738949, 0.607341, 0.527475, 0.430473, 0.371975, 0.373224, 0.379653, 0.402661, 0.518739, 0.640352, 0.712627, 0.75298, 0.82797, 0.870935, 0.838067, 0.872136]
# [0.862139, 0.939637, 0.799552, 0.599876, 0.452041, 0.367442, 0.371397, 0.458007, 0.545675, 0.596441, 0.659989, 0.694823, 0.716197, 0.718397, 0.749976, 0.702072, 0.754866, 0.791751, 0.744595, 0.670233, 0.678106, 0.738486, 0.760503, 0.863024]

# %%
# Normalize and change to the 0-1 position
active_ips = []
for row in raw_active_ips:
    # print(row)
    max_count = max(row)
    new_row = []
    for item in row:
        new_row.append(item*100/max_count)
    active_ips.append(new_row)

# fix
active_ips[0][13] = 100.0

for item in active_ips:
    print(item)
# Out:
# [63.541208125243465, 71.05342819135785, 72.84305129593605, 72.15453062041634, 74.76232227688202, 76.74828653748511, 79.23414888882725, 81.45516776435203, 82.2388439509919, 83.0380778827959, 85.88104475685898, 87.68514018252009, 93.51326448528587, 100.0, 99.2340524066867, 79.93605646134866, 76.39467949235922, 70.91485571698892, 59.77358053665779, 51.93886891574576, 51.93332119266398, 54.756268022562345, 53.68145697680449, 60.188333138359]
# [87.72702881202014, 94.81319427245292, 91.52941743030902, 87.8264399130411, 91.53515048111761, 90.25713879486685, 98.78986763532292, 97.91706798022327, 84.72864323912783, 69.63833622279094, 60.48081950521478, 49.358471614518834, 42.65103149050148, 42.79424309970005, 43.53139877266848, 46.16951943274902, 59.479140867938014, 73.4234110276379, 81.710535971454, 86.33745195703422, 94.93588155975672, 99.86229211957769, 96.0936138400433, 100.0]
# [91.75234691694772, 100.0, 85.09158323905935, 63.841249333519215, 48.10804597945803, 39.10467552895427, 39.52558275163707, 48.74297202004604, 58.07295796142554, 63.475682630632896, 70.23871984606822, 73.94589612797282, 76.220604339761, 76.45473730813069, 79.81550322092467, 74.71736425875099, 80.33591695516462, 84.2613690180357, 79.2428352651077, 71.32892808605877, 72.16680484059269, 78.59269058157567, 80.93582947457371, 91.84653222467827]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta

# Time range (0–23 hours)
origin_hours = range(48)

# Parse time strings
begin_list = begin.split('-')  # e.g., "2025-07-28-16"
end_list = end.split('-')      # e.g., "2025-07-29-15"

plt.rcParams['pdf.fonttype'] = 42

# Create subplots for each country
fig, axes = plt.subplots(len(countries), 1, figsize=(4.3, 4.1), sharex=True)

# Reference y-axis values and annotation offset per country
y_values = [
    [100, 80, 60],
    [100, 75, 50],
    [100, 70, 40]
]
red_loc = [
    [-30, 30],
    [-25, 30],
    [-15, 40]
]

# Plot traffic for each selected country
for i, (ax, country, data) in enumerate(zip(axes, countries, active_ips)):
    start_time = datetime(*map(int, begin_list))
    end_time = datetime(*map(int, end_list))

    # Generate hourly timestamps (24 hours)
    time_labels = [start_time + timedelta(hours=j) for j in range(24)]

    ax.plot(time_labels, data, label=country, marker='o')
    ax.set_title(labels[i], fontsize=12, pad=-30)
    ax.set_ylim(min(data) * 0.995, max(data) * 1.005)
    ax.grid(True, linestyle='--', alpha=0.6)

    # Format x-axis as HH:MM with 4-hour intervals
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
    ax.xaxis.set_major_locator(mdates.HourLocator(interval=4))

    # Calculate percentage difference
    min_value = min(data)
    min_index = data.index(min_value)
    min_time = time_labels[min_index]

    # Draw horizontal dashed line at minimum value
    ax.axhline(y=min_value, color='r', linestyle='--', linewidth=1)

    # Annotate minimum point
    ax.annotate(f'Min: {min_value:.1f}%', 
                xy=(min_time, min_value), 
                xycoords='data', 
                xytext=(red_loc[i][0], red_loc[i][1]), 
                textcoords='offset points',
                arrowprops=dict(arrowstyle='->', lw=1),
                fontsize=12, color='red')

    # Set custom y-ticks for clarity
    yticks = [y for y in y_values[i] if min(data) <= y <= max(data)]
    ax.set_yticks(yticks)
    ax.set_yticklabels([str(y) for y in yticks], fontsize=10)

# Set common Y-axis and X-axis labels
fig.text(0.023, 0.5, 'Normalized load of Starlink active users (%)', ha='center', va='center', rotation='vertical', fontsize=13)
fig.text(0.5, 0.02, 'Time (UTC+0)', ha='center', va='center', fontsize=13)

# Final layout adjustments
plt.tight_layout()
plt.subplots_adjust(left=0.13, bottom=0.12)

# Save and show the plot
plt.savefig('figure3b.pdf', bbox_inches="tight")
plt.savefig('figure3b.png', bbox_inches="tight")
