# %%
import numpy as np
import math
from fractions import Fraction
from tqdm import tqdm
import multiprocessing as mp
from haversine import haversine, Unit
import matplotlib.pyplot as plt
import os
import random
import matplotlib
from scipy.sparse import lil_matrix, csr_matrix
import gc
import time
from multiprocessing import shared_memory

# %%
# Astronomy-related constants

TE = 24 * 3600  # One Earth sidereal day in seconds

RE = 6371e3  # Mean radius of Earth in meters

u = 3.986e14  # Standard gravitational parameter (μ = GM) in m^3/s^2

K = RE / pow(u, 1/3) * pow(2 * np.pi, 2/3)  

eps = 25 * np.pi / 180  # Maximum elevation angle for ground access, in radians (25°)

# %%
# === Orbital mechanics ===

def satellite_period(h):
    # Satellite orbital period (h in meters)
    a = RE + h
    return float(2 * np.pi * (a**3 / u)**0.5)

def coverage_eta(T):
    # Coverage half angle (rad)
    return math.acos(K * math.cos(eps) / T**(2/3)) - eps

def approximate_ratio(a, b, precision=1e-3):
    # Approximate integer ratio of a/b
    if b == 0:
        raise ValueError("Denominator cannot be zero")
    ratio = Fraction(a, b).limit_denominator(int(1 / precision))
    return ratio.numerator, ratio.denominator

def alpha_gamma_to_lambda_phi(alpha, gamma, inc):
    # Convert orbit plane coords to lat/lon
    phi = math.asin(math.sin(inc) * math.sin(gamma))
    temp = math.atan2(math.cos(inc) * math.sin(gamma), math.cos(gamma))
    lamb = (temp + alpha) % (2 * math.pi)
    if lamb > math.pi:
        lamb -= 2 * math.pi
    return lamb, phi


# === Ground coverage logic ===

def is_cover(l_sat, p_sat, l_cell, p_cell, eta):
    # Determine whether (l_sat, p_sat) covers (l_cell, p_cell)
    if (p_sat - 2*eta) < -np.pi/2 or (p_sat + 2*eta) > np.pi/2 or \
       (l_sat - 2*eta) < -np.pi or (l_sat + 2*eta) > np.pi:
        d = haversine((np.degrees(p_sat), np.degrees(l_sat)),
                      (np.degrees(p_cell), np.degrees(l_cell)),
                      unit=Unit.METERS)
        return d <= eta * RE
    else:
        if (p_sat - 2*eta) <= p_cell <= (p_sat + 2*eta) and \
           (l_sat - 2*eta) <= l_cell <= (l_sat + 2*eta):
            d = haversine((np.degrees(p_sat), np.degrees(l_sat)),
                          (np.degrees(p_cell), np.degrees(l_cell)),
                          unit=Unit.METERS)
            return d <= eta * RE
    return False

def get_grid_id(lat_deg: float, lon_deg: float) -> int:
    # Map (lat, lon) to grid ID (0–120), row-major from NW to SE
    lon_deg = ((lon_deg + 180) % 360) - 180
    lat = 90
    row, col = -1, -1

    for i in range(11):
        step = 16 if i < 10 else 20
        if lat_deg <= lat and lat_deg > (lat - step) if i < 10 else lat_deg >= -90:
            row = i
            break
        lat -= step

    lon = -180
    for j in range(11):
        step = 32 if j < 10 else 40
        if lon_deg >= lon and lon_deg < (lon + step) if j < 10 else lon_deg <= 180:
            col = j
            break
        lon += step

    if row == -1 and lat_deg == -90: row = 10
    if col == -1 and lon_deg == 180: col = 10

    if row != -1 and col != -1:
        return row * 11 + col
    else:
        print(f"Warning: Could not determine grid for lat={lat_deg}, lon={lon_deg}")
        return -1

def create_new_grid_satellites(satellite_location):
    # Convert sat (lon, lat) → grid ID
    lon, lat = satellite_location
    grid_id = get_grid_id(np.degrees(lat), np.degrees(lon))
    if 0 <= grid_id < 121:
        return grid_id
    else:
        raise ValueError("Invalid satellite location")


# === Satellite ground supply generation ===

def cal_supply_all_cell(h, beta, a0):
    '''
    Compute stable subsatellite point coverage over one orbital cycle
    Returns a list of [covered_cell_list, lon, lat] for each slot
    '''
    T = satellite_period(h * 1e3)
    p, q = approximate_ratio(int(T), TE)
    eta = coverage_eta(T)
    step = 2 * eta
    inc = beta
    total_supply = []

    num_slots = int(2 * np.pi * q / step)

    for i in range(num_slots):
        t = step * i / (2 * np.pi / T)
        a_sat = (a0 - (2 * np.pi / TE) * t) % (2 * np.pi)
        b_sat = (step * i) % (2 * np.pi)
        l_sat, p_sat = alpha_gamma_to_lambda_phi(a_sat, b_sat, inc)
        cid = create_new_grid_satellites([l_sat, p_sat])
        total_supply.append([[ [cid, 1.0] ], l_sat, p_sat])

    return np.asarray(total_supply, dtype="object")


# === Multiprocessing coverage computation ===

def recover_fulltime(data):
    # Aggregate full-time user coverage over time
    random_numbers, cover, n_length = data
    selected_cover = lil_matrix((1, n_length), dtype=np.float64)
    sat_location = []

    for t in range(time_split):
        for num in random_numbers:
            num = (num + t) % time_split
            sat_location.append([cover[num][1], cover[num][2]])
            for idx, users in cover[num][0]:
                selected_cover[0, t * len(demand_list) + idx] += users

    return [selected_cover.tocsr(), sat_location]

def generate_baseset(args):
    # Build base unit from file and random selection
    file, random_numbers, sat_num = args
    file_param = file.split("/")[1].split("_")
    h = float(file_param[0])
    beta = float(file_param[1])
    alpha0 = float(file_param[2].split(".npy")[0])
    param = [h, beta, alpha0]

    cover = cal_supply_all_cell(h, beta, alpha0)
    fulltime_cover = recover_fulltime([random_numbers, cover, n_length])
    
    return [param, random_numbers, fulltime_cover, sat_num]

# %%
sat_height=573
# 需求函数
base_cover_path="candidate_backbone_network_"+str(sat_height)+"/"

time_split=308
print(time_split)
demand_list=np.load("data/backbone_satellite_demand.npy",allow_pickle=True)
d=1
selected_params=np.load("data/TinyLEO_for_backbone_network.npy",allow_pickle=True)
print(len(selected_params))
files=[]
sat_nums=0
for s_tmp in selected_params:
    param_tmp,slots,satmaps,sat_num=s_tmp
    tmp=base_cover_path+str(int(param_tmp[0]))+"_"+str(param_tmp[1])+"_"+str(param_tmp[2])+".npy"
    files.append([tmp,slots,sat_num])
    sat_nums+=sat_num
print(files[0])
print(sat_nums)
all_cover=[]
n_length=len(demand_list)*time_split

with mp.Pool(processes=100) as pool:
    all_cover = list(tqdm(pool.imap(generate_baseset, files), total=len(files), mininterval=10,maxinterval=20))
    pool.close()  # Prevents any more tasks from being submitted to the pool
    pool.join()  # Wait for the worker processes to exit
# Out:
# 308
# 3343
# ['candidate_backbone_network_573/573_0.9773843811168246_2.443460952792061.npy', [0], 1]
# 3343
# 100%|██████████| 3343/3343 [00:01<00:00, 2533.86it/s]

# %%
# === Flatten demand vector into time-expanded form ===
tmp_R = [demand for demand in demand_list]
ttmpR = tmp_R * int(time_split)
R = np.array(ttmpR).reshape(-1)
standard_R = sum(R)
del ttmpR, tmp_R  # Clean up

selected = []  # Selected coverage combinations
num_processes = 110  # Number of parallel processes

# === Dot product: used to evaluate coverage gain ===
def compute_dot(args, show=False):
    R, cid = args
    global all_cover
    fulltime_cover = all_cover[cid][2][0]
    dot = fulltime_cover @ R  # Compute inner product (coverage gain)
    return [dot[0], cid]

# === Update residual demand ===
def update_residual(R, cid):
    global all_cover
    # Subtract selected satellite's contribution, weighted by its satellite count
    R[all_cover[cid][2][0].indices] -= (all_cover[cid][2][0].data * all_cover[cid][3])
    R = np.maximum(R, 0)  # Ensure no negative demand
    return R

# === Find max dot product in a result chunk ===
def find_max_in_chunk(chunk):
    chunk = np.array(chunk)
    max_value = np.max(chunk[:, 0])      # Max dot product value
    local_index = np.argmax(chunk[:, 0]) # Index within chunk
    max_index = chunk[local_index][1]    # Original global index
    return [max_value, int(max_index)]

# %%
# === Initialize time-expanded demand vector ===
tmp_R = [demand for demand in demand_list]
ttmpR = tmp_R * int(time_split)
R_2 = np.array(ttmpR).reshape(-1).copy()
R_sum_2 = np.sum(R_2)
print("Initial residual:", R_sum_2)
del ttmpR, tmp_R  # Cleanup

process = []  # Store coverage progress

# === Sequentially subtract coverage from each selected base ===
for idx in range(len(all_cover)):
    R_2 = update_residual(R_2, idx)  # Update residual demand
    covered = R_sum_2 - np.sum(R_2)  # Coverage gained this step
    process.append([all_cover[idx][3], covered])
    R_sum_2 = np.sum(R_2)
    print("Residual after step", idx, ":", R_sum_2)

# === Summary of remaining demand ===
# Out:
# Initial residual: 153692.0
# Residual after step 0 : 153599.0
# Residual after step 1 : 153506.0
# Residual after step 2 : 153413.0
# Residual after step 3 : 153320.0
# Residual after step 4 : 153227.0
# Residual after step 5 : 153134.0
# Residual after step 6 : 153041.0
# Residual after step 7 : 152948.0
# Residual after step 8 : 152855.0
# Residual after step 9 : 152762.0
# Residual after step 10 : 152669.0
# Residual after step 11 : 152576.0
# Residual after step 12 : 152483.0
# Residual after step 13 : 152390.0
# Residual after step 14 : 152297.0
# Residual after step 15 : 152204.0
# Residual after step 16 : 152111.0
# Residual after step 17 : 152018.0
# Residual after step 18 : 151925.0
# Residual after step 19 : 151832.0
# Residual after step 20 : 151739.0
# Residual after step 21 : 151646.0
# Residual after step 22 : 151553.0
# Residual after step 23 : 151460.0
# Residual after step 24 : 151367.0
# Residual after step 25 : 151274.0
# Residual after step 26 : 151181.0
# Residual after step 27 : 151088.0
# Residual after step 28 : 150995.0
# Residual after step 29 : 150902.0
# Residual after step 30 : 150809.0
# Residual after step 31 : 150716.0
# Residual after step 32 : 150624.0
# Residual after step 33 : 150531.0
# Residual after step 34 : 150439.0
# Residual after step 35 : 150347.0
# Residual after step 36 : 150255.0
# Residual after step 37 : 150163.0
# Residual after step 38 : 150071.0
# Residual after step 39 : 149979.0
# Residual after step 40 : 149886.0
# Residual after step 41 : 149793.0
# Residual after step 42 : 149701.0
# Residual after step 43 : 149609.0
# Residual after step 44 : 149516.0
# Residual after step 45 : 149423.0
# Residual after step 46 : 149330.0
# Residual after step 47 : 149237.0
# Residual after step 48 : 149144.0
# Residual after step 49 : 149051.0
# Residual after step 50 : 148958.0
# Residual after step 51 : 148865.0
# Residual after step 52 : 148772.0
# Residual after step 53 : 148679.0
# Residual after step 54 : 148586.0
# Residual after step 55 : 148493.0
# Residual after step 56 : 148400.0
# Residual after step 57 : 148307.0
# Residual after step 58 : 148214.0
# Residual after step 59 : 148121.0
# Residual after step 60 : 148028.0
# Residual after step 61 : 147935.0
# Residual after step 62 : 147842.0
# Residual after step 63 : 147749.0
# Residual after step 64 : 147656.0
# Residual after step 65 : 147563.0
# Residual after step 66 : 147471.0
# Residual after step 67 : 147378.0
# Residual after step 68 : 147285.0
# Residual after step 69 : 147192.0
# Residual after step 70 : 147099.0
# Residual after step 71 : 147008.0
# Residual after step 72 : 146915.0
# Residual after step 73 : 146826.0
# Residual after step 74 : 146738.0
# Residual after step 75 : 146645.0
# Residual after step 76 : 146553.0
# Residual after step 77 : 146462.0
# Residual after step 78 : 146373.0
# Residual after step 79 : 146284.0
# Residual after step 80 : 146193.0
# Residual after step 81 : 146102.0
# Residual after step 82 : 146011.0
# Residual after step 83 : 145920.0
# Residual after step 84 : 145829.0
# Residual after step 85 : 145738.0
# Residual after step 86 : 145647.0
# Residual after step 87 : 145554.0
# Residual after step 88 : 145463.0
# Residual after step 89 : 145371.0
# Residual after step 90 : 145280.0
# Residual after step 91 : 145188.0
# Residual after step 92 : 145096.0
# Residual after step 93 : 145003.0
# Residual after step 94 : 144912.0
# Residual after step 95 : 144821.0
# Residual after step 96 : 144728.0
# Residual after step 97 : 144636.0
# Residual after step 98 : 144544.0
# Residual after step 99 : 144452.0
# Residual after step 100 : 144361.0
# Residual after step 101 : 144270.0
# Residual after step 102 : 144178.0
# Residual after step 103 : 144087.0
# Residual after step 104 : 143995.0
# Residual after step 105 : 143906.0
# Residual after step 106 : 143815.0
# Residual after step 107 : 143724.0
# Residual after step 108 : 143634.0
# Residual after step 109 : 143544.0
# Residual after step 110 : 143455.0
# Residual after step 111 : 143364.0
# Residual after step 112 : 143275.0
# Residual after step 113 : 143184.0
# Residual after step 114 : 143092.0
# Residual after step 115 : 143002.0
# Residual after step 116 : 142911.0
# Residual after step 117 : 142822.0
# Residual after step 118 : 142731.0
# Residual after step 119 : 142641.0
# Residual after step 120 : 142552.0
# Residual after step 121 : 142462.0
# Residual after step 122 : 142371.0
# Residual after step 123 : 142280.0
# Residual after step 124 : 142190.0
# Residual after step 125 : 142102.0
# Residual after step 126 : 142011.0
# Residual after step 127 : 141921.0
# Residual after step 128 : 141831.0
# Residual after step 129 : 141740.0
# Residual after step 130 : 141653.0
# Residual after step 131 : 141564.0
# Residual after step 132 : 141474.0
# Residual after step 133 : 141388.0
# Residual after step 134 : 141298.0
# Residual after step 135 : 141210.0
# Residual after step 136 : 141121.0
# Residual after step 137 : 141033.0
# Residual after step 138 : 140944.0
# Residual after step 139 : 140856.0
# Residual after step 140 : 140770.0
# Residual after step 141 : 140683.0
# Residual after step 142 : 140595.0
# Residual after step 143 : 140506.0
# Residual after step 144 : 140419.0
# Residual after step 145 : 140332.0
# Residual after step 146 : 140247.0
# Residual after step 147 : 140161.0
# Residual after step 148 : 140075.0
# Residual after step 149 : 139987.0
# Residual after step 150 : 139901.0
# Residual after step 151 : 139817.0
# Residual after step 152 : 139731.0
# Residual after step 153 : 139645.0
# Residual after step 154 : 139561.0
# Residual after step 155 : 139477.0
# Residual after step 156 : 139392.0
# Residual after step 157 : 139307.0
# Residual after step 158 : 139223.0
# Residual after step 159 : 139140.0
# Residual after step 160 : 139057.0
# Residual after step 161 : 138975.0
# Residual after step 162 : 138891.0
# Residual after step 163 : 138806.0
# Residual after step 164 : 138725.0
# Residual after step 165 : 138644.0
# Residual after step 166 : 138562.0
# Residual after step 167 : 138479.0
# Residual after step 168 : 138395.0
# Residual after step 169 : 138314.0
# Residual after step 170 : 138232.0
# Residual after step 171 : 138151.0
# Residual after step 172 : 138069.0
# Residual after step 173 : 137989.0
# Residual after step 174 : 137908.0
# Residual after step 175 : 137827.0
# Residual after step 176 : 137745.0
# Residual after step 177 : 137665.0
# Residual after step 178 : 137587.0
# Residual after step 179 : 137507.0
# Residual after step 180 : 137427.0
# Residual after step 181 : 137343.0
# Residual after step 182 : 137262.0
# Residual after step 183 : 137184.0
# Residual after step 184 : 137106.0
# Residual after step 185 : 137026.0
# Residual after step 186 : 136947.0
# Residual after step 187 : 136868.0
# Residual after step 188 : 136788.0
# Residual after step 189 : 136710.0
# Residual after step 190 : 136632.0
# Residual after step 191 : 136554.0
# Residual after step 192 : 136477.0
# Residual after step 193 : 136399.0
# Residual after step 194 : 136321.0
# Residual after step 195 : 136243.0
# Residual after step 196 : 136164.0
# Residual after step 197 : 136086.0
# Residual after step 198 : 136008.0
# Residual after step 199 : 135931.0
# Residual after step 200 : 135853.0
# Residual after step 201 : 135775.0
# Residual after step 202 : 135696.0
# Residual after step 203 : 135618.0
# Residual after step 204 : 135541.0
# Residual after step 205 : 135464.0
# Residual after step 206 : 135388.0
# Residual after step 207 : 135310.0
# Residual after step 208 : 135231.0
# Residual after step 209 : 135153.0
# Residual after step 210 : 135074.0
# Residual after step 211 : 134996.0
# Residual after step 212 : 134918.0
# Residual after step 213 : 134843.0
# Residual after step 214 : 134766.0
# Residual after step 215 : 134687.0
# Residual after step 216 : 134609.0
# Residual after step 217 : 134531.0
# Residual after step 218 : 134454.0
# Residual after step 219 : 134378.0
# Residual after step 220 : 134300.0
# Residual after step 221 : 134223.0
# Residual after step 222 : 134146.0
# Residual after step 223 : 134070.0
# Residual after step 224 : 133992.0
# Residual after step 225 : 133916.0
# Residual after step 226 : 133839.0
# Residual after step 227 : 133762.0
# Residual after step 228 : 133685.0
# Residual after step 229 : 133607.0
# Residual after step 230 : 133530.0
# Residual after step 231 : 133453.0
# Residual after step 232 : 133375.0
# Residual after step 233 : 133298.0
# Residual after step 234 : 133221.0
# Residual after step 235 : 133144.0
# Residual after step 236 : 133065.0
# Residual after step 237 : 132987.0
# Residual after step 238 : 132911.0
# Residual after step 239 : 132834.0
# Residual after step 240 : 132758.0
# Residual after step 241 : 132682.0
# Residual after step 242 : 132606.0
# Residual after step 243 : 132527.0
# Residual after step 244 : 132454.0
# Residual after step 245 : 132377.0
# Residual after step 246 : 132300.0
# Residual after step 247 : 132223.0
# Residual after step 248 : 132147.0
# Residual after step 249 : 132072.0
# Residual after step 250 : 131997.0
# Residual after step 251 : 131922.0
# Residual after step 252 : 131847.0
# Residual after step 253 : 131771.0
# Residual after step 254 : 131697.0
# Residual after step 255 : 131623.0
# Residual after step 256 : 131549.0
# Residual after step 257 : 131474.0
# Residual after step 258 : 131400.0
# Residual after step 259 : 131324.0
# Residual after step 260 : 131250.0
# Residual after step 261 : 131176.0
# Residual after step 262 : 131102.0
# Residual after step 263 : 131027.0
# Residual after step 264 : 130954.0
# Residual after step 265 : 130881.0
# Residual after step 266 : 130808.0
# Residual after step 267 : 130735.0
# Residual after step 268 : 130661.0
# Residual after step 269 : 130586.0
# Residual after step 270 : 130510.0
# Residual after step 271 : 130437.0
# Residual after step 272 : 130362.0
# Residual after step 273 : 130288.0
# Residual after step 274 : 130215.0
# Residual after step 275 : 130140.0
# Residual after step 276 : 130068.0
# Residual after step 277 : 129994.0
# Residual after step 278 : 129921.0
# Residual after step 279 : 129849.0
# Residual after step 280 : 129774.0
# Residual after step 281 : 129699.0
# Residual after step 282 : 129626.0
# Residual after step 283 : 129553.0
# Residual after step 284 : 129479.0
# Residual after step 285 : 129406.0
# Residual after step 286 : 129333.0
# Residual after step 287 : 129260.0
# Residual after step 288 : 129188.0
# Residual after step 289 : 129116.0
# Residual after step 290 : 129044.0
# Residual after step 291 : 128972.0
# Residual after step 292 : 128900.0
# Residual after step 293 : 128828.0
# Residual after step 294 : 128756.0
# Residual after step 295 : 128684.0
# Residual after step 296 : 128612.0
# Residual after step 297 : 128540.0
# Residual after step 298 : 128468.0
# Residual after step 299 : 128396.0
# Residual after step 300 : 128324.0
# Residual after step 301 : 128252.0
# Residual after step 302 : 128180.0
# Residual after step 303 : 128108.0
# Residual after step 304 : 128036.0
# Residual after step 305 : 127964.0
# Residual after step 306 : 127892.0
# Residual after step 307 : 127820.0
# Residual after step 308 : 127756.0
# Residual after step 309 : 127692.0
# Residual after step 310 : 127628.0
# Residual after step 311 : 127564.0
# Residual after step 312 : 127500.0
# Residual after step 313 : 127436.0
# Residual after step 314 : 127372.0
# Residual after step 315 : 127308.0
# Residual after step 316 : 127244.0
# Residual after step 317 : 127180.0
# Residual after step 318 : 127116.0
# Residual after step 319 : 127052.0
# Residual after step 320 : 126988.0
# Residual after step 321 : 126924.0
# Residual after step 322 : 126860.0
# Residual after step 323 : 126796.0
# Residual after step 324 : 126732.0
# Residual after step 325 : 126668.0
# Residual after step 326 : 126604.0
# Residual after step 327 : 126540.0
# Residual after step 328 : 126476.0
# Residual after step 329 : 126412.0
# Residual after step 330 : 126348.0
# Residual after step 331 : 126285.0
# Residual after step 332 : 126221.0
# Residual after step 333 : 126157.0
# Residual after step 334 : 126093.0
# Residual after step 335 : 126029.0
# Residual after step 336 : 125965.0
# Residual after step 337 : 125901.0
# Residual after step 338 : 125837.0
# Residual after step 339 : 125773.0
# Residual after step 340 : 125709.0
# Residual after step 341 : 125645.0
# Residual after step 342 : 125582.0
# Residual after step 343 : 125518.0
# Residual after step 344 : 125454.0
# Residual after step 345 : 125390.0
# Residual after step 346 : 125326.0
# Residual after step 347 : 125262.0
# Residual after step 348 : 125198.0
# Residual after step 349 : 125135.0
# Residual after step 350 : 125072.0
# Residual after step 351 : 125008.0
# Residual after step 352 : 124944.0
# Residual after step 353 : 124880.0
# Residual after step 354 : 124817.0
# Residual after step 355 : 124753.0
# Residual after step 356 : 124689.0
# Residual after step 357 : 124625.0
# Residual after step 358 : 124561.0
# Residual after step 359 : 124498.0
# Residual after step 360 : 124434.0
# Residual after step 361 : 124370.0
# Residual after step 362 : 124306.0
# Residual after step 363 : 124242.0
# Residual after step 364 : 124179.0
# Residual after step 365 : 124115.0
# Residual after step 366 : 124051.0
# Residual after step 367 : 123987.0
# Residual after step 368 : 123923.0
# Residual after step 369 : 123860.0
# Residual after step 370 : 123796.0
# Residual after step 371 : 123733.0
# Residual after step 372 : 123670.0
# Residual after step 373 : 123607.0
# Residual after step 374 : 123544.0
# Residual after step 375 : 123480.0
# Residual after step 376 : 123417.0
# Residual after step 377 : 123354.0
# Residual after step 378 : 123291.0
# Residual after step 379 : 123227.0
# Residual after step 380 : 123163.0
# Residual after step 381 : 123100.0
# Residual after step 382 : 123037.0
# Residual after step 383 : 122974.0
# Residual after step 384 : 122911.0
# Residual after step 385 : 122848.0
# Residual after step 386 : 122784.0
# Residual after step 387 : 122721.0
# Residual after step 388 : 122658.0
# Residual after step 389 : 122595.0
# Residual after step 390 : 122532.0
# Residual after step 391 : 122469.0
# Residual after step 392 : 122406.0
# Residual after step 393 : 122344.0
# Residual after step 394 : 122281.0
# Residual after step 395 : 122219.0
# Residual after step 396 : 122157.0
# Residual after step 397 : 122094.0
# Residual after step 398 : 122031.0
# Residual after step 399 : 121970.0
# Residual after step 400 : 121908.0
# Residual after step 401 : 121846.0
# Residual after step 402 : 121783.0
# Residual after step 403 : 121720.0
# Residual after step 404 : 121658.0
# Residual after step 405 : 121596.0
# Residual after step 406 : 121534.0
# Residual after step 407 : 121472.0
# Residual after step 408 : 121410.0
# Residual after step 409 : 121348.0
# Residual after step 410 : 121286.0
# Residual after step 411 : 121224.0
# Residual after step 412 : 121162.0
# Residual after step 413 : 121100.0
# Residual after step 414 : 121038.0
# Residual after step 415 : 120975.0
# Residual after step 416 : 120912.0
# Residual after step 417 : 120850.0
# Residual after step 418 : 120788.0
# Residual after step 419 : 120726.0
# Residual after step 420 : 120664.0
# Residual after step 421 : 120601.0
# Residual after step 422 : 120539.0
# Residual after step 423 : 120478.0
# Residual after step 424 : 120416.0
# Residual after step 425 : 120354.0
# Residual after step 426 : 120292.0
# Residual after step 427 : 120230.0
# Residual after step 428 : 120168.0
# Residual after step 429 : 120106.0
# Residual after step 430 : 120044.0
# Residual after step 431 : 119982.0
# Residual after step 432 : 119920.0
# Residual after step 433 : 119857.0
# Residual after step 434 : 119795.0
# Residual after step 435 : 119733.0
# Residual after step 436 : 119671.0
# Residual after step 437 : 119609.0
# Residual after step 438 : 119547.0
# Residual after step 439 : 119485.0
# Residual after step 440 : 119423.0
# Residual after step 441 : 119361.0
# Residual after step 442 : 119299.0
# Residual after step 443 : 119237.0
# Residual after step 444 : 119175.0
# Residual after step 445 : 119113.0
# Residual after step 446 : 119051.0
# Residual after step 447 : 118990.0
# Residual after step 448 : 118929.0
# Residual after step 449 : 118867.0
# Residual after step 450 : 118806.0
# Residual after step 451 : 118744.0
# Residual after step 452 : 118682.0
# Residual after step 453 : 118620.0
# Residual after step 454 : 118558.0
# Residual after step 455 : 118496.0
# Residual after step 456 : 118434.0
# Residual after step 457 : 118372.0
# Residual after step 458 : 118309.0
# Residual after step 459 : 118248.0
# Residual after step 460 : 118186.0
# Residual after step 461 : 118124.0
# Residual after step 462 : 118063.0
# Residual after step 463 : 118001.0
# Residual after step 464 : 117940.0
# Residual after step 465 : 117879.0
# Residual after step 466 : 117817.0
# Residual after step 467 : 117756.0
# Residual after step 468 : 117694.0
# Residual after step 469 : 117633.0
# Residual after step 470 : 117571.0
# Residual after step 471 : 117510.0
# Residual after step 472 : 117448.0
# Residual after step 473 : 117387.0
# Residual after step 474 : 117326.0
# Residual after step 475 : 117265.0
# Residual after step 476 : 117204.0
# Residual after step 477 : 117143.0
# Residual after step 478 : 117082.0
# Residual after step 479 : 117021.0
# Residual after step 480 : 116960.0
# Residual after step 481 : 116899.0
# Residual after step 482 : 116838.0
# Residual after step 483 : 116777.0
# Residual after step 484 : 116716.0
# Residual after step 485 : 116655.0
# Residual after step 486 : 116593.0
# Residual after step 487 : 116532.0
# Residual after step 488 : 116471.0
# Residual after step 489 : 116410.0
# Residual after step 490 : 116349.0
# Residual after step 491 : 116288.0
# Residual after step 492 : 116227.0
# Residual after step 493 : 116166.0
# Residual after step 494 : 116105.0
# Residual after step 495 : 116044.0
# Residual after step 496 : 115983.0
# Residual after step 497 : 115922.0
# Residual after step 498 : 115861.0
# Residual after step 499 : 115800.0
# Residual after step 500 : 115739.0
# Residual after step 501 : 115678.0
# Residual after step 502 : 115617.0
# Residual after step 503 : 115556.0
# Residual after step 504 : 115495.0
# Residual after step 505 : 115434.0
# Residual after step 506 : 115373.0
# Residual after step 507 : 115312.0
# Residual after step 508 : 115251.0
# Residual after step 509 : 115190.0
# Residual after step 510 : 115129.0
# Residual after step 511 : 115068.0
# Residual after step 512 : 115007.0
# Residual after step 513 : 114946.0
# Residual after step 514 : 114885.0
# Residual after step 515 : 114824.0
# Residual after step 516 : 114763.0
# Residual after step 517 : 114702.0
# Residual after step 518 : 114641.0
# Residual after step 519 : 114580.0
# Residual after step 520 : 114519.0
# Residual after step 521 : 114458.0
# Residual after step 522 : 114397.0
# Residual after step 523 : 114336.0
# Residual after step 524 : 114275.0
# Residual after step 525 : 114214.0
# Residual after step 526 : 114153.0
# Residual after step 527 : 114092.0
# Residual after step 528 : 114031.0
# Residual after step 529 : 113970.0
# Residual after step 530 : 113909.0
# Residual after step 531 : 113848.0
# Residual after step 532 : 113787.0
# Residual after step 533 : 113726.0
# Residual after step 534 : 113665.0
# Residual after step 535 : 113604.0
# Residual after step 536 : 113543.0
# Residual after step 537 : 113482.0
# Residual after step 538 : 113421.0
# Residual after step 539 : 113360.0
# Residual after step 540 : 113299.0
# Residual after step 541 : 113238.0
# Residual after step 542 : 113177.0
# Residual after step 543 : 113116.0
# Residual after step 544 : 113055.0
# Residual after step 545 : 112994.0
# Residual after step 546 : 112933.0
# Residual after step 547 : 112872.0
# Residual after step 548 : 112811.0
# Residual after step 549 : 112750.0
# Residual after step 550 : 112689.0
# Residual after step 551 : 112628.0
# Residual after step 552 : 112567.0
# Residual after step 553 : 112506.0
# Residual after step 554 : 112445.0
# Residual after step 555 : 112384.0
# Residual after step 556 : 112323.0
# Residual after step 557 : 112262.0
# Residual after step 558 : 112201.0
# Residual after step 559 : 112140.0
# Residual after step 560 : 112079.0
# Residual after step 561 : 112018.0
# Residual after step 562 : 111957.0
# Residual after step 563 : 111896.0
# Residual after step 564 : 111835.0
# Residual after step 565 : 111774.0
# Residual after step 566 : 111713.0
# Residual after step 567 : 111652.0
# Residual after step 568 : 111591.0
# Residual after step 569 : 111530.0
# Residual after step 570 : 111469.0
# Residual after step 571 : 111408.0
# Residual after step 572 : 111347.0
# Residual after step 573 : 111286.0
# Residual after step 574 : 111225.0
# Residual after step 575 : 111164.0
# Residual after step 576 : 111103.0
# Residual after step 577 : 111042.0
# Residual after step 578 : 110981.0
# Residual after step 579 : 110920.0
# Residual after step 580 : 110859.0
# Residual after step 581 : 110798.0
# Residual after step 582 : 110737.0
# Residual after step 583 : 110676.0
# Residual after step 584 : 110615.0
# Residual after step 585 : 110554.0
# Residual after step 586 : 110493.0
# Residual after step 587 : 110432.0
# Residual after step 588 : 110371.0
# Residual after step 589 : 110310.0
# Residual after step 590 : 110249.0
# Residual after step 591 : 110188.0
# Residual after step 592 : 110127.0
# Residual after step 593 : 110066.0
# Residual after step 594 : 110005.0
# Residual after step 595 : 109944.0
# Residual after step 596 : 109883.0
# Residual after step 597 : 109822.0
# Residual after step 598 : 109761.0
# Residual after step 599 : 109700.0
# Residual after step 600 : 109639.0
# Residual after step 601 : 109578.0
# Residual after step 602 : 109517.0
# Residual after step 603 : 109456.0
# Residual after step 604 : 109395.0
# Residual after step 605 : 109334.0
# Residual after step 606 : 109273.0
# Residual after step 607 : 109212.0
# Residual after step 608 : 109151.0
# Residual after step 609 : 109090.0
# Residual after step 610 : 109029.0
# Residual after step 611 : 108968.0
# Residual after step 612 : 108907.0
# Residual after step 613 : 108846.0
# Residual after step 614 : 108785.0
# Residual after step 615 : 108724.0
# Residual after step 616 : 108666.0
# Residual after step 617 : 108608.0
# Residual after step 618 : 108550.0
# Residual after step 619 : 108492.0
# Residual after step 620 : 108434.0
# Residual after step 621 : 108376.0
# Residual after step 622 : 108318.0
# Residual after step 623 : 108260.0
# Residual after step 624 : 108202.0
# Residual after step 625 : 108144.0
# Residual after step 626 : 108086.0
# Residual after step 627 : 108028.0
# Residual after step 628 : 107970.0
# Residual after step 629 : 107912.0
# Residual after step 630 : 107854.0
# Residual after step 631 : 107796.0
# Residual after step 632 : 107738.0
# Residual after step 633 : 107680.0
# Residual after step 634 : 107622.0
# Residual after step 635 : 107564.0
# Residual after step 636 : 107506.0
# Residual after step 637 : 107448.0
# Residual after step 638 : 107390.0
# Residual after step 639 : 107332.0
# Residual after step 640 : 107274.0
# Residual after step 641 : 107216.0
# Residual after step 642 : 107158.0
# Residual after step 643 : 107100.0
# Residual after step 644 : 107042.0
# Residual after step 645 : 106984.0
# Residual after step 646 : 106926.0
# Residual after step 647 : 106868.0
# Residual after step 648 : 106810.0
# Residual after step 649 : 106752.0
# Residual after step 650 : 106694.0
# Residual after step 651 : 106636.0
# Residual after step 652 : 106578.0
# Residual after step 653 : 106520.0
# Residual after step 654 : 106462.0
# Residual after step 655 : 106404.0
# Residual after step 656 : 106346.0
# Residual after step 657 : 106288.0
# Residual after step 658 : 106230.0
# Residual after step 659 : 106172.0
# Residual after step 660 : 106114.0
# Residual after step 661 : 106056.0
# Residual after step 662 : 105998.0
# Residual after step 663 : 105940.0
# Residual after step 664 : 105882.0
# Residual after step 665 : 105824.0
# Residual after step 666 : 105766.0
# Residual after step 667 : 105708.0
# Residual after step 668 : 105650.0
# Residual after step 669 : 105592.0
# Residual after step 670 : 105534.0
# Residual after step 671 : 105476.0
# Residual after step 672 : 105418.0
# Residual after step 673 : 105360.0
# Residual after step 674 : 105302.0
# Residual after step 675 : 105244.0
# Residual after step 676 : 105186.0
# Residual after step 677 : 105128.0
# Residual after step 678 : 105070.0
# Residual after step 679 : 105012.0
# Residual after step 680 : 104954.0
# Residual after step 681 : 104896.0
# Residual after step 682 : 104838.0
# Residual after step 683 : 104780.0
# Residual after step 684 : 104722.0
# Residual after step 685 : 104664.0
# Residual after step 686 : 104606.0
# Residual after step 687 : 104548.0
# Residual after step 688 : 104490.0
# Residual after step 689 : 104432.0
# Residual after step 690 : 104374.0
# Residual after step 691 : 104316.0
# Residual after step 692 : 104258.0
# Residual after step 693 : 104200.0
# Residual after step 694 : 104142.0
# Residual after step 695 : 104084.0
# Residual after step 696 : 104026.0
# Residual after step 697 : 103968.0
# Residual after step 698 : 103910.0
# Residual after step 699 : 103852.0
# Residual after step 700 : 103794.0
# Residual after step 701 : 103736.0
# Residual after step 702 : 103678.0
# Residual after step 703 : 103620.0
# Residual after step 704 : 103562.0
# Residual after step 705 : 103504.0
# Residual after step 706 : 103446.0
# Residual after step 707 : 103388.0
# Residual after step 708 : 103330.0
# Residual after step 709 : 103272.0
# Residual after step 710 : 103214.0
# Residual after step 711 : 103156.0
# Residual after step 712 : 103098.0
# Residual after step 713 : 103040.0
# Residual after step 714 : 102982.0
# Residual after step 715 : 102924.0
# Residual after step 716 : 102866.0
# Residual after step 717 : 102808.0
# Residual after step 718 : 102750.0
# Residual after step 719 : 102692.0
# Residual after step 720 : 102634.0
# Residual after step 721 : 102576.0
# Residual after step 722 : 102518.0
# Residual after step 723 : 102460.0
# Residual after step 724 : 102402.0
# Residual after step 725 : 102344.0
# Residual after step 726 : 102286.0
# Residual after step 727 : 102228.0
# Residual after step 728 : 102170.0
# Residual after step 729 : 102112.0
# Residual after step 730 : 102054.0
# Residual after step 731 : 101996.0
# Residual after step 732 : 101938.0
# Residual after step 733 : 101880.0
# Residual after step 734 : 101822.0
# Residual after step 735 : 101764.0
# Residual after step 736 : 101706.0
# Residual after step 737 : 101648.0
# Residual after step 738 : 101590.0
# Residual after step 739 : 101532.0
# Residual after step 740 : 101474.0
# Residual after step 741 : 101416.0
# Residual after step 742 : 101358.0
# Residual after step 743 : 101300.0
# Residual after step 744 : 101242.0
# Residual after step 745 : 101184.0
# Residual after step 746 : 101126.0
# Residual after step 747 : 101068.0
# Residual after step 748 : 101010.0
# Residual after step 749 : 100952.0
# Residual after step 750 : 100894.0
# Residual after step 751 : 100836.0
# Residual after step 752 : 100778.0
# Residual after step 753 : 100720.0
# Residual after step 754 : 100662.0
# Residual after step 755 : 100604.0
# Residual after step 756 : 100546.0
# Residual after step 757 : 100488.0
# Residual after step 758 : 100430.0
# Residual after step 759 : 100372.0
# Residual after step 760 : 100314.0
# Residual after step 761 : 100256.0
# Residual after step 762 : 100198.0
# Residual after step 763 : 100140.0
# Residual after step 764 : 100082.0
# Residual after step 765 : 100024.0
# Residual after step 766 : 99966.0
# Residual after step 767 : 99908.0
# Residual after step 768 : 99850.0
# Residual after step 769 : 99792.0
# Residual after step 770 : 99734.0
# Residual after step 771 : 99676.0
# Residual after step 772 : 99618.0
# Residual after step 773 : 99560.0
# Residual after step 774 : 99502.0
# Residual after step 775 : 99444.0
# Residual after step 776 : 99386.0
# Residual after step 777 : 99328.0
# Residual after step 778 : 99270.0
# Residual after step 779 : 99212.0
# Residual after step 780 : 99154.0
# Residual after step 781 : 99096.0
# Residual after step 782 : 99038.0
# Residual after step 783 : 98980.0
# Residual after step 784 : 98922.0
# Residual after step 785 : 98864.0
# Residual after step 786 : 98806.0
# Residual after step 787 : 98748.0
# Residual after step 788 : 98690.0
# Residual after step 789 : 98632.0
# Residual after step 790 : 98574.0
# Residual after step 791 : 98516.0
# Residual after step 792 : 98458.0
# Residual after step 793 : 98400.0
# Residual after step 794 : 98342.0
# Residual after step 795 : 98284.0
# Residual after step 796 : 98226.0
# Residual after step 797 : 98168.0
# Residual after step 798 : 98110.0
# Residual after step 799 : 98052.0
# Residual after step 800 : 97994.0
# Residual after step 801 : 97936.0
# Residual after step 802 : 97878.0
# Residual after step 803 : 97820.0
# Residual after step 804 : 97762.0
# Residual after step 805 : 97704.0
# Residual after step 806 : 97646.0
# Residual after step 807 : 97588.0
# Residual after step 808 : 97530.0
# Residual after step 809 : 97472.0
# Residual after step 810 : 97414.0
# Residual after step 811 : 97356.0
# Residual after step 812 : 97298.0
# Residual after step 813 : 97240.0
# Residual after step 814 : 97182.0
# Residual after step 815 : 97124.0
# Residual after step 816 : 97066.0
# Residual after step 817 : 97008.0
# Residual after step 818 : 96950.0
# Residual after step 819 : 96892.0
# Residual after step 820 : 96834.0
# Residual after step 821 : 96776.0
# Residual after step 822 : 96718.0
# Residual after step 823 : 96660.0
# Residual after step 824 : 96602.0
# Residual after step 825 : 96544.0
# Residual after step 826 : 96486.0
# Residual after step 827 : 96428.0
# Residual after step 828 : 96370.0
# Residual after step 829 : 96312.0
# Residual after step 830 : 96254.0
# Residual after step 831 : 96196.0
# Residual after step 832 : 96138.0
# Residual after step 833 : 96080.0
# Residual after step 834 : 96022.0
# Residual after step 835 : 95964.0
# Residual after step 836 : 95906.0
# Residual after step 837 : 95848.0
# Residual after step 838 : 95790.0
# Residual after step 839 : 95732.0
# Residual after step 840 : 95674.0
# Residual after step 841 : 95616.0
# Residual after step 842 : 95558.0
# Residual after step 843 : 95500.0
# Residual after step 844 : 95442.0
# Residual after step 845 : 95384.0
# Residual after step 846 : 95326.0
# Residual after step 847 : 95268.0
# Residual after step 848 : 95210.0
# Residual after step 849 : 95152.0
# Residual after step 850 : 95094.0
# Residual after step 851 : 95036.0
# Residual after step 852 : 94978.0
# Residual after step 853 : 94920.0
# Residual after step 854 : 94862.0
# Residual after step 855 : 94804.0
# Residual after step 856 : 94746.0
# Residual after step 857 : 94688.0
# Residual after step 858 : 94630.0
# Residual after step 859 : 94572.0
# Residual after step 860 : 94514.0
# Residual after step 861 : 94456.0
# Residual after step 862 : 94398.0
# Residual after step 863 : 94340.0
# Residual after step 864 : 94282.0
# Residual after step 865 : 94224.0
# Residual after step 866 : 94166.0
# Residual after step 867 : 94108.0
# Residual after step 868 : 94050.0
# Residual after step 869 : 93992.0
# Residual after step 870 : 93934.0
# Residual after step 871 : 93876.0
# Residual after step 872 : 93818.0
# Residual after step 873 : 93760.0
# Residual after step 874 : 93702.0
# Residual after step 875 : 93644.0
# Residual after step 876 : 93586.0
# Residual after step 877 : 93528.0
# Residual after step 878 : 93470.0
# Residual after step 879 : 93412.0
# Residual after step 880 : 93354.0
# Residual after step 881 : 93296.0
# Residual after step 882 : 93238.0
# Residual after step 883 : 93180.0
# Residual after step 884 : 93122.0
# Residual after step 885 : 93064.0
# Residual after step 886 : 93006.0
# Residual after step 887 : 92948.0
# Residual after step 888 : 92890.0
# Residual after step 889 : 92832.0
# Residual after step 890 : 92774.0
# Residual after step 891 : 92716.0
# Residual after step 892 : 92658.0
# Residual after step 893 : 92600.0
# Residual after step 894 : 92542.0
# Residual after step 895 : 92484.0
# Residual after step 896 : 92426.0
# Residual after step 897 : 92368.0
# Residual after step 898 : 92310.0
# Residual after step 899 : 92252.0
# Residual after step 900 : 92194.0
# Residual after step 901 : 92136.0
# Residual after step 902 : 92078.0
# Residual after step 903 : 92020.0
# Residual after step 904 : 91962.0
# Residual after step 905 : 91904.0
# Residual after step 906 : 91846.0
# Residual after step 907 : 91788.0
# Residual after step 908 : 91730.0
# Residual after step 909 : 91672.0
# Residual after step 910 : 91614.0
# Residual after step 911 : 91556.0
# Residual after step 912 : 91498.0
# Residual after step 913 : 91440.0
# Residual after step 914 : 91382.0
# Residual after step 915 : 91324.0
# Residual after step 916 : 91266.0
# Residual after step 917 : 91208.0
# Residual after step 918 : 91150.0
# Residual after step 919 : 91092.0
# Residual after step 920 : 91034.0
# Residual after step 921 : 90976.0
# Residual after step 922 : 90918.0
# Residual after step 923 : 90860.0
# Residual after step 924 : 90802.0
# Residual after step 925 : 90744.0
# Residual after step 926 : 90686.0
# Residual after step 927 : 90628.0
# Residual after step 928 : 90570.0
# Residual after step 929 : 90512.0
# Residual after step 930 : 90454.0
# Residual after step 931 : 90396.0
# Residual after step 932 : 90338.0
# Residual after step 933 : 90280.0
# Residual after step 934 : 90222.0
# Residual after step 935 : 90164.0
# Residual after step 936 : 90106.0
# Residual after step 937 : 90048.0
# Residual after step 938 : 89990.0
# Residual after step 939 : 89932.0
# Residual after step 940 : 89874.0
# Residual after step 941 : 89816.0
# Residual after step 942 : 89758.0
# Residual after step 943 : 89700.0
# Residual after step 944 : 89642.0
# Residual after step 945 : 89584.0
# Residual after step 946 : 89526.0
# Residual after step 947 : 89468.0
# Residual after step 948 : 89410.0
# Residual after step 949 : 89352.0
# Residual after step 950 : 89294.0
# Residual after step 951 : 89236.0
# Residual after step 952 : 89178.0
# Residual after step 953 : 89120.0
# Residual after step 954 : 89062.0
# Residual after step 955 : 89004.0
# Residual after step 956 : 88946.0
# Residual after step 957 : 88888.0
# Residual after step 958 : 88830.0
# Residual after step 959 : 88772.0
# Residual after step 960 : 88714.0
# Residual after step 961 : 88656.0
# Residual after step 962 : 88598.0
# Residual after step 963 : 88540.0
# Residual after step 964 : 88482.0
# Residual after step 965 : 88424.0
# Residual after step 966 : 88366.0
# Residual after step 967 : 88308.0
# Residual after step 968 : 88250.0
# Residual after step 969 : 88192.0
# Residual after step 970 : 88134.0
# Residual after step 971 : 88076.0
# Residual after step 972 : 88018.0
# Residual after step 973 : 87960.0
# Residual after step 974 : 87902.0
# Residual after step 975 : 87844.0
# Residual after step 976 : 87786.0
# Residual after step 977 : 87728.0
# Residual after step 978 : 87670.0
# Residual after step 979 : 87612.0
# Residual after step 980 : 87554.0
# Residual after step 981 : 87496.0
# Residual after step 982 : 87438.0
# Residual after step 983 : 87380.0
# Residual after step 984 : 87322.0
# Residual after step 985 : 87264.0
# Residual after step 986 : 87206.0
# Residual after step 987 : 87148.0
# Residual after step 988 : 87090.0
# Residual after step 989 : 87032.0
# Residual after step 990 : 86974.0
# Residual after step 991 : 86916.0
# Residual after step 992 : 86858.0
# Residual after step 993 : 86800.0
# Residual after step 994 : 86742.0
# Residual after step 995 : 86684.0
# Residual after step 996 : 86626.0
# Residual after step 997 : 86568.0
# Residual after step 998 : 86510.0
# Residual after step 999 : 86452.0
# Residual after step 1000 : 86394.0
# Residual after step 1001 : 86336.0
# Residual after step 1002 : 86278.0
# Residual after step 1003 : 86220.0
# Residual after step 1004 : 86162.0
# Residual after step 1005 : 86104.0
# Residual after step 1006 : 86046.0
# Residual after step 1007 : 85988.0
# Residual after step 1008 : 85930.0
# Residual after step 1009 : 85872.0
# Residual after step 1010 : 85814.0
# Residual after step 1011 : 85756.0
# Residual after step 1012 : 85698.0
# Residual after step 1013 : 85640.0
# Residual after step 1014 : 85582.0
# Residual after step 1015 : 85524.0
# Residual after step 1016 : 85466.0
# Residual after step 1017 : 85408.0
# Residual after step 1018 : 85350.0
# Residual after step 1019 : 85292.0
# Residual after step 1020 : 85234.0
# Residual after step 1021 : 85176.0
# Residual after step 1022 : 85118.0
# Residual after step 1023 : 85060.0
# Residual after step 1024 : 85002.0
# Residual after step 1025 : 84944.0
# Residual after step 1026 : 84886.0
# Residual after step 1027 : 84828.0
# Residual after step 1028 : 84770.0
# Residual after step 1029 : 84712.0
# Residual after step 1030 : 84654.0
# Residual after step 1031 : 84596.0
# Residual after step 1032 : 84538.0
# Residual after step 1033 : 84480.0
# Residual after step 1034 : 84422.0
# Residual after step 1035 : 84364.0
# Residual after step 1036 : 84306.0
# Residual after step 1037 : 84248.0
# Residual after step 1038 : 84190.0
# Residual after step 1039 : 84132.0
# Residual after step 1040 : 84074.0
# Residual after step 1041 : 84016.0
# Residual after step 1042 : 83958.0
# Residual after step 1043 : 83900.0
# Residual after step 1044 : 83842.0
# Residual after step 1045 : 83784.0
# Residual after step 1046 : 83726.0
# Residual after step 1047 : 83668.0
# Residual after step 1048 : 83610.0
# Residual after step 1049 : 83553.0
# Residual after step 1050 : 83495.0
# Residual after step 1051 : 83437.0
# Residual after step 1052 : 83379.0
# Residual after step 1053 : 83321.0
# Residual after step 1054 : 83263.0
# Residual after step 1055 : 83205.0
# Residual after step 1056 : 83147.0
# Residual after step 1057 : 83090.0
# Residual after step 1058 : 83032.0
# Residual after step 1059 : 82975.0
# Residual after step 1060 : 82918.0
# Residual after step 1061 : 82860.0
# Residual after step 1062 : 82802.0
# Residual after step 1063 : 82744.0
# Residual after step 1064 : 82686.0
# Residual after step 1065 : 82629.0
# Residual after step 1066 : 82571.0
# Residual after step 1067 : 82513.0
# Residual after step 1068 : 82455.0
# Residual after step 1069 : 82397.0
# Residual after step 1070 : 82340.0
# Residual after step 1071 : 82282.0
# Residual after step 1072 : 82224.0
# Residual after step 1073 : 82167.0
# Residual after step 1074 : 82110.0
# Residual after step 1075 : 82053.0
# Residual after step 1076 : 81995.0
# Residual after step 1077 : 81938.0
# Residual after step 1078 : 81880.0
# Residual after step 1079 : 81823.0
# Residual after step 1080 : 81765.0
# Residual after step 1081 : 81707.0
# Residual after step 1082 : 81647.0
# Residual after step 1083 : 81590.0
# Residual after step 1084 : 81533.0
# Residual after step 1085 : 81476.0
# Residual after step 1086 : 81419.0
# Residual after step 1087 : 81362.0
# Residual after step 1088 : 81305.0
# Residual after step 1089 : 81248.0
# Residual after step 1090 : 81191.0
# Residual after step 1091 : 81135.0
# Residual after step 1092 : 81077.0
# Residual after step 1093 : 81021.0
# Residual after step 1094 : 80966.0
# Residual after step 1095 : 80909.0
# Residual after step 1096 : 80852.0
# Residual after step 1097 : 80795.0
# Residual after step 1098 : 80738.0
# Residual after step 1099 : 80681.0
# Residual after step 1100 : 80624.0
# Residual after step 1101 : 80567.0
# Residual after step 1102 : 80510.0
# Residual after step 1103 : 80453.0
# Residual after step 1104 : 80397.0
# Residual after step 1105 : 80341.0
# Residual after step 1106 : 80286.0
# Residual after step 1107 : 80230.0
# Residual after step 1108 : 80175.0
# Residual after step 1109 : 80120.0
# Residual after step 1110 : 80064.0
# Residual after step 1111 : 80009.0
# Residual after step 1112 : 79953.0
# Residual after step 1113 : 79897.0
# Residual after step 1114 : 79841.0
# Residual after step 1115 : 79785.0
# Residual after step 1116 : 79730.0
# Residual after step 1117 : 79674.0
# Residual after step 1118 : 79619.0
# Residual after step 1119 : 79563.0
# Residual after step 1120 : 79508.0
# Residual after step 1121 : 79454.0
# Residual after step 1122 : 79399.0
# Residual after step 1123 : 79344.0
# Residual after step 1124 : 79289.0
# Residual after step 1125 : 79234.0
# Residual after step 1126 : 79179.0
# Residual after step 1127 : 79125.0
# Residual after step 1128 : 79069.0
# Residual after step 1129 : 79015.0
# Residual after step 1130 : 78961.0
# Residual after step 1131 : 78907.0
# Residual after step 1132 : 78853.0
# Residual after step 1133 : 78801.0
# Residual after step 1134 : 78748.0
# Residual after step 1135 : 78695.0
# Residual after step 1136 : 78643.0
# Residual after step 1137 : 78589.0
# Residual after step 1138 : 78535.0
# Residual after step 1139 : 78482.0
# Residual after step 1140 : 78428.0
# Residual after step 1141 : 78375.0
# Residual after step 1142 : 78324.0
# Residual after step 1143 : 78272.0
# Residual after step 1144 : 78221.0
# Residual after step 1145 : 78169.0
# Residual after step 1146 : 78117.0
# Residual after step 1147 : 78067.0
# Residual after step 1148 : 78015.0
# Residual after step 1149 : 77964.0
# Residual after step 1150 : 77913.0
# Residual after step 1151 : 77862.0
# Residual after step 1152 : 77811.0
# Residual after step 1153 : 77761.0
# Residual after step 1154 : 77711.0
# Residual after step 1155 : 77661.0
# Residual after step 1156 : 77612.0
# Residual after step 1157 : 77563.0
# Residual after step 1158 : 77513.0
# Residual after step 1159 : 77462.0
# Residual after step 1160 : 77411.0
# Residual after step 1161 : 77360.0
# Residual after step 1162 : 77311.0
# Residual after step 1163 : 77261.0
# Residual after step 1164 : 77211.0
# Residual after step 1165 : 77161.0
# Residual after step 1166 : 77110.0
# Residual after step 1167 : 77061.0
# Residual after step 1168 : 77012.0
# Residual after step 1169 : 76962.0
# Residual after step 1170 : 76913.0
# Residual after step 1171 : 76863.0
# Residual after step 1172 : 76814.0
# Residual after step 1173 : 76764.0
# Residual after step 1174 : 76715.0
# Residual after step 1175 : 76666.0
# Residual after step 1176 : 76617.0
# Residual after step 1177 : 76568.0
# Residual after step 1178 : 76519.0
# Residual after step 1179 : 76470.0
# Residual after step 1180 : 76421.0
# Residual after step 1181 : 76372.0
# Residual after step 1182 : 76323.0
# Residual after step 1183 : 76273.0
# Residual after step 1184 : 76224.0
# Residual after step 1185 : 76175.0
# Residual after step 1186 : 76126.0
# Residual after step 1187 : 76077.0
# Residual after step 1188 : 76028.0
# Residual after step 1189 : 75979.0
# Residual after step 1190 : 75930.0
# Residual after step 1191 : 75881.0
# Residual after step 1192 : 75832.0
# Residual after step 1193 : 75783.0
# Residual after step 1194 : 75734.0
# Residual after step 1195 : 75684.0
# Residual after step 1196 : 75635.0
# Residual after step 1197 : 75586.0
# Residual after step 1198 : 75537.0
# Residual after step 1199 : 75488.0
# Residual after step 1200 : 75439.0
# Residual after step 1201 : 75389.0
# Residual after step 1202 : 75340.0
# Residual after step 1203 : 75291.0
# Residual after step 1204 : 75242.0
# Residual after step 1205 : 75193.0
# Residual after step 1206 : 75144.0
# Residual after step 1207 : 75095.0
# Residual after step 1208 : 75046.0
# Residual after step 1209 : 74997.0
# Residual after step 1210 : 74948.0
# Residual after step 1211 : 74899.0
# Residual after step 1212 : 74850.0
# Residual after step 1213 : 74801.0
# Residual after step 1214 : 74752.0
# Residual after step 1215 : 74703.0
# Residual after step 1216 : 74654.0
# Residual after step 1217 : 74605.0
# Residual after step 1218 : 74556.0
# Residual after step 1219 : 74507.0
# Residual after step 1220 : 74458.0
# Residual after step 1221 : 74409.0
# Residual after step 1222 : 74360.0
# Residual after step 1223 : 74311.0
# Residual after step 1224 : 74262.0
# Residual after step 1225 : 74213.0
# Residual after step 1226 : 74164.0
# Residual after step 1227 : 74115.0
# Residual after step 1228 : 74066.0
# Residual after step 1229 : 74017.0
# Residual after step 1230 : 73968.0
# Residual after step 1231 : 73919.0
# Residual after step 1232 : 73870.0
# Residual after step 1233 : 73821.0
# Residual after step 1234 : 73772.0
# Residual after step 1235 : 73723.0
# Residual after step 1236 : 73674.0
# Residual after step 1237 : 73625.0
# Residual after step 1238 : 73576.0
# Residual after step 1239 : 73527.0
# Residual after step 1240 : 73478.0
# Residual after step 1241 : 73429.0
# Residual after step 1242 : 73380.0
# Residual after step 1243 : 73331.0
# Residual after step 1244 : 73282.0
# Residual after step 1245 : 73233.0
# Residual after step 1246 : 73184.0
# Residual after step 1247 : 73135.0
# Residual after step 1248 : 73086.0
# Residual after step 1249 : 73037.0
# Residual after step 1250 : 72988.0
# Residual after step 1251 : 72939.0
# Residual after step 1252 : 72890.0
# Residual after step 1253 : 72841.0
# Residual after step 1254 : 72792.0
# Residual after step 1255 : 72743.0
# Residual after step 1256 : 72694.0
# Residual after step 1257 : 72645.0
# Residual after step 1258 : 72596.0
# Residual after step 1259 : 72547.0
# Residual after step 1260 : 72498.0
# Residual after step 1261 : 72449.0
# Residual after step 1262 : 72400.0
# Residual after step 1263 : 72351.0
# Residual after step 1264 : 72302.0
# Residual after step 1265 : 72253.0
# Residual after step 1266 : 72204.0
# Residual after step 1267 : 72155.0
# Residual after step 1268 : 72106.0
# Residual after step 1269 : 72057.0
# Residual after step 1270 : 72008.0
# Residual after step 1271 : 71959.0
# Residual after step 1272 : 71910.0
# Residual after step 1273 : 71861.0
# Residual after step 1274 : 71812.0
# Residual after step 1275 : 71763.0
# Residual after step 1276 : 71714.0
# Residual after step 1277 : 71665.0
# Residual after step 1278 : 71616.0
# Residual after step 1279 : 71567.0
# Residual after step 1280 : 71518.0
# Residual after step 1281 : 71469.0
# Residual after step 1282 : 71420.0
# Residual after step 1283 : 71371.0
# Residual after step 1284 : 71322.0
# Residual after step 1285 : 71273.0
# Residual after step 1286 : 71224.0
# Residual after step 1287 : 71175.0
# Residual after step 1288 : 71126.0
# Residual after step 1289 : 71077.0
# Residual after step 1290 : 71028.0
# Residual after step 1291 : 70979.0
# Residual after step 1292 : 70930.0
# Residual after step 1293 : 70881.0
# Residual after step 1294 : 70832.0
# Residual after step 1295 : 70783.0
# Residual after step 1296 : 70734.0
# Residual after step 1297 : 70685.0
# Residual after step 1298 : 70636.0
# Residual after step 1299 : 70587.0
# Residual after step 1300 : 70538.0
# Residual after step 1301 : 70489.0
# Residual after step 1302 : 70440.0
# Residual after step 1303 : 70391.0
# Residual after step 1304 : 70342.0
# Residual after step 1305 : 70293.0
# Residual after step 1306 : 70244.0
# Residual after step 1307 : 70195.0
# Residual after step 1308 : 70146.0
# Residual after step 1309 : 70097.0
# Residual after step 1310 : 70048.0
# Residual after step 1311 : 69999.0
# Residual after step 1312 : 69950.0
# Residual after step 1313 : 69901.0
# Residual after step 1314 : 69852.0
# Residual after step 1315 : 69803.0
# Residual after step 1316 : 69754.0
# Residual after step 1317 : 69705.0
# Residual after step 1318 : 69656.0
# Residual after step 1319 : 69607.0
# Residual after step 1320 : 69558.0
# Residual after step 1321 : 69509.0
# Residual after step 1322 : 69460.0
# Residual after step 1323 : 69411.0
# Residual after step 1324 : 69362.0
# Residual after step 1325 : 69313.0
# Residual after step 1326 : 69264.0
# Residual after step 1327 : 69215.0
# Residual after step 1328 : 69166.0
# Residual after step 1329 : 69117.0
# Residual after step 1330 : 69068.0
# Residual after step 1331 : 69019.0
# Residual after step 1332 : 68970.0
# Residual after step 1333 : 68921.0
# Residual after step 1334 : 68872.0
# Residual after step 1335 : 68823.0
# Residual after step 1336 : 68774.0
# Residual after step 1337 : 68725.0
# Residual after step 1338 : 68676.0
# Residual after step 1339 : 68627.0
# Residual after step 1340 : 68578.0
# Residual after step 1341 : 68529.0
# Residual after step 1342 : 68480.0
# Residual after step 1343 : 68431.0
# Residual after step 1344 : 68382.0
# Residual after step 1345 : 68333.0
# Residual after step 1346 : 68284.0
# Residual after step 1347 : 68235.0
# Residual after step 1348 : 68186.0
# Residual after step 1349 : 68137.0
# Residual after step 1350 : 68088.0
# Residual after step 1351 : 68039.0
# Residual after step 1352 : 67990.0
# Residual after step 1353 : 67940.0
# Residual after step 1354 : 67891.0
# Residual after step 1355 : 67842.0
# Residual after step 1356 : 67793.0
# Residual after step 1357 : 67744.0
# Residual after step 1358 : 67695.0
# Residual after step 1359 : 67646.0
# Residual after step 1360 : 67597.0
# Residual after step 1361 : 67548.0
# Residual after step 1362 : 67499.0
# Residual after step 1363 : 67450.0
# Residual after step 1364 : 67401.0
# Residual after step 1365 : 67352.0
# Residual after step 1366 : 67303.0
# Residual after step 1367 : 67254.0
# Residual after step 1368 : 67205.0
# Residual after step 1369 : 67156.0
# Residual after step 1370 : 67107.0
# Residual after step 1371 : 67058.0
# Residual after step 1372 : 67009.0
# Residual after step 1373 : 66960.0
# Residual after step 1374 : 66911.0
# Residual after step 1375 : 66862.0
# Residual after step 1376 : 66813.0
# Residual after step 1377 : 66764.0
# Residual after step 1378 : 66715.0
# Residual after step 1379 : 66666.0
# ...
# Residual after step 2870 : 7238.0
# Residual after step 2871 : 7213.0
# Residual after step 2872 : 7188.0
# Residual after step 2873 : 7161.0
# Residual after step 2874 : 7135.0
# Residual after step 2875 : 7108.0
# Residual after step 2876 : 7083.0
# Residual after step 2877 : 7056.0
# Residual after step 2878 : 7031.0
# Residual after step 2879 : 7006.0
# Residual after step 2880 : 6981.0
# Residual after step 2881 : 6955.0
# Residual after step 2882 : 6931.0
# Residual after step 2883 : 6905.0
# Residual after step 2884 : 6881.0
# Residual after step 2885 : 6857.0
# Residual after step 2886 : 6832.0
# Residual after step 2887 : 6807.0
# Residual after step 2888 : 6781.0
# Residual after step 2889 : 6755.0
# Residual after step 2890 : 6731.0
# Residual after step 2891 : 6706.0
# Residual after step 2892 : 6681.0
# Residual after step 2893 : 6656.0
# Residual after step 2894 : 6631.0
# Residual after step 2895 : 6607.0
# Residual after step 2896 : 6580.0
# Residual after step 2897 : 6554.0
# Residual after step 2898 : 6529.0
# Residual after step 2899 : 6505.0
# Residual after step 2900 : 6481.0
# Residual after step 2901 : 6457.0
# Residual after step 2902 : 6431.0
# Residual after step 2903 : 6404.0
# Residual after step 2904 : 6379.0
# Residual after step 2905 : 6357.0
# Residual after step 2906 : 6334.0
# Residual after step 2907 : 6311.0
# Residual after step 2908 : 6287.0
# Residual after step 2909 : 6262.0
# Residual after step 2910 : 6238.0
# Residual after step 2911 : 6216.0
# Residual after step 2912 : 6191.0
# Residual after step 2913 : 6168.0
# Residual after step 2914 : 6147.0
# Residual after step 2915 : 6123.0
# Residual after step 2916 : 6100.0
# Residual after step 2917 : 6075.0
# Residual after step 2918 : 6053.0
# Residual after step 2919 : 6028.0
# Residual after step 2920 : 6005.0
# Residual after step 2921 : 5981.0
# Residual after step 2922 : 5957.0
# Residual after step 2923 : 5932.0
# Residual after step 2924 : 5908.0
# Residual after step 2925 : 5885.0
# Residual after step 2926 : 5862.0
# Residual after step 2927 : 5840.0
# Residual after step 2928 : 5818.0
# Residual after step 2929 : 5795.0
# Residual after step 2930 : 5771.0
# Residual after step 2931 : 5749.0
# Residual after step 2932 : 5728.0
# Residual after step 2933 : 5705.0
# Residual after step 2934 : 5684.0
# Residual after step 2935 : 5662.0
# Residual after step 2936 : 5639.0
# Residual after step 2937 : 5615.0
# Residual after step 2938 : 5595.0
# Residual after step 2939 : 5573.0
# Residual after step 2940 : 5551.0
# Residual after step 2941 : 5527.0
# Residual after step 2942 : 5506.0
# Residual after step 2943 : 5485.0
# Residual after step 2944 : 5462.0
# Residual after step 2945 : 5438.0
# Residual after step 2946 : 5416.0
# Residual after step 2947 : 5393.0
# Residual after step 2948 : 5373.0
# Residual after step 2949 : 5350.0
# Residual after step 2950 : 5331.0
# Residual after step 2951 : 5312.0
# Residual after step 2952 : 5290.0
# Residual after step 2953 : 5270.0
# Residual after step 2954 : 5248.0
# Residual after step 2955 : 5226.0
# Residual after step 2956 : 5202.0
# Residual after step 2957 : 5179.0
# Residual after step 2958 : 5159.0
# Residual after step 2959 : 5138.0
# Residual after step 2960 : 5117.0
# Residual after step 2961 : 5094.0
# Residual after step 2962 : 5075.0
# Residual after step 2963 : 5055.0
# Residual after step 2964 : 5036.0
# Residual after step 2965 : 5015.0
# Residual after step 2966 : 4992.0
# Residual after step 2967 : 4970.0
# Residual after step 2968 : 4951.0
# Residual after step 2969 : 4930.0
# Residual after step 2970 : 4908.0
# Residual after step 2971 : 4890.0
# Residual after step 2972 : 4867.0
# Residual after step 2973 : 4845.0
# Residual after step 2974 : 4826.0
# Residual after step 2975 : 4807.0
# Residual after step 2976 : 4789.0
# Residual after step 2977 : 4767.0
# Residual after step 2978 : 4745.0
# Residual after step 2979 : 4726.0
# Residual after step 2980 : 4704.0
# Residual after step 2981 : 4683.0
# Residual after step 2982 : 4664.0
# Residual after step 2983 : 4645.0
# Residual after step 2984 : 4622.0
# Residual after step 2985 : 4601.0
# Residual after step 2986 : 4584.0
# Residual after step 2987 : 4563.0
# Residual after step 2988 : 4542.0
# Residual after step 2989 : 4521.0
# Residual after step 2990 : 4503.0
# Residual after step 2991 : 4485.0
# Residual after step 2992 : 4466.0
# Residual after step 2993 : 4446.0
# Residual after step 2994 : 4426.0
# Residual after step 2995 : 4409.0
# Residual after step 2996 : 4393.0
# Residual after step 2997 : 4376.0
# Residual after step 2998 : 4358.0
# Residual after step 2999 : 4340.0
# Residual after step 3000 : 4319.0
# Residual after step 3001 : 4302.0
# Residual after step 3002 : 4282.0
# Residual after step 3003 : 4265.0
# Residual after step 3004 : 4249.0
# Residual after step 3005 : 4231.0
# Residual after step 3006 : 4214.0
# Residual after step 3007 : 4195.0
# Residual after step 3008 : 4178.0
# Residual after step 3009 : 4160.0
# Residual after step 3010 : 4141.0
# Residual after step 3011 : 4121.0
# Residual after step 3012 : 4103.0
# Residual after step 3013 : 4086.0
# Residual after step 3014 : 4068.0
# Residual after step 3015 : 4049.0
# Residual after step 3016 : 4033.0
# Residual after step 3017 : 4015.0
# Residual after step 3018 : 3996.0
# Residual after step 3019 : 3977.0
# Residual after step 3020 : 3958.0
# Residual after step 3021 : 3938.0
# Residual after step 3022 : 3920.0
# Residual after step 3023 : 3903.0
# Residual after step 3024 : 3887.0
# Residual after step 3025 : 3871.0
# Residual after step 3026 : 3851.0
# Residual after step 3027 : 3830.0
# Residual after step 3028 : 3810.0
# Residual after step 3029 : 3794.0
# Residual after step 3030 : 3778.0
# Residual after step 3031 : 3759.0
# Residual after step 3032 : 3743.0
# Residual after step 3033 : 3726.0
# Residual after step 3034 : 3705.0
# Residual after step 3035 : 3690.0
# Residual after step 3036 : 3674.0
# Residual after step 3037 : 3654.0
# Residual after step 3038 : 3638.0
# Residual after step 3039 : 3623.0
# Residual after step 3040 : 3606.0
# Residual after step 3041 : 3589.0
# Residual after step 3042 : 3573.0
# Residual after step 3043 : 3558.0
# Residual after step 3044 : 3541.0
# Residual after step 3045 : 3525.0
# Residual after step 3046 : 3510.0
# Residual after step 3047 : 3496.0
# Residual after step 3048 : 3479.0
# Residual after step 3049 : 3462.0
# Residual after step 3050 : 3444.0
# Residual after step 3051 : 3427.0
# Residual after step 3052 : 3411.0
# Residual after step 3053 : 3396.0
# Residual after step 3054 : 3382.0
# Residual after step 3055 : 3367.0
# Residual after step 3056 : 3351.0
# Residual after step 3057 : 3336.0
# Residual after step 3058 : 3320.0
# Residual after step 3059 : 3304.0
# Residual after step 3060 : 3288.0
# Residual after step 3061 : 3273.0
# Residual after step 3062 : 3258.0
# Residual after step 3063 : 3239.0
# Residual after step 3064 : 3224.0
# Residual after step 3065 : 3208.0
# Residual after step 3066 : 3192.0
# Residual after step 3067 : 3178.0
# Residual after step 3068 : 3164.0
# Residual after step 3069 : 3149.0
# Residual after step 3070 : 3134.0
# Residual after step 3071 : 3120.0
# Residual after step 3072 : 3105.0
# Residual after step 3073 : 3087.0
# Residual after step 3074 : 3072.0
# Residual after step 3075 : 3059.0
# Residual after step 3076 : 3044.0
# Residual after step 3077 : 3027.0
# Residual after step 3078 : 3013.0
# Residual after step 3079 : 2999.0
# Residual after step 3080 : 2983.0
# Residual after step 3081 : 2967.0
# Residual after step 3082 : 2954.0
# Residual after step 3083 : 2936.0
# Residual after step 3084 : 2922.0
# Residual after step 3085 : 2906.0
# Residual after step 3086 : 2890.0
# Residual after step 3087 : 2875.0
# Residual after step 3088 : 2861.0
# Residual after step 3089 : 2847.0
# Residual after step 3090 : 2832.0
# Residual after step 3091 : 2816.0
# Residual after step 3092 : 2802.0
# Residual after step 3093 : 2789.0
# Residual after step 3094 : 2773.0
# Residual after step 3095 : 2758.0
# Residual after step 3096 : 2742.0
# Residual after step 3097 : 2727.0
# Residual after step 3098 : 2713.0
# Residual after step 3099 : 2698.0
# Residual after step 3100 : 2684.0
# Residual after step 3101 : 2669.0
# Residual after step 3102 : 2655.0
# Residual after step 3103 : 2642.0
# Residual after step 3104 : 2626.0
# Residual after step 3105 : 2610.0
# Residual after step 3106 : 2595.0
# Residual after step 3107 : 2580.0
# Residual after step 3108 : 2566.0
# Residual after step 3109 : 2551.0
# Residual after step 3110 : 2536.0
# Residual after step 3111 : 2522.0
# Residual after step 3112 : 2507.0
# Residual after step 3113 : 2493.0
# Residual after step 3114 : 2478.0
# Residual after step 3115 : 2465.0
# Residual after step 3116 : 2449.0
# Residual after step 3117 : 2434.0
# Residual after step 3118 : 2420.0
# Residual after step 3119 : 2407.0
# Residual after step 3120 : 2392.0
# Residual after step 3121 : 2375.0
# Residual after step 3122 : 2361.0
# Residual after step 3123 : 2346.0
# Residual after step 3124 : 2332.0
# Residual after step 3125 : 2318.0
# Residual after step 3126 : 2305.0
# Residual after step 3127 : 2291.0
# Residual after step 3128 : 2275.0
# Residual after step 3129 : 2261.0
# Residual after step 3130 : 2246.0
# Residual after step 3131 : 2233.0
# Residual after step 3132 : 2218.0
# Residual after step 3133 : 2205.0
# Residual after step 3134 : 2191.0
# Residual after step 3135 : 2178.0
# Residual after step 3136 : 2164.0
# Residual after step 3137 : 2150.0
# Residual after step 3138 : 2136.0
# Residual after step 3139 : 2122.0
# Residual after step 3140 : 2109.0
# Residual after step 3141 : 2096.0
# Residual after step 3142 : 2083.0
# Residual after step 3143 : 2070.0
# Residual after step 3144 : 2057.0
# Residual after step 3145 : 2043.0
# Residual after step 3146 : 2030.0
# Residual after step 3147 : 2016.0
# Residual after step 3148 : 2002.0
# Residual after step 3149 : 1989.0
# Residual after step 3150 : 1975.0
# Residual after step 3151 : 1962.0
# Residual after step 3152 : 1948.0
# Residual after step 3153 : 1934.0
# Residual after step 3154 : 1921.0
# Residual after step 3155 : 1905.0
# Residual after step 3156 : 1893.0
# Residual after step 3157 : 1880.0
# Residual after step 3158 : 1867.0
# Residual after step 3159 : 1854.0
# Residual after step 3160 : 1840.0
# Residual after step 3161 : 1827.0
# Residual after step 3162 : 1813.0
# Residual after step 3163 : 1799.0
# Residual after step 3164 : 1786.0
# Residual after step 3165 : 1772.0
# Residual after step 3166 : 1759.0
# Residual after step 3167 : 1746.0
# Residual after step 3168 : 1733.0
# Residual after step 3169 : 1720.0
# Residual after step 3170 : 1707.0
# Residual after step 3171 : 1693.0
# Residual after step 3172 : 1680.0
# Residual after step 3173 : 1666.0
# Residual after step 3174 : 1653.0
# Residual after step 3175 : 1639.0
# Residual after step 3176 : 1626.0
# Residual after step 3177 : 1613.0
# Residual after step 3178 : 1600.0
# Residual after step 3179 : 1587.0
# Residual after step 3180 : 1574.0
# Residual after step 3181 : 1561.0
# Residual after step 3182 : 1547.0
# Residual after step 3183 : 1534.0
# Residual after step 3184 : 1521.0
# Residual after step 3185 : 1508.0
# Residual after step 3186 : 1495.0
# Residual after step 3187 : 1482.0
# Residual after step 3188 : 1469.0
# Residual after step 3189 : 1456.0
# Residual after step 3190 : 1443.0
# Residual after step 3191 : 1429.0
# Residual after step 3192 : 1416.0
# Residual after step 3193 : 1403.0
# Residual after step 3194 : 1390.0
# Residual after step 3195 : 1376.0
# Residual after step 3196 : 1363.0
# Residual after step 3197 : 1350.0
# Residual after step 3198 : 1336.0
# Residual after step 3199 : 1324.0
# Residual after step 3200 : 1311.0
# Residual after step 3201 : 1298.0
# Residual after step 3202 : 1285.0
# Residual after step 3203 : 1271.0
# Residual after step 3204 : 1257.0
# Residual after step 3205 : 1243.0
# Residual after step 3206 : 1229.0
# Residual after step 3207 : 1215.0
# Residual after step 3208 : 1203.0
# Residual after step 3209 : 1191.0
# Residual after step 3210 : 1178.0
# Residual after step 3211 : 1165.0
# Residual after step 3212 : 1152.0
# Residual after step 3213 : 1140.0
# Residual after step 3214 : 1128.0
# Residual after step 3215 : 1115.0
# Residual after step 3216 : 1102.0
# Residual after step 3217 : 1089.0
# Residual after step 3218 : 1077.0
# Residual after step 3219 : 1063.0
# Residual after step 3220 : 1050.0
# Residual after step 3221 : 1037.0
# Residual after step 3222 : 1024.0
# Residual after step 3223 : 1011.0
# Residual after step 3224 : 1000.0
# Residual after step 3225 : 988.0
# Residual after step 3226 : 976.0
# Residual after step 3227 : 964.0
# Residual after step 3228 : 952.0
# Residual after step 3229 : 941.0
# Residual after step 3230 : 928.0
# Residual after step 3231 : 916.0
# Residual after step 3232 : 904.0
# Residual after step 3233 : 892.0
# Residual after step 3234 : 881.0
# Residual after step 3235 : 869.0
# Residual after step 3236 : 857.0
# Residual after step 3237 : 843.0
# Residual after step 3238 : 832.0
# Residual after step 3239 : 820.0
# Residual after step 3240 : 809.0
# Residual after step 3241 : 796.0
# Residual after step 3242 : 783.0
# Residual after step 3243 : 771.0
# Residual after step 3244 : 759.0
# Residual after step 3245 : 746.0
# Residual after step 3246 : 736.0
# Residual after step 3247 : 724.0
# Residual after step 3248 : 713.0
# Residual after step 3249 : 700.0
# Residual after step 3250 : 688.0
# Residual after step 3251 : 675.0
# Residual after step 3252 : 662.0
# Residual after step 3253 : 650.0
# Residual after step 3254 : 639.0
# Residual after step 3255 : 627.0
# Residual after step 3256 : 617.0
# Residual after step 3257 : 607.0
# Residual after step 3258 : 598.0
# Residual after step 3259 : 588.0
# Residual after step 3260 : 578.0
# Residual after step 3261 : 568.0
# Residual after step 3262 : 558.0
# Residual after step 3263 : 548.0
# Residual after step 3264 : 537.0
# Residual after step 3265 : 527.0
# Residual after step 3266 : 517.0
# Residual after step 3267 : 505.0
# Residual after step 3268 : 496.0
# Residual after step 3269 : 487.0
# Residual after step 3270 : 478.0
# Residual after step 3271 : 467.0
# Residual after step 3272 : 458.0
# Residual after step 3273 : 447.0
# Residual after step 3274 : 439.0
# Residual after step 3275 : 430.0
# Residual after step 3276 : 419.0
# Residual after step 3277 : 408.0
# Residual after step 3278 : 398.0
# Residual after step 3279 : 389.0
# Residual after step 3280 : 380.0
# Residual after step 3281 : 371.0
# Residual after step 3282 : 360.0
# Residual after step 3283 : 350.0
# Residual after step 3284 : 340.0
# Residual after step 3285 : 330.0
# Residual after step 3286 : 322.0
# Residual after step 3287 : 314.0
# Residual after step 3288 : 306.0
# Residual after step 3289 : 299.0
# Residual after step 3290 : 291.0
# Residual after step 3291 : 283.0
# Residual after step 3292 : 275.0
# Residual after step 3293 : 268.0
# Residual after step 3294 : 261.0
# Residual after step 3295 : 252.0
# Residual after step 3296 : 244.0
# Residual after step 3297 : 236.0
# Residual after step 3298 : 228.0
# Residual after step 3299 : 221.0
# Residual after step 3300 : 212.0
# Residual after step 3301 : 204.0
# Residual after step 3302 : 198.0
# Residual after step 3303 : 191.0
# Residual after step 3304 : 185.0
# Residual after step 3305 : 178.0
# Residual after step 3306 : 171.0
# Residual after step 3307 : 164.0
# Residual after step 3308 : 157.0
# Residual after step 3309 : 149.0
# Residual after step 3310 : 141.0
# Residual after step 3311 : 134.0
# Residual after step 3312 : 127.0
# Residual after step 3313 : 120.0
# Residual after step 3314 : 114.0
# Residual after step 3315 : 107.0
# Residual after step 3316 : 101.0
# Residual after step 3317 : 95.0
# Residual after step 3318 : 89.0
# Residual after step 3319 : 83.0
# Residual after step 3320 : 77.0
# Residual after step 3321 : 71.0
# Residual after step 3322 : 65.0
# Residual after step 3323 : 61.0
# Residual after step 3324 : 56.0
# Residual after step 3325 : 51.0
# Residual after step 3326 : 47.0
# Residual after step 3327 : 43.0
# Residual after step 3328 : 39.0
# Residual after step 3329 : 35.0
# Residual after step 3330 : 31.0
# Residual after step 3331 : 27.0
# Residual after step 3332 : 23.0
# Residual after step 3333 : 19.0
# Residual after step 3334 : 15.0
# Residual after step 3335 : 12.0
# Residual after step 3336 : 9.0
# Residual after step 3337 : 7.0
# Residual after step 3338 : 5.0
# Residual after step 3339 : 3.0
# Residual after step 3340 : 2.0
# Residual after step 3341 : 1.0
# Residual after step 3342 : 0.0
# Remaining nonzero entries = 0, Max = 0.00, Mean = 0.00

# %%
print(f"Remaining nonzero entries = {np.count_nonzero(R_2)}, Max = {np.max(R_2):.2f}, Mean = {np.mean(R_2):.2f}")
# Out:
# Remaining nonzero entries = 0, Max = 0.00, Mean = 0.00

# %%
plt_data=[0]
r_sum=sum([demand for demand in demand_list])*time_split
for item in process:
    for _ in range(item[0]):
        v=item[1]/item[0]/r_sum*100+plt_data[-1]
        plt_data.append(v)
np.save("data/network_availability_backbone_demand.npy",plt_data)

# %%
time_shift=0
total_supply=[0]*len(demand_list)
for cover in tqdm(all_cover):
    cover_csr = cover[2][0]
    sat_num = cover[3]
    total_supply += cover_csr.toarray().flatten()[len(demand_list)*time_shift:len(demand_list)*(time_shift+1)] * sat_num
# Out:
# 100%|██████████| 3343/3343 [00:00<00:00, 29706.75it/s]

# %%
supply_demand_ratio=[]
for idx,demand in enumerate(demand_list):
    if demand!=0:
        supply_demand_ratio.append(total_supply[idx]/demand)
print(np.mean(supply_demand_ratio))
np.save("data/supply_demand_ratio_backbone.npy",supply_demand_ratio)
# Out:
# 7.505528028121609

# %%
def FeasibilityCheck_one_slot(params):
    t,mega=params
    two_pi=2*np.pi
    total_supply=[]
    for idx,shell in enumerate(mega):
        T=T_list[idx]
        inc=inc_list[idx]
        for mid in range(shell["m"]):
            for nid in range(shell["n"]):
                r_set=[]
                a_sat=(two_pi/shell["m"]*mid-t/TE*two_pi)%two_pi
                b_sat=(two_pi/shell["n"]*nid+t/T*two_pi)%two_pi
                l_sat,p_sat=alpha_gamma_to_lambda_phi(a_sat,b_sat,inc)
                cid=create_new_grid_satellites([l_sat,p_sat])
                r_set=[[cid,1.0]]
                total_supply.append(r_set)
    # check the demand
    supply=[0]*len(demand_list)
    for r_set in total_supply:
        for item in r_set:
            supply[item[0]]+=item[1]
    return supply

# %%
backbone_data=np.load("data/MegaReduce_official_demand.npy",allow_pickle=True)
selected_data_backbone=backbone_data[-1][0]
T_list = np.array([satellite_period(shell["h"] * 1e3) for shell in selected_data_backbone])
inc_list = np.radians(np.array([shell["inc"] for shell in selected_data_backbone]))
total_supply_backbone=FeasibilityCheck_one_slot([0,selected_data_backbone])

supply_demand_ratio=[]
for idx,demand in enumerate(demand_list):
    if demand!=0:
        supply_demand_ratio.append(total_supply_backbone[idx]/demand)
print(np.mean(supply_demand_ratio))
np.save("data/supply_demand_ratio_backbone_megareduce.npy",supply_demand_ratio)
# Out:
# 13.836079205998992
